# %%
"""Get Holdings

Shows how to use the Get Holdings endpoint and extract it to a csv

Attributes
----------
holdings
transaction portfolios
"""
# Out:
# 'Get Holdings\n\nShows how to use the Get Holdings endpoint and extract it to a csv\n\nAttributes\n----------\nholdings\ntransaction portfolios\n'

# %% [markdown]
# # Set up LUSID

# %%
# Import general purpose packages
import os
import json
from datetime import datetime, timedelta
import pytz

# Import lusid specific packages
import lusid
import lusid.models as models
from lusid.exceptions import ApiException
from lusid.utilities import ApiClientFactory
from lusidjam.refreshing_token import RefreshingToken
from lusidtools.pandas_utils.lusid_pandas import lusid_response_to_data_frame
from lusidtools.cocoon.seed_sample_data import seed_data
from lusidtools.cocoon.utilities import create_scope_id

# Import data wrangling packages
import pandas as pd

pd.set_option("display.max_columns", None)

# Authenticate our user and create our API client
secrets_path = os.getenv("FBN_SECRETS_PATH")

# Initiate an API Factory which is the client side object for interacting with LUSID APIs
api_factory = lusid.utilities.ApiClientFactory(
    token=RefreshingToken(),
    api_secrets_filename=secrets_path,
    app_name="LusidJupyterNotebook",
)

# %% [markdown]
# # 1. Set up API

# %%
transaction_portfolio_api = api_factory.build(lusid.api.TransactionPortfoliosApi)

# %% [markdown]
# # 2. Run query and append data

# %%
port_list=["Global-Equity",
"UK-Equities",
"US-Corporate-Bond",
"US-Treasury-Bond"]

# %%
holdings = [lusid_response_to_data_frame(transaction_portfolio_api.get_holdings(scope='Finbourne-Examples', code=code),rename_properties=True)
            for code in port_list]

# %%
t holdings = pd.concat(holdings)
holdings.to_csv('holdings_exctract.csv')
holdings
# Out:
#    instrument_scope instrument_uid sub_holding_keys  \
# 0           default  LUID_3H20UBFA               {}
# 1           default  LUID_31ZLKWDQ               {}
# 2           default  LUID_OUSF7KDR               {}
# 3           default  LUID_BDTJQKP1               {}
# 4           default  LUID_AME0PTMO               {}
# 5           default  LUID_5QJC3AOO               {}
# 6           default  LUID_E4JEX4J7               {}
# 7           default  LUID_KOXFLVUC               {}
# 8           default  LUID_QGHPQYLG               {}
# 9           default  LUID_8IA33I0K               {}
# 10          default        CCY_USD               {}
# 11          default        CCY_GBP               {}
# 12          default        CCY_EUR               {}
# 13          default        CCY_JPY               {}
# 0           default  LUID_1GE7UFMM               {}
# 1           default  LUID_E3Q6JOBO               {}
# 2           default  LUID_63DLF4VU               {}
# 3           default  LUID_RQWALYGH               {}
# 4           default  LUID_5QJC3AOO               {}
# 5           default  LUID_E4JEX4J7               {}
# 6           default  LUID_KTR2C5H9               {}
# 7           default  LUID_1DUPKXID               {}
# 8           default  LUID_Q5M89609               {}
# 9           default  LUID_TZTUV3GJ               {}
# 10          default        CCY_GBP               {}
# 0           default  LUID_OYESYE50               {}
# 1           default  LUID_TXJYHAZA               {}
# 2           default  LUID_57YE2DH0               {}
# 3           default  LUID_ZLZEJVRZ               {}
# 4           default  LUID_OODUORDJ               {}
# 5           default  LUID_6EGRWV3G               {}
# 6           default  LUID_JNV75HDA               {}
# 7           default  LUID_0HVJ675V               {}
# 8           default  LUID_V7MK8JHO               {}
# 9           default  LUID_DLCC6POA               {}
# 10          default        CCY_USD               {}
# 0           default  LUID_BRVKZW68               {}
# 1           default  LUID_XH8ERPOE               {}
# 2           default  LUID_VYBM7RRC               {}
# 3           default  LUID_UETA6QN8               {}
# 4           default  LUID_YKUVREEO               {}
# 5           default  LUID_AWNXYH31               {}
# 6           default  LUID_MMTS8V7A               {}
# 7           default  LUID_O0G86KUT               {}
# 8           default  LUID_0HBQPWHS               {}
# 9           default  LUID_Y54762WC               {}
# 10          default        CCY_USD               {}
#
#    SourcePortfolioId(default-Properties)  \
# 0                          Global-Equity
# 1                          Global-Equity
# 2                          Global-Equity
# 3                          Global-Equity
# 4                          Global-Equity
# 5                          Global-Equity
# 6                          Global-Equity
# 7                          Global-Equity
# 8                          Global-Equity
# 9                          Global-Equity
# 10                         Global-Equity
# 11                         Global-Equity
# 12                         Global-Equity
# 13                         Global-Equity
# 0                            UK-Equities
# 1                            UK-Equities
# 2                            UK-Equities
# 3                            UK-Equities
# 4                            UK-Equities
# 5                            UK-Equities
# 6                            UK-Equities
# 7                            UK-Equities
# 8                            UK-Equities
# 9                            UK-Equities
# 10                           UK-Equities
# 0                      US-Corporate-Bond
# 1                      US-Corporate-Bond
# 2                      US-Corporate-Bond
# 3                      US-Corporate-Bond
# 4                      US-Corporate-Bond
# 5                      US-Corporate-Bond
# 6                      US-Corporate-Bond
# 7                      US-Corporate-Bond
# 8                      US-Corporate-Bond
# 9                      US-Corporate-Bond
# 10                     US-Corporate-Bond
# 0                       US-Treasury-Bond
# 1                       US-Treasury-Bond
# 2                       US-Treasury-Bond
# 3                       US-Treasury-Bond
# 4                       US-Treasury-Bond
# 5                       US-Treasury-Bond
# 6                       US-Treasury-Bond
# 7                       US-Treasury-Bond
# 8                       US-Treasury-Bond
# 9                       US-Treasury-Bond
# 10                      US-Treasury-Bond
#
#    SourcePortfolioScope(default-Properties) holding_type         units  \
# 0                        Finbourne-Examples            P  1.200000e+07
# 1                        Finbourne-Examples            P  8.390274e+06
# 2                        Finbourne-Examples            P  1.098658e+07
# 3                        Finbourne-Examples            P -8.191471e+06
# 4                        Finbourne-Examples            P  1.085971e+07
# 5                        Finbourne-Examples            P  4.741176e+05
# 6                        Finbourne-Examples            P  2.937647e+06
# 7                        Finbourne-Examples            P  8.300000e+06
# 8                        Finbourne-Examples            P  2.135294e+07
# 9                        Finbourne-Examples            P  1.556824e+07
# 10                       Finbourne-Examples            B -2.450548e+07
# 11                       Finbourne-Examples            B -2.734676e+07
# 12                       Finbourne-Examples            B  2.076854e+09
# 13                       Finbourne-Examples            B -3.584603e+07
# 0                        Finbourne-Examples            P  8.286765e+04
# 1                        Finbourne-Examples            P  6.736471e+04
# 2                        Finbourne-Examples            P  5.147059e+04
# 3                        Finbourne-Examples            P  8.000000e+03
# 4                        Finbourne-Examples            P  1.989706e+04
# 5                        Finbourne-Examples            P  1.213235e+04
# 6                        Finbourne-Examples            P  9.263294e+04
# 7                        Finbourne-Examples            P  5.343088e+04
# 8                        Finbourne-Examples            P  1.200000e+05
# 9                        Finbourne-Examples            P  3.602941e+04
# 10                       Finbourne-Examples            B  2.294932e+05
# 0                        Finbourne-Examples            P -5.520221e+06
# 1                        Finbourne-Examples            P -6.500000e+07
# 2                        Finbourne-Examples            P  1.137500e+08
# 3                        Finbourne-Examples            P -2.838971e+07
# 4                        Finbourne-Examples            P -4.014706e+07
# 5                        Finbourne-Examples            P  2.208088e+07
# 6                        Finbourne-Examples            P  7.025735e+07
# 7                        Finbourne-Examples            P  1.261765e+07
# 8                        Finbourne-Examples            P  8.363971e+06
# 9                        Finbourne-Examples            P  1.577206e+07
# 10                       Finbourne-Examples            B -7.648761e+05
# 0                        Finbourne-Examples            P -5.823529e+06
# 1                        Finbourne-Examples            P  8.735294e+06
# 2                        Finbourne-Examples            P  4.561765e+07
# 3                        Finbourne-Examples            P  5.250000e+07
# 4                        Finbourne-Examples            P  2.161765e+07
# 5                        Finbourne-Examples            P  1.550000e+08
# 6                        Finbourne-Examples            P  5.823529e+07
# 7                        Finbourne-Examples            P  7.500000e+07
# 8                        Finbourne-Examples            P -1.455882e+07
# 9                        Finbourne-Examples            P  7.667647e+07
# 10                       Finbourne-Examples            B  2.906731e+06
#
#     settled_units   cost.amount cost.currency  cost_portfolio_ccy.amount  \
# 0    1.200000e+07  2.390760e+09           USD               1.822715e+09
# 1    8.390274e+06  1.329858e+09           EUR               1.146539e+09
# 2    1.098658e+07  7.197106e+10           JPY               4.896295e+08
# 3   -8.191471e+06 -1.092849e+09           USD              -8.224518e+08
# 4    1.085971e+07  1.314567e+09           USD               1.002226e+09
# 5    4.741176e+05  3.109738e+08           GBP               3.109738e+08
# 6    2.937647e+06  1.390072e+09           GBP               1.390072e+09
# 7    8.300000e+06  9.814750e+10           JPY               6.680444e+08
# 8    2.135294e+07  2.379056e+09           USD               1.760183e+09
# 9    1.556824e+07  1.257652e+09           EUR               1.050759e+09
# 10  -2.450548e+07 -2.450548e+07           USD               0.000000e+00
# 11  -2.734676e+07 -2.734676e+07           GBP              -2.734676e+07
# 12   2.076854e+09  2.076854e+09           EUR               0.000000e+00
# 13  -3.584603e+07 -3.584603e+07           JPY               0.000000e+00
# 0    8.286765e+04  2.382445e+05           GBP               2.382445e+05
# 1    6.736471e+04  1.791901e+05           GBP               1.791901e+05
# 2    5.147059e+04  9.761397e+04           GBP               9.761397e+04
# 3    8.000000e+03  3.868000e+05           GBP               3.868000e+05
# 4    1.989706e+04  1.305048e+05           GBP               1.305048e+05
# 5    1.213235e+04  6.914228e+04           GBP               6.914228e+04
# 6    9.263294e+04  5.552418e+06           GBP               5.552418e+06
# 7    5.343088e+04  2.585520e+06           GBP               2.585520e+06
# 8    1.200000e+05  1.710000e+05           GBP               1.710000e+05
# 9    3.602941e+04  2.955853e+05           GBP               2.955853e+05
# 10   2.294932e+05  2.294931e+05           GBP               2.294931e+05
# 0   -5.520221e+06 -5.625523e+06           USD              -5.625523e+06
# 1   -6.500000e+07 -6.752482e+07           USD              -6.752482e+07
# 2    1.137500e+08  1.134238e+08           USD               1.134238e+08
# 3   -2.838971e+07 -3.136201e+07           USD              -3.136201e+07
# 4   -4.014706e+07 -4.106366e+07           USD              -4.106366e+07
# 5    2.208088e+07  2.069485e+07           USD               2.069485e+07
# 6    7.025735e+07  7.139498e+07           USD               7.139498e+07
# 7    1.261765e+07  1.257152e+07           USD               1.257152e+07
# 8    8.363971e+06  1.041076e+07           USD               1.041076e+07
# 9    1.577206e+07  1.689421e+07           USD               1.689421e+07
# 10  -7.648761e+05 -7.648762e+05           USD              -7.648762e+05
# 0   -5.823529e+06 -7.025708e+06           USD              -7.025708e+06
# 1    8.735294e+06  8.805198e+06           USD               8.805198e+06
# 2    4.561765e+07  4.577540e+07           USD               4.577540e+07
# 3    5.250000e+07  5.259227e+07           USD               5.259227e+07
# 4    2.161765e+07  2.133231e+07           USD               2.133231e+07
# 5    1.550000e+08  1.527824e+08           USD               1.527824e+08
# 6    5.823529e+07  5.694038e+07           USD               5.694038e+07
# 7    7.500000e+07  7.403448e+07           USD               7.403448e+07
# 8   -1.455882e+07 -1.455073e+07           USD              -1.455073e+07
# 9    7.667647e+07  7.567790e+07           USD               7.567790e+07
# 10   2.906731e+06  2.906731e+06           USD               2.906731e+06
#
#    cost_portfolio_ccy.currency currency
# 0                          GBP      USD
# 1                          GBP      EUR
# 2                          GBP      JPY
# 3                          GBP      USD
# 4                          GBP      USD
# 5                          GBP      GBP
# 6                          GBP      GBP
# 7                          GBP      JPY
# 8                          GBP      USD
# 9                          GBP      EUR
# 10                         GBP      USD
# 11                         GBP      GBP
# 12                         GBP      EUR
# 13                         GBP      JPY
# 0                          GBP      GBP
# 1                          GBP      GBP
# 2                          GBP      GBP
# 3                          GBP      GBP
# 4                          GBP      GBP
# 5                          GBP      GBP
# 6                          GBP      GBP
# 7                          GBP      GBP
# 8                          GBP      GBP
# 9                          GBP      GBP
# 10                         GBP      GBP
# 0                          USD      USD
# 1                          USD      USD
# 2                          USD      USD
# 3                          USD      USD
# 4                          USD      USD
# 5                          USD      USD
# 6                          USD      USD
# 7                          USD      USD
# 8                          USD      USD
# 9                          USD      USD
# 10                         USD      USD
# 0                          USD      USD
# 1                          USD      USD
# 2                          USD      USD
# 3                          USD      USD
# 4                          USD      USD
# 5                          USD      USD
# 6                          USD      USD
# 7                          USD      USD
# 8                          USD      USD
# 9                          USD      USD
# 10                         USD      USD
