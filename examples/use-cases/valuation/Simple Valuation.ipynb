# %%
from lusidtools.jupyter_tools import toggle_code

"""Simple valuation with default recipes

This notebook shows how to value a portfolio using default recipes, for an out of the box look at positions and valuations

Attributes
----------
valuation
transactions
recipes
manifests
"""


toggle_code("Hide docstring")
# Out:
#     <form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Hide docstring"></form>
#
#          <script>
#          function code_toggle() {
#              if ($('div.cell.code_cell.rendered.selected div.input').css('display')!='none'){
#                  $('div.cell.code_cell.rendered.selected div.input').hide();
#              } else {
#                  $('div.cell.code_cell.rendered.selected div.input').show();
#              }
#          }
#          </script>

# %% [markdown]
# # Simplified Valuation

# %% [markdown]
# >⚠️ WARNING ⚠️
# >
# >In order to run this notebook, code in sections 1.1 needs to be uncommented.
# >Be aware that this will have system-wide implications for booking transactions (beyond the scope of this notebook) as enabling the "SetTradeToPortfolioRate" field enables it across the entire LUSID domain.

# %% [markdown]
# This notebook illustrates an example of how to use [*GetValuation*](https://www.lusid.com/docs/api/#operation/GetValuation) for a simplified call to the valuation engine. This notebook also demonstrates how LUSID can return the cost of trades in the base portfolio currency when trades are booked with different trade currencies to the base portfolio currency. This is possible by accessing FX rates that we load into the quotes store.
#
# ## Table of contents
# - 1. [Load data](#1.-Load-Data)
#    * [1.1 Config Store](#1.1-Config-Store)
#    * [1.2 Define Valuation Recipe](#1.2-Define-Valuation-Recipe)
#    * [1.3 FX rate](#1.3-FX-rate)
#    * [1.4 Instruments](#1.4-Instruments)
#    * [1.5 Portfolio](#1.5-Portfolio)
#    * [1.6 Transactions](#1.6-Transactions)
#    * [1.7 Quotes](#1.7-Quotes)
# - 2. [Run simplified valuation](#2.-Run-simplified-valuation)
#     * [2.1 Single-day](#2.1-Single-day)
#     * [2.2 Multi-day subtotals](#2.2-Multi-day-subtotals)
#     * [2.3 Multi-day ranges](#2.3-Multi-day-ranges)
# - 3. [A2B Report](#3.-A2B-Report)
#     * [3.1 A2B Currency Gains](#3.1-A2B-Currency-Gains)

# %%
# Import system packages

# Import lusid specific packages
# These are the core lusid packages for interacting with the API via Python

import lusid
import lusid.models as models
from lusid.utilities import ApiClientFactory
import lusid_configuration
from lusid_configuration import ConfigurationSetsApi
from lusid_configuration import models as config_models
from fbnsdkutilities import ApiClientFactory as ConfigApiClientFactory
from lusidjam.refreshing_token import RefreshingToken
from lusidtools.cocoon.cocoon import load_from_data_frame
from lusidtools.cocoon.cocoon_printer import (
    format_instruments_response,
    format_portfolios_response,
    format_transactions_response,
    format_quotes_response,
)
from lusidtools.pandas_utils.lusid_pandas import lusid_response_to_data_frame

import os
import pandas as pd
import pytz
from datetime import datetime, timedelta

# Set pandas dataframe display formatting
pd.set_option('display.max_columns', None)
pd.options.display.float_format = '{:,.2f}'.format

# Authenticate our user and create our API client
secrets_path = os.getenv("FBN_SECRETS_PATH")

if secrets_path is None:
    secrets_path = os.path.join(os.path.dirname(os.getcwd()), "secrets.json")


# Initiate an API Factory which is the client side object for interacting with LUSID APIs
api_factory = lusid.utilities.ApiClientFactory(
    token=RefreshingToken(),
    api_secrets_filename = secrets_path,
    app_name="LusidJupyterNotebook")

api_client = api_factory.api_client

lusid_api_url = api_client.configuration.host
configuration_api_url = lusid_api_url[: lusid_api_url.rfind("/") + 1] + "configuration"

config_api_factory = ConfigApiClientFactory(
    lusid_configuration,
    token=api_client.configuration.access_token,
    api_url=configuration_api_url,
    app_name="LusidJupyterNotebook",
)

print ('LUSID Environment Initialised')
print ('LUSID SDK Version: ', api_factory.build(lusid.api.ApplicationMetadataApi).get_lusid_versions().build_version)
# Out:
# LUSID Environment Initialised
# LUSID SDK Version:  0.6.10866.0

# %%
# Define the apis
quotes_api = api_factory.build(lusid.QuotesApi)
configuration_recipe_api = api_factory.build(lusid.api.ConfigurationRecipeApi)
instruments_api = api_factory.build(lusid.InstrumentsApi)
transaction_portfolios_api = api_factory.build(lusid.TransactionPortfoliosApi)
sets_api = config_api_factory.build(lusid_configuration.api.ConfigurationSetsApi)
aggregation_api = api_factory.build(lusid.AggregationApi)

# %% [markdown]
# ## 1. Load Data

# %%
# Define Variables
scope = "simple-valuation"
portfolio_code = "global-equities"
recipe_scope="IBOR"
recipe_code="TTPR_NB_Recipe"
start_date = datetime(year=2020, month=8, day=24, tzinfo=pytz.UTC)
end_date = datetime(year=2020, month=8, day=28, tzinfo=pytz.UTC)

transaction_date = datetime(year=2020, month=8, day=3, tzinfo=pytz.UTC)

# %% [markdown]
# ### 1.1 Config Store
#
# Set the "SetTradeToPortfolioRate" item to True to enable the calculation of the trade to portfolio rate in valuations.
# <span style="color:red">(This will need to be uncommented)</span>
#
# (Details on TradeToPortfolioRate property can be found here - https://support.lusid.com/knowledgebase/article/KA-01744/en-us#transaction)
#
# Also, set the scope and code of the "TradeToPortfolioRateRecipe" item (RecipeScope/RecipeCode)

# %%
###########
# WARNING #
###########

# Turning on this property is a system-wide change and could affect other processes.

# Uncomment this to turn on TTPR

#Configure "SetTradeToPortfolioRate"

# config_ttpr_response = sets_api.update_configuration_item(
#      type="Shared",
#      scope="system",
#      code="TransactionBooking",
#      key="SetTradeToPortfolioRate",
#      update_configuration_item = config_models.UpdateConfigurationItem(value="True")
#  )

# Configure "TradeToPortfolioRateRecipe" config item
config_ttpr_recipe_response = sets_api.update_configuration_item(
    type="Shared",
    scope="system",
    code="TransactionBooking",
    key="TradeToPortfolioRateRecipe",
    update_configuration_item = config_models.UpdateConfigurationItem(value="IBOR/TTPR_NB_Recipe")
)

# %% [markdown]
# ### 1.2 Define Valuation Recipe
# Define the valuation recipe to be linked to the trade to portfolio rate configuration in the configuration store.

# %%
# Create a recipe to perform a valuation
configuration_recipe = models.ConfigurationRecipe(
    scope=recipe_scope,
    code=recipe_code,
    market=models.MarketContext(
        market_rules=[
            # define how to resolve the quotes
            models.MarketDataKeyRule(
                key='Fx.CurrencyPair.*',
                data_scope=scope,
                supplier='Lusid',
                quote_type='Rate',
                quote_interval='1D.0D',
                field="mid"
            ),
            models.MarketDataKeyRule(
                key='Quote.LusidInstrumentId.*',
                data_scope=scope,
                supplier='Lusid',
                quote_type='Price',
                quote_interval='1D.0D',
                field="mid"

            )
        ],
        options=models.MarketOptions(
            default_supplier="Lusid",
            default_instrument_code_type="ClientInternal",
            default_scope='Lusid',
            # This enables FX rate inference
            attempt_to_infer_missing_fx=True,

        ),
    ),
    pricing=models.PricingContext(
        options={"AllowPartiallySuccessfulEvaluation": True},
    ),
)

# Upsert recipe to LUSID
upsert_configuration_recipe_response = configuration_recipe_api.upsert_configuration_recipe(
    upsert_recipe_request=models.UpsertRecipeRequest(
        configuration_recipe=configuration_recipe
    )
)

# %% [markdown]
# ### 1.3 FX rate
# Load 6 different FX rate quotes for the different date's booked into this portfolio (see below).

# %%
# Define function to create FX rate upsert quote requests for provided currencies and effective date
def spot_request(from_ccy, to_ccy, fx_rate, valuation_date):
            return models.UpsertQuoteRequest(
                       quote_id=models.QuoteId(
                           models.QuoteSeriesId(
                               provider='Lusid',
                               instrument_id=f'{from_ccy}/{to_ccy}',
                               instrument_id_type='CurrencyPair',
                               quote_type='Rate',
                               field='mid'
                           ),
                           effective_at=valuation_date
                       ),
                       metric_value=models.MetricValue(
                           value=fx_rate,
                           unit=f'{from_ccy}/{to_ccy}'
                       ),
                       lineage='None'
            )

# %%
# Upsert 6 FX rate quotes
fx_rates = [[0.785, transaction_date.isoformat()],[0.77, start_date.isoformat()], [0.78, (start_date + timedelta(days=1)).isoformat()], [0.79, (start_date + timedelta(days=2)).isoformat()], [0.80, (start_date + timedelta(days=3)).isoformat()], [0.81, (start_date + timedelta(days=4)).isoformat()]]

request_body = {}
for i in range(len(fx_rates)):
    rate = fx_rates[i]
    request_body[str(i)] = spot_request("USD", "GBP", rate[0], rate[1])

response = quotes_api.upsert_quotes(scope=scope, request_body=request_body)

# %% [markdown]
# ### 1.4 Instruments
#
# Read the data from the quotes files, reading the instrument names and identifiers and adding the unique names to LUSID.

# %%
instruments_df = pd.read_excel("data/simple-valuation/ftse-100-prices31-Jul-2020-31-Aug-2020.xlsx")[["name", "figi"]].drop_duplicates()
instruments_df.head()
# Out:
#                   name          figi
# 0         3I GROUP PLC  BBG000BZZ876
# 21   ADMIRAL GROUP PLC  BBG000PG2GZ0
# 42  ANGLO AMERICAN PLC  BBG000BWF7M0
# 63     ANTOFAGASTA PLC  BBG000BD4SC9
# 84   ASHTEAD GROUP PLC  BBG000BD42C6

# %% [markdown]
# Create a mapping schema for the instruments using the provided FIGIs as the instrument identifiers. The instruments file is then loaded into LUSID.

# %%
instrument_mapping = {
    "identifier_mapping": {
        "Figi": "figi"
    },
    "required": {
        "name": "name"
    },
}

# %%
# Instruments can be loaded using a dataframe with file_type set to "instruments"
result = load_from_data_frame(
    api_factory=api_factory,
    scope=scope,
    data_frame=instruments_df,
    mapping_required=instrument_mapping["required"],
    mapping_optional={},
    file_type="instruments",
    identifier_mapping=instrument_mapping["identifier_mapping"]
)

succ, failed, errors = format_instruments_response(result)
pd.DataFrame(data=[{"success": len(succ), "failed": len(failed), "errors": len(errors)}])
# Out:
#    success  failed  errors
# 0      101       0       0

# %%
us_instruments_df = pd.read_excel("data/simple-valuation/usportfolio.xlsx")[["name", "ticker"]].drop_duplicates()
us_instruments_df.head()
# Out:
#                             name ticker
# 0          Uber Technologies Inc   UBER
# 1  Zoom Video Communications Inc     ZM
# 2          Spotify Technology SA   SPOT
# 3                  Pinterest Inc   PINS
# 4                       Nike Inc    NKE

# %% [markdown]
# Create a mapping schema for the instruments using the provided Ticker as the instrument identifiers. The instruments file is then loaded into LUSID.

# %%
us_instrument_mapping = {
    "identifier_mapping": {
        "ClientInternal": "ticker"
    },
    "required": {
        "name": "name"
    },
}

# %%
result = load_from_data_frame(
    api_factory=api_factory,
    scope=scope,
    data_frame=us_instruments_df,
    mapping_required=us_instrument_mapping["required"],
    mapping_optional={},
    file_type="instruments",
    identifier_mapping=us_instrument_mapping["identifier_mapping"]
)

succ, failed, errors = format_instruments_response(result)
pd.DataFrame(data=[{"success": len(succ), "failed": len(failed), "errors": len(errors)}])
# Out:
#    success  failed  errors
# 0       15       0       0

# %% [markdown]
# The instruments should now be viewable in the [LUSID webtool](https://www.lusid.com/app/home) (*Data Management* >>> *Instruments*)

# %% [markdown]
# ### 1.5 Portfolio
#
# Create a portfolio in LUSID by setting up a mapping schema which can then be used to load the relevant contents.

# %%
uk_portfolio_df = pd.read_excel("data/simple-valuation/ukportfolio.xlsx")
us_portfolio_df = pd.read_excel("data/simple-valuation/usportfolio.xlsx")
portfolio_df = pd.concat([uk_portfolio_df, us_portfolio_df])
portfolio_df
# Out:
#      portfolio_code    portfolio_name portfolio_base_currency instrument_id  \
# 0   global-equities  Equity Portfolio                     GBP  BBG000BWF7M0
# 1   global-equities  Equity Portfolio                     GBP  BBG000BDCLS8
# 2   global-equities  Equity Portfolio                     GBP  BBG000BD3SC0
# 3   global-equities  Equity Portfolio                     GBP  BBG000BD6DG6
# 4   global-equities  Equity Portfolio                     GBP  BBG000NSXQ99
# 5   global-equities  Equity Portfolio                     GBP  BBG000C0M8X7
# 6   global-equities  Equity Portfolio                     GBP  BBG000BDY8C0
# 7   global-equities  Equity Portfolio                     GBP  BBG000BF46Y8
# 8   global-equities  Equity Portfolio                     GBP  BBG000BRVH05
# 9   global-equities  Equity Portfolio                     GBP  BBG000BDQGR5
# 10  global-equities  Equity Portfolio                     GBP  BBG000BDY322
# 11  global-equities  Equity Portfolio                     GBP  BBG000BDPHS3
# 12  global-equities  Equity Portfolio                     GBP  BBG000CT5GJ1
# 13  global-equities  Equity Portfolio                     GBP  BBG000BD5TW4
# 14  global-equities  Equity Portfolio                     GBP  BBG000BDZZM8
# 15  global-equities  Equity Portfolio                     GBP  BBG000C05BD1
# 16  global-equities  Equity Portfolio                     GBP  BBG00RM7J0M5
# 17  global-equities  Equity Portfolio                     GBP  BBG000C6K6G9
# 18  global-equities  Equity Portfolio                     GBP  BBG000FV67Q4
# 19  global-equities  Equity Portfolio                     GBP  BBG000BKH1W6
# 20  global-equities  Equity Portfolio                     GBP  BBG000NSXQ99
# 21  global-equities  Equity Portfolio                     GBP  BBG00RM7J0M5
# 22  global-equities  Equity Portfolio                     GBP  BBG000BDY8C0
# 0   global-equities  Equity Portfolio                     GBP           NaN
# 1   global-equities  Equity Portfolio                     GBP           NaN
# 2   global-equities  Equity Portfolio                     GBP           NaN
# 3   global-equities  Equity Portfolio                     GBP           NaN
# 4   global-equities  Equity Portfolio                     GBP           NaN
# 5   global-equities  Equity Portfolio                     GBP           NaN
# 6   global-equities  Equity Portfolio                     GBP           NaN
# 7   global-equities  Equity Portfolio                     GBP           NaN
# 8   global-equities  Equity Portfolio                     GBP           NaN
# 9   global-equities  Equity Portfolio                     GBP           NaN
# 10  global-equities  Equity Portfolio                     GBP           NaN
# 11  global-equities  Equity Portfolio                     GBP           NaN
# 12  global-equities  Equity Portfolio                     GBP           NaN
# 13  global-equities  Equity Portfolio                     GBP           NaN
# 14  global-equities  Equity Portfolio                     GBP           NaN
#
#                                 name  txn_id txn_type txn_trade_date  \
# 0                 ANGLO AMERICAN PLC      T1      Buy     2020-08-03
# 1            CRODA INTERNATIONAL PLC      T2      Buy     2020-08-03
# 2       ASSOCIATED BRITISH FOODS PLC      T3      Buy     2020-08-03
# 3           BARRATT DEVELOPMENTS PLC      T4      Buy     2020-08-03
# 4                 BURBERRY GROUP PLC      T5      Buy     2020-08-03
# 5                       UNILEVER PLC      T6      Buy     2020-08-03
# 6                        PEARSON PLC      T7      Buy     2020-08-03
# 7                          TESCO PLC      T8      Buy     2020-08-03
# 8                      WHITBREAD PLC      T9      Buy     2020-08-03
# 9           LLOYDS BANKING GROUP PLC     T10      Buy     2020-08-03
# 10                    PRUDENTIAL PLC     T11      Buy     2020-08-03
# 11         LAND SECURITIES GROUP PLC     T12      Buy     2020-08-03
# 12               GLAXOSMITHKLINE PLC     T13      Buy     2020-08-03
# 13                   BAE SYSTEMS PLC     T14      Buy     2020-08-03
# 14              RENTOKIL INITIAL PLC     T15      Buy     2020-08-03
# 15                            BP PLC     T16      Buy     2020-08-03
# 16                 JUST EAT TAKEAWAY     T17      Buy     2020-08-03
# 17                VODAFONE GROUP PLC     T18      Buy     2020-08-03
# 18                 NATIONAL GRID PLC     T19      Buy     2020-08-03
# 19                    KINGFISHER PLC     T20      Buy     2020-08-03
# 20                BURBERRY GROUP PLC     T21      Buy     2020-08-03
# 21                 JUST EAT TAKEAWAY     T22      Buy     2020-08-03
# 22                       PEARSON PLC     T23      Buy     2020-08-03
# 0              Uber Technologies Inc   US_T1      Buy     2020-08-03
# 1      Zoom Video Communications Inc   US_T2      Buy     2020-08-03
# 2              Spotify Technology SA   US_T3      Buy     2020-08-03
# 3                      Pinterest Inc   US_T4      Buy     2020-08-03
# 4                           Nike Inc   US_T5      Buy     2020-08-03
# 5             Harmony Gold Mining Co   US_T6      Buy     2020-08-03
# 6                         Diageo PLC   US_T7      Buy     2020-08-03
# 7                      Carnival Corp   US_T8      Buy     2020-08-03
# 8       Bristol-Myers Squibb Company   US_T9      Buy     2020-08-03
# 9             AmerisourceBergen Corp  US_T10      Buy     2020-08-03
# 10                         Aflac Inc  US_T11      Buy     2020-08-03
# 11  American International Group Inc  US_T12      Buy     2020-08-03
# 12                     Allstate Corp  US_T13      Buy     2020-08-03
# 13               American Tower Corp  US_T14      Buy     2020-08-03
# 14                       Apache Corp  US_T15      Buy     2020-08-03
#
#    txn_settle_date  txn_units  txn_price  txn_consideration currency  \
# 0       2020-08-05     105000   1,910.60       2,016,700.00      GBP
# 1       2020-08-05       3500   5,820.00         198,934.00      GBP
# 2       2020-08-05      51000   1,786.00         903,500.00      GBP
# 3       2020-08-05      57000     524.40         303,360.00      GBP
# 4       2020-08-05      93000   1,280.00       1,190,400.00      GBP
# 5       2020-08-05      30000   4,664.00       1,397,770.00      GBP
# 6       2020-08-05     148000     541.80         804,170.00      GBP
# 7       2020-08-05     133000     219.20         292,675.00      GBP
# 8       2020-08-05      36000   2,220.00         799,414.00      GBP
# 9       2020-08-05    5750000      27.87       1,599,120.00      GBP
# 10      2020-08-05      85000   1,154.00         984,376.00      GBP
# 11      2020-08-05      52000     584.00         307,776.00      GBP
# 12      2020-08-05     163000   1,585.40       2,593,800.00      GBP
# 13      2020-08-05      81000     492.10         399,344.00      GBP
# 14      2020-08-05      83000     550.80       1,892,400.00      GBP
# 15      2020-08-05      64000     281.05       1,798,200.00      GBP
# 16      2020-08-05       2300   8,576.00         199,180.00      GBP
# 17      2020-08-05     500000     117.02         580,405.00      GBP
# 18      2020-08-05      87000     918.80         793,092.00      GBP
# 19      2020-08-05     360000     247.80         891,540.00      GBP
# 20      2020-08-05      50000   1,280.00         640,000.00      GBP
# 21      2020-08-05       5000   8,576.00         433,000.00      GBP
# 22      2020-08-05     153000     541.80         831,900.00      GBP
# 0       2020-08-05         50      50.00           2,500.00      USD
# 1       2020-08-05        100     300.00          30,000.00      USD
# 2       2020-08-05        150     200.00          30,000.00      USD
# 3       2020-08-05        200     100.00          20,000.00      USD
# 4       2020-08-05        250     150.00          37,500.00      USD
# 5       2020-08-05        300      50.00          15,000.00      USD
# 6       2020-08-05        350     150.00          52,500.00      USD
# 7       2020-08-05        400      50.00          20,000.00      USD
# 8       2020-08-05        450     150.00          67,500.00      USD
# 9       2020-08-05        550      80.00          44,000.00      USD
# 10      2020-08-05        650      20.00          13,000.00      USD
# 11      2020-08-05        700      15.00          10,500.00      USD
# 12      2020-08-05        750      50.00          37,500.00      USD
# 13      2020-08-05        800     100.00          80,000.00      USD
# 14      2020-08-05        850      50.00          42,500.00      USD
#
#     cash_transactions Strategy HoldingType  Commission  Fx_rate  \
# 0                 NaN  Tracker      Equity    5,041.75     1.00
# 1                 NaN  Tracker      Equity      497.33     1.00
# 2                 NaN  Tracker      Equity    2,258.75     1.00
# 3                 NaN  Tracker      Equity      758.40     1.00
# 4                 NaN  Tracker      Equity    2,976.00     1.00
# 5                 NaN  Tracker      Equity    3,494.43     1.00
# 6                 NaN  Tracker      Equity    2,010.42     1.00
# 7                 NaN  Tracker      Equity      731.69     1.00
# 8                 NaN  Tracker      Equity    1,998.54     1.00
# 9                 NaN  Tracker      Equity    3,997.80     1.00
# 10                NaN  Tracker      Equity    2,460.94     1.00
# 11                NaN  Tracker      Equity      769.44     1.00
# 12                NaN  Tracker      Equity    6,484.50     1.00
# 13                NaN  Tracker      Equity      998.36     1.00
# 14                NaN  Tracker      Equity    4,731.00     1.00
# 15                NaN  Tracker      Equity    4,495.50     1.00
# 16                NaN  Tracker      Equity      497.95     1.00
# 17                NaN  Tracker      Equity    1,451.01     1.00
# 18                NaN  Tracker      Equity    1,982.73     1.00
# 19                NaN  Tracker      Equity    2,228.85     1.00
# 20                NaN   Growth      Equity    1,600.00     1.00
# 21                NaN   Growth      Equity    1,082.50     1.00
# 22                NaN   Growth      Equity    2,079.75     1.00
# 0                 NaN      NaN         NaN         NaN      NaN
# 1                 NaN      NaN         NaN         NaN      NaN
# 2                 NaN      NaN         NaN         NaN      NaN
# 3                 NaN      NaN         NaN         NaN      NaN
# 4                 NaN      NaN         NaN         NaN      NaN
# 5                 NaN      NaN         NaN         NaN      NaN
# 6                 NaN      NaN         NaN         NaN      NaN
# 7                 NaN      NaN         NaN         NaN      NaN
# 8                 NaN      NaN         NaN         NaN      NaN
# 9                 NaN      NaN         NaN         NaN      NaN
# 10                NaN      NaN         NaN         NaN      NaN
# 11                NaN      NaN         NaN         NaN      NaN
# 12                NaN      NaN         NaN         NaN      NaN
# 13                NaN      NaN         NaN         NaN      NaN
# 14                NaN      NaN         NaN         NaN      NaN
#
#             Sector ticker
# 0              NaN    NaN
# 1              NaN    NaN
# 2              NaN    NaN
# 3              NaN    NaN
# 4              NaN    NaN
# 5              NaN    NaN
# 6              NaN    NaN
# 7              NaN    NaN
# 8              NaN    NaN
# 9              NaN    NaN
# 10             NaN    NaN
# 11             NaN    NaN
# 12             NaN    NaN
# 13             NaN    NaN
# 14             NaN    NaN
# 15             NaN    NaN
# 16             NaN    NaN
# 17             NaN    NaN
# 18             NaN    NaN
# 19             NaN    NaN
# 20             NaN    NaN
# 21             NaN    NaN
# 22             NaN    NaN
# 0       Technology   UBER
# 1       Technology     ZM
# 2       Technology   SPOT
# 3       Technology   PINS
# 4   Consumer Goods    NKE
# 5   Consumer Goods    HMY
# 6   Consumer Goods    DEO
# 7   Consumer Goods    CCL
# 8       Healthcare    BMY
# 9       Healthcare    ABC
# 10       Financial    AFL
# 11       Financial    AIG
# 12       Financial    ALL
# 13       Financial    AMT
# 14          Energy    APA

# %%
portfolio_mapping = {
    "required": {
        "code": "portfolio_code",
        "display_name": "portfolio_name",
        "base_currency": "$GBP",
    },
    "optional": {
        "created": "$2020-01-01T00:00:00+00:00",
        "instrument_scopes": f"${scope}"
                 },
}

# %%
# A portfolio can be loaded using a dataframe with file_type = "portfolios"
result = load_from_data_frame(
    api_factory=api_factory,
    scope=scope,
    data_frame=portfolio_df,
    mapping_required=portfolio_mapping["required"],
    mapping_optional=portfolio_mapping["optional"],
    file_type="portfolios",
    sub_holding_keys=[],
)

succ, failed = format_portfolios_response(result)
pd.DataFrame(data=[{"success": len(succ), "failed": len(failed), "errors": len(errors)}])
# Out:
#    success  failed  errors
# 0        1       0       0

# %% [markdown]
# ### 1.6 Transactions
#
# Create transaction mapping schemas that use the provided FIGI or Ticker identifiers to load the data into LUSID.

# %%
uk_transaction_mapping = {
    "identifier_mapping": {
        "Figi": "instrument_id"
    },
    "required": {
        "code": "portfolio_code",
        "transaction_id": "txn_id",
        "type": "txn_type",
        "transaction_price.price": "txn_price",
        "transaction_price.type": "$Price",
        "total_consideration.amount": "txn_consideration",
        "units": "txn_units",
        "transaction_date": "txn_trade_date",
        "total_consideration.currency": "currency",
        "settlement_date": "txn_settle_date",
    },
    "optional": {},
    "properties": [
                    {"scope": "default", "source": "Fx_rate", "target": "TradeToPortfolioRate"},
    ],
}

# %%
us_transaction_mapping = {
    "identifier_mapping": {
        "ClientInternal": "ticker"
    },
    "required": {
        "code": "portfolio_code",
        "transaction_id": "txn_id",
        "type": "txn_type",
        "transaction_price.price": "txn_price",
        "transaction_price.type": "$Price",
        "total_consideration.amount": "txn_consideration",
        "units": "txn_units",
        "transaction_date": "txn_trade_date",
        "total_consideration.currency": "currency",
        "settlement_date": "txn_settle_date",
    },
    "optional": {},
    "properties": [
                    {"scope": "default", "source": "Fx_rate", "target": "TradeToPortfolioRate"},
    ],
}

# %%
result = load_from_data_frame(
    api_factory=api_factory,
    scope=scope,
    data_frame=uk_portfolio_df,
    mapping_required=uk_transaction_mapping["required"],
    mapping_optional=uk_transaction_mapping["optional"],
    file_type="transactions",
    identifier_mapping=uk_transaction_mapping["identifier_mapping"],
    property_columns=uk_transaction_mapping["properties"]
)
succ, failed = format_transactions_response(result)
pd.DataFrame(data=[{"success": len(succ), "failed": len(failed), "errors": len(errors)}])
# Out:
#    success  failed  errors
# 0        1       0       0

# %%
result = load_from_data_frame(
    api_factory=api_factory,
    scope=scope,
    data_frame=us_portfolio_df,
    mapping_required=us_transaction_mapping["required"],
    mapping_optional=us_transaction_mapping["optional"],
    file_type="transactions",
    identifier_mapping=us_transaction_mapping["identifier_mapping"],
    property_columns=us_transaction_mapping["properties"],
    properties_scope="default",
)
succ, failed = format_transactions_response(result)
pd.DataFrame(data=[{"success": len(succ), "failed": len(failed), "errors": len(errors)}])
# Out:
#    success  failed  errors
# 0        1       0       0

# %% [markdown]
# ### 1.7 Quotes
#
# Load the source quotes data which contains open and close prices for our Holdings between July 31st and August 31st. This is the pricing data that will be used later in valuation.

# %%
uk_quotes_df = pd.read_excel("data/simple-valuation/ftse-100-prices31-Jul-2020-31-Aug-2020.xlsx")
us_quotes_df = pd.read_csv("data/simple-valuation/yahoo-us-prices.csv")

# %%
uk_quotes_df.head(1)
# Out:
#                        date ticker          name          figi  \
# 0  2020-07-31T00:00:00.000Z  III.L  3I GROUP PLC  BBG000BZZ876
#
#                Sector  open_price  close_price currency
# 0  Financial Services      876.20       889.60      GBP

# %%
us_quotes_df.head(1)
# Out:
#          date ticker  open_price  close_price                   name currency
# 0  31/07/2020   UBER       30.40        30.26  Uber Technologies Inc      USD

# %% [markdown]
# The current quotes sources data use FIGI or Ticker as the core unique identifiers, but we can call the API and create unique LUSID identifiers (LUID). These will later be used in our valuation call by mapping them against the previously set transactions.

# %%
def add_luid_id(data_frame, scope, identifier, type):
    client_ids = pd.DataFrame(list(data_frame[identifier].unique()), columns=[identifier])

    # Call lusid_instrument_id to the API for creating the LUIDs
    client_ids["LUID"] = client_ids[identifier].apply(
    lambda x: api_factory.build(lusid.api.InstrumentsApi).get_instrument(
        scope=scope,
        identifier_type=type,
        identifier=x).lusid_instrument_id)
    client_ids = client_ids.set_index(identifier)
    data_frame['LUID'] = data_frame[identifier].apply(lambda x: client_ids.loc[x]["LUID"])
    return data_frame

# %%
uk_df = add_luid_id(uk_quotes_df, scope, "figi", "Figi")
us_df = add_luid_id(us_quotes_df, scope, "ticker", "ClientInternal")

df = pd.concat([uk_df, us_df],ignore_index=True)

# Check the first one to see that LUID was added
df.head(1)
# Out:
#                        date ticker          name          figi  \
# 0  2020-07-31T00:00:00.000Z  III.L  3I GROUP PLC  BBG000BZZ876
#
#                Sector  open_price  close_price currency           LUID
# 0  Financial Services      876.20       889.60      GBP  LUID_00003DGC

# %% [markdown]
# Create a mapping schema for the quotes dataframe to read the using the LUIDs.

# %%
quotes_mapping = {
    "quote_id.quote_series_id.instrument_id_type": "$LusidInstrumentId",
    "quote_id.effective_at": "date",
    "quote_id.quote_series_id.provider": "$Lusid",
    "quote_id.quote_series_id.quote_type": "$Price",
    "quote_id.quote_series_id.instrument_id": "LUID",
    "metric_value.unit": "currency",
}

# %% [markdown]
# We can use the end of day close prices for mapping the quotes source data (pricing data assumed to be using "mid" quotes).

# %%
quotes_mapping["quote_id.quote_series_id.field"] ="$mid"
quotes_mapping["metric_value.value"] = "close_price"

result = load_from_data_frame(
    api_factory = api_factory,
    scope=scope,
    data_frame=df,
    mapping_required=quotes_mapping,
    mapping_optional={},
    file_type="quotes"
)

succ, failed, errors = format_quotes_response(result)
display(pd.DataFrame(data=[{"success": len(succ), "failed": len(failed), "errors": len(errors)}]))
# Out:
#    success  failed  errors
# 0     2421       0       0

# %% [markdown]
# ## 2. Run simplified valuation
#
# ### 2.1 Single-day
#
# Perform a valuation on the portfolio by using the simple valuation call from LUSID.
#
# - Recipe attributes:
#
# | Price source/supplier | Instrument ID | Quote Type  | Pricing Model |   Calculation    |
# |:---------------------:|:-------------:|:-----------:|:-------------:|:----------------:|
# |         LUSID         |     LUID      | Price (mid) | Simple Static | Quantity x price |

# %%
# Set up the aggregation request
def aggregation_request(effectiveAt):
    return models.ValuationRequest( 
        recipe_id = models.ResourceId(
            scope = recipe_scope,
            code = recipe_code
        ),
        metrics = [
            models.AggregateSpec("Instrument/default/Name", "Value"),
            models.AggregateSpec("Valuation/PV", "Sum"),
            models.AggregateSpec("Holding/default/Units", "Sum")
        ],
        group_by=["Instrument/default/Name"],
        # choose the valuation date for the request - set using effectiveAt
        valuation_schedule=models.ValuationSchedule(effective_at=effectiveAt),
        portfolio_entity_ids = [models.PortfolioEntityId(
                                                        scope = scope,
                                                        code = portfolio_code,
                                                        portfolio_entity_type="SinglePortfolio" 
            )]
        )

# %%
# Pull the data aggregation by passing the effectiveAt date
aggregation = aggregation_api.get_valuation(
                                            valuation_request=aggregation_request((start_date+timedelta(days=3)).isoformat())
            )
#display(aggregation)
pd.DataFrame(aggregation.data)
# Out:
#              Instrument/default/Name  Sum(Valuation/PV)  \
# 0                GLAXOSMITHKLINE PLC     247,955,600.00
# 1                        PEARSON PLC     176,386,000.00
# 2                     KINGFISHER PLC      98,640,000.00
# 3                 VODAFONE GROUP PLC      58,480,000.00
# 4               RENTOKIL INITIAL PLC      44,753,600.00
# 5                     PRUDENTIAL PLC     104,082,500.00
# 6                  JUST EAT TAKEAWAY      64,313,000.00
# 7                          TESCO PLC      30,191,000.00
# 8                 BURBERRY GROUP PLC     200,700,500.00
# 9                             BP PLC      18,048,000.00
# 10                 NATIONAL GRID PLC      77,221,200.00
# 11      ASSOCIATED BRITISH FOODS PLC     104,193,000.00
# 12                     WHITBREAD PLC      85,320,000.00
# 13          LLOYDS BANKING GROUP PLC     164,450,000.00
# 14                   BAE SYSTEMS PLC      43,869,600.00
# 15          BARRATT DEVELOPMENTS PLC      29,982,000.00
# 16           CRODA INTERNATIONAL PLC      20,965,000.00
# 17                ANGLO AMERICAN PLC     200,172,000.00
# 18         LAND SECURITIES GROUP PLC      29,827,200.00
# 19                      UNILEVER PLC     137,430,000.00
# 20  American International Group Inc          20,685.00
# 21            AmerisourceBergen Corp          53,663.50
# 22      Bristol-Myers Squibb Company          28,084.50
# 23                     Pinterest Inc           6,580.00
# 24                          Nike Inc          27,957.50
# 25            Harmony Gold Mining Co           1,776.00
# 26     Zoom Video Communications Inc          28,228.00
# 27             Spotify Technology SA          40,369.50
# 28                         Aflac Inc          24,297.00
# 29                        Diageo PLC          48,370.00
# 30                     Carnival Corp           6,456.00
# 31             Uber Technologies Inc           1,552.00
# 32                     Allstate Corp          71,250.00
# 33                       Apache Corp          12,291.00
# 34               American Tower Corp         196,352.00
# 35                               GBP     -21,851,056.00
# 36                               USD        -502,500.00
#
#     Sum(Holding/default/Units)
# 0                   163,000.00
# 1                   301,000.00
# 2                   360,000.00
# 3                   500,000.00
# 4                    83,000.00
# 5                    85,000.00
# 6                     7,300.00
# 7                   133,000.00
# 8                   143,000.00
# 9                    64,000.00
# 10                   87,000.00
# 11                   51,000.00
# 12                   36,000.00
# 13                5,750,000.00
# 14                   81,000.00
# 15                   57,000.00
# 16                    3,500.00
# 17                  105,000.00
# 18                   52,000.00
# 19                   30,000.00
# 20                      700.00
# 21                      550.00
# 22                      450.00
# 23                      200.00
# 24                      250.00
# 25                      300.00
# 26                      100.00
# 27                      150.00
# 28                      650.00
# 29                      350.00
# 30                      400.00
# 31                       50.00
# 32                      750.00
# 33                      850.00
# 34                      800.00
# 35              -21,851,056.00
# 36                 -502,500.00

# %% [markdown]
# ### 2.2 Multi-day subtotals
#
# Using the same valuation request, we are also able to inspect the evolution of the portfolio holdings and their value for a custom date range. Using a function that groups by <code>"Analytic/default/ValuationDate"</code> the function can call LUSID for an overall PV of the portfolio as a time series.

# %%
def aggregation_interval_request(effectiveFrom, effectiveAt):
    return models.ValuationRequest( 
        recipe_id = models.ResourceId(
            scope = recipe_scope,
            code = recipe_code
        ),
        metrics = [
            models.AggregateSpec("Analytic/default/ValuationDate", "Value"),
            models.AggregateSpec("Valuation/PvInPortfolioCcy", "Sum"),

        ],
        group_by=["Analytic/default/ValuationDate"],
        # choose the valuation interval for the request - set using effectiveFrom and effectiveAt
        valuation_schedule=models.ValuationSchedule(effective_from = effectiveFrom, effective_at=effectiveAt),
        portfolio_entity_ids = [models.PortfolioEntityId(
                                                        scope = scope,
                                                        code = portfolio_code,
                                                        portfolio_entity_type="SinglePortfolio"
            )]
        )

# %%
aggregation = aggregation_api.get_valuation(
                                            valuation_request=aggregation_interval_request(
                                                start_date.isoformat(),
                                                end_date.isoformat())
            )
pd.DataFrame(aggregation.data)
# Out:
#       Analytic/default/ValuationDate  Sum(Valuation/PvInPortfolioCcy)
# 0  2020-08-24T00:00:00.0000000+00:00                 1,915,179,511.24
# 1  2020-08-25T00:00:00.0000000+00:00                 1,895,623,263.62
# 2  2020-08-26T00:00:00.0000000+00:00                 1,904,370,976.30
# 3  2020-08-27T00:00:00.0000000+00:00                 1,891,959,702.80
# 4  2020-08-28T00:00:00.0000000+00:00                 1,882,314,481.03

# %% [markdown]
# ### 2.3 Multi-day ranges
#
# Given the new function now holds data across the selected period, we can also apply other types of specifications in the aggregation metrics. For example, we can see the min/max range for the valuation of each holding in the selected time period. This can illustrate how a stock's volatility can drift the exposure of the portfolio, which can be notable for longer periods.

# %%
def aggregation_interval_request(effectiveFrom, effectiveAt):
    return models.ValuationRequest( 
        recipe_id = models.ResourceId(
            scope = recipe_scope,
            code = recipe_code
        ),
        metrics = [
            models.AggregateSpec("Instrument/default/Name", "Value"),
            models.AggregateSpec("Valuation/PvInReportCcy", "Min"),
            models.AggregateSpec("Valuation/PvInReportCcy", "Max"),
        ],
        group_by=["Instrument/default/Name"],
        # choose the valuation interval for the request - set using effectiveFrom and effectiveAt
        valuation_schedule=models.ValuationSchedule(effective_from = effectiveFrom, effective_at=effectiveAt),
        portfolio_entity_ids = [models.PortfolioEntityId(
                                                        scope = scope,
                                                        code = portfolio_code,
                                                        portfolio_entity_type="SinglePortfolio" 
            )]
        )

aggregation_api = api_factory.build(lusid.AggregationApi)
aggregation = aggregation_api.get_valuation(
                                            valuation_request=aggregation_interval_request(
                                                start_date.isoformat(),
                                                end_date.isoformat())
            )
pd.DataFrame(aggregation.data)
# Out:
#              Instrument/default/Name  Min(Valuation/PvInReportCcy)  \
# 0                GLAXOSMITHKLINE PLC                239,936,000.00
# 1                        PEARSON PLC                168,379,400.00
# 2                     KINGFISHER PLC                 97,308,000.00
# 3                 VODAFONE GROUP PLC                 55,720,000.00
# 4               RENTOKIL INITIAL PLC                 44,239,000.00
# 5                     PRUDENTIAL PLC                101,915,000.00
# 6                  JUST EAT TAKEAWAY                 61,422,200.00
# 7                          TESCO PLC                 29,087,100.00
# 8                 BURBERRY GROUP PLC                200,700,500.00
# 9                             BP PLC                 16,908,800.00
# 10                 NATIONAL GRID PLC                 73,358,400.00
# 11      ASSOCIATED BRITISH FOODS PLC                104,193,000.00
# 12                     WHITBREAD PLC                 85,320,000.00
# 13          LLOYDS BANKING GROUP PLC                162,150,000.00
# 14                   BAE SYSTEMS PLC                 42,087,600.00
# 15          BARRATT DEVELOPMENTS PLC                 29,058,600.00
# 16           CRODA INTERNATIONAL PLC                 20,650,000.00
# 17                ANGLO AMERICAN PLC                189,399,000.00
# 18         LAND SECURITIES GROUP PLC                 29,796,000.00
# 19                      UNILEVER PLC                133,800,000.00
# 20  American International Group Inc                     15,927.45
# 21            AmerisourceBergen Corp                     41,320.89
# 22      Bristol-Myers Squibb Company                     21,625.06
# 23                     Pinterest Inc                      5,066.60
# 24                          Nike Inc                     21,527.28
# 25            Harmony Gold Mining Co                      1,354.86
# 26     Zoom Video Communications Inc                     21,735.56
# 27             Spotify Technology SA                     31,084.52
# 28                         Aflac Inc                     18,708.69
# 29                        Diageo PLC                     37,244.90
# 30                     Carnival Corp                      4,828.48
# 31             Uber Technologies Inc                      1,195.04
# 32                     Allstate Corp                     54,855.45
# 33                       Apache Corp                      9,454.72
# 34               American Tower Corp                    151,191.04
# 35                               GBP                -21,851,056.00
# 36                               USD                   -407,025.00
#
#     Max(Valuation/PvInReportCcy)
# 0                 247,955,600.00
# 1                 176,386,000.00
# 2                 101,232,000.00
# 3                  58,480,000.00
# 4                  44,952,800.00
# 5                 104,082,500.00
# 6                  64,313,000.00
# 7                  30,191,000.00
# 8                 207,493,000.00
# 9                  18,048,000.00
# 10                 77,221,200.00
# 11                104,958,000.00
# 12                 91,044,000.00
# 13                164,450,000.00
# 14                 43,869,600.00
# 15                 29,982,000.00
# 16                 21,133,000.00
# 17                200,172,000.00
# 18                 30,274,400.00
# 19                137,430,000.00
# 20                     16,828.56
# 21                     43,716.91
# 22                     22,784.89
# 23                      5,587.38
# 24                     22,445.10
# 25                      1,412.52
# 26                     23,869.08
# 27                     33,049.22
# 28                     19,417.32
# 29                     38,394.40
# 30                      5,222.88
# 31                      1,328.40
# 32                     57,183.97
# 33                     10,052.10
# 34                    160,684.56
# 35                -21,851,056.00
# 36                   -386,925.00

# %% [markdown]
# ## 3. A2B Report

# %% [markdown]
# For breaking down the profit and loss occurred in a given period, LUSID offers an A2B report, see [here](https://www.lusid.com/docs/api#operation/GetA2BData) for documentation.
#
# The AtoB report will give a breakdown of each holding's P&L, including the flows (transactions) that have occurred in the selected time window as well as totals at the start and end of the window. Within the report you will find the following details:
#
#  - **Market Value (Start)**: The market value at the start of the window in the portfolio base currency (GBP).
#  - **Gains**: Capital Gain, Gain due to asset appreciation based on available market data and the Currency Gain from the FX rates.
#  - **Flows**: Any transaction activity occurring in the period.
#
# Note, the following table has been filtered down to some core fields.

# %%
# Request A2B Movements report
a2b = transaction_portfolios_api.get_a2_b_data(
    scope=scope,
    code=portfolio_code,
    from_effective_at=start_date,
    to_effective_at=end_date,
    recipe_id_scope=recipe_scope,
    recipe_id_code=recipe_code,
    property_keys=["Instrument/default/Name"]
)

# %%
# Rename A2B columns in df
rename_cols = {
    "portfolio_id.scope": "Portfolio Scope",
    "portfolio_id.code": "Portfolio Code",
    "holding_type": "Holding Type",
    "instrument_uid": "Instrument ID",
    "Name(default-Properties)": "Instrument Name",
    "start.holding_currency.currency": "Holding Currency",
    "start.portfolio_currency.total": "Market Value (Start)",
    "start.portfolio_currency.components.MarketGain": "P&L - Since inception (Start)",
    "start.portfolio_currency.components.CurrencyGain": "Currency Gain - Since inception (Start)",
    "gains.portfolio_currency.total":"P&L (Window)",
    "gains.portfolio_currency.components.DeltaMarketGain": "Market Gain (Window)",
    "gains.portfolio_currency.components.DeltaCurrencyGain": "Currency Gain (Window) ",
    "end.portfolio_currency.total": "Market Value (End)",
    "end.portfolio_currency.components.MarketGain": "P&L - Since inception (End)",
    "end.portfolio_currency.components.CurrencyGain": "Currency Gain - Since inception (End)"
}

# Format and filter A2B
a2b_df = lusid_response_to_data_frame(a2b, rename_properties=True)
col_filters = rename_cols.keys()
a2b_df = a2b_df[col_filters].copy()
a2b_df.rename(columns=rename_cols, inplace=True)
a2b_df
# Out:
#      Portfolio Scope   Portfolio Code Holding Type  Instrument ID  \
# 0   simple-valuation  global-equities            B        CCY_GBP
# 1   simple-valuation  global-equities            B        CCY_USD
# 2   simple-valuation  global-equities            P  LUID_00003DAS
# 3   simple-valuation  global-equities            P  LUID_00003DAT
# 4   simple-valuation  global-equities            P  LUID_00003DAU
# 5   simple-valuation  global-equities            P  LUID_00003DAV
# 6   simple-valuation  global-equities            P  LUID_00003DAW
# 7   simple-valuation  global-equities            P  LUID_00003DAX
# 8   simple-valuation  global-equities            P  LUID_00003DAZ
# 9   simple-valuation  global-equities            P  LUID_00003DB0
# 10  simple-valuation  global-equities            P  LUID_00003DB1
# 11  simple-valuation  global-equities            P  LUID_00003DB2
# 12  simple-valuation  global-equities            P  LUID_00003DB3
# 13  simple-valuation  global-equities            P  LUID_00003DB4
# 14  simple-valuation  global-equities            P  LUID_00003DB5
# 15  simple-valuation  global-equities            P  LUID_00003DB6
# 16  simple-valuation  global-equities            P  LUID_00003DB7
# 17  simple-valuation  global-equities            P  LUID_00003DEK
# 18  simple-valuation  global-equities            P  LUID_00003DEL
# 19  simple-valuation  global-equities            P  LUID_00003DEN
# 20  simple-valuation  global-equities            P  LUID_00003DEO
# 21  simple-valuation  global-equities            P  LUID_00003DEU
# 22  simple-valuation  global-equities            P  LUID_00003DEX
# 23  simple-valuation  global-equities            P  LUID_00003DF5
# 24  simple-valuation  global-equities            P  LUID_00003DF7
# 25  simple-valuation  global-equities            P  LUID_00003DFD
# 26  simple-valuation  global-equities            P  LUID_00003DFG
# 27  simple-valuation  global-equities            P  LUID_00003DFJ
# 28  simple-valuation  global-equities            P  LUID_00003DFU
# 29  simple-valuation  global-equities            P  LUID_00003DG1
# 30  simple-valuation  global-equities            P  LUID_00003DG2
# 31  simple-valuation  global-equities            P  LUID_00003DGE
# 32  simple-valuation  global-equities            P  LUID_00003DGF
# 33  simple-valuation  global-equities            P  LUID_00003DGK
# 34  simple-valuation  global-equities            P  LUID_00003DGX
# 35  simple-valuation  global-equities            P  LUID_00003DH4
# 36  simple-valuation  global-equities            P  LUID_00003DH6
#
#                      Instrument Name Holding Currency  Market Value (Start)  \
# 0                                GBP              GBP        -21,851,056.00
# 1                                USD              USD           -386,925.00
# 2                          Aflac Inc              USD             18,708.69
# 3             Harmony Gold Mining Co              USD              1,367.52
# 4                American Tower Corp              USD            151,191.04
# 5              Spotify Technology SA              USD             31,084.52
# 6                      Carnival Corp              USD              4,971.12
# 7                         Diageo PLC              USD             37,244.90
# 8                           Nike Inc              USD             21,527.28
# 9                        Apache Corp              USD              9,464.07
# 10                     Allstate Corp              USD             54,862.50
# 11  American International Group Inc              USD             15,927.45
# 12            AmerisourceBergen Corp              USD             41,320.89
# 13      Bristol-Myers Squibb Company              USD             21,625.06
# 14                     Pinterest Inc              USD              5,066.60
# 15     Zoom Video Communications Inc              USD             21,735.56
# 16             Uber Technologies Inc              USD              1,195.04
# 17               GLAXOSMITHKLINE PLC              GBP        247,955,600.00
# 18                         TESCO PLC              GBP         30,191,000.00
# 19                      UNILEVER PLC              GBP        137,430,000.00
# 20          BARRATT DEVELOPMENTS PLC              GBP         29,982,000.00
# 21                ANGLO AMERICAN PLC              GBP        200,172,000.00
# 22                    KINGFISHER PLC              GBP         98,640,000.00
# 23                 NATIONAL GRID PLC              GBP         77,221,200.00
# 24                     WHITBREAD PLC              GBP         85,320,000.00
# 25          LLOYDS BANKING GROUP PLC              GBP        164,450,000.00
# 26                BURBERRY GROUP PLC              GBP        200,700,500.00
# 27      ASSOCIATED BRITISH FOODS PLC              GBP        104,193,000.00
# 28              RENTOKIL INITIAL PLC              GBP         44,753,600.00
# 29           CRODA INTERNATIONAL PLC              GBP         20,965,000.00
# 30         LAND SECURITIES GROUP PLC              GBP         29,827,200.00
# 31                   BAE SYSTEMS PLC              GBP         43,869,600.00
# 32                       PEARSON PLC              GBP        176,386,000.00
# 33                            BP PLC              GBP         18,048,000.00
# 34                VODAFONE GROUP PLC              GBP         58,480,000.00
# 35                 JUST EAT TAKEAWAY              GBP         64,313,000.00
# 36                    PRUDENTIAL PLC              GBP        104,082,500.00
#
#     P&L - Since inception (Start)  Currency Gain - Since inception (Start)  \
# 0                             NaN                                      NaN
# 1                             NaN                                 7,537.50
# 2                        8,698.69                                  -195.00
# 3                      -10,182.48                                  -225.00
# 4                       89,591.04                                -1,200.00
# 5                        7,984.52                                  -450.00
# 6                      -10,428.88                                  -300.00
# 7                       -3,180.10                                  -787.50
# 8                       -7,347.72                                  -562.50
# 9                      -23,260.93                                  -637.50
# 10                      25,987.50                                  -562.50
# 11                       7,842.45                                  -157.50
# 12                       7,440.89                                  -660.00
# 13                     -30,349.94                                -1,012.50
# 14                     -10,333.40                                  -300.00
# 15                      -1,364.44                                  -450.00
# 16                        -729.96                                   -37.50
# 17                 245,361,800.00                                      NaN
# 18                  29,898,325.00                                      NaN
# 19                 136,032,230.00                                      NaN
# 20                  29,678,640.00                                      NaN
# 21                 198,155,300.00                                      NaN
# 22                  97,748,460.00                                      NaN
# 23                  76,428,108.00                                      NaN
# 24                  84,520,586.00                                      NaN
# 25                 162,850,880.00                                      NaN
# 26                 198,870,100.00                                      NaN
# 27                 103,289,500.00                                      NaN
# 28                  42,861,200.00                                      NaN
# 29                  20,766,066.00                                      NaN
# 30                  29,519,424.00                                      NaN
# 31                  43,470,256.00                                      NaN
# 32                 174,749,930.00                                      NaN
# 33                  16,249,800.00                                      NaN
# 34                  57,899,595.00                                      NaN
# 35                  63,680,820.00                                      NaN
# 36                 103,098,124.00                                      NaN
#
#     P&L (Window)  Market Gain (Window)  Currency Gain (Window)   \
# 0            NaN                   NaN                      NaN
# 1     -20,100.00                   NaN               -20,100.00
# 2         708.63                188.63                   520.00
# 3          29.73               -570.27                   600.00
# 4       9,493.52              6,293.52                 3,200.00
# 5       1,964.70                764.70                 1,200.00
# 6         251.76               -548.24                   800.00
# 7       1,149.50               -950.50                 2,100.00
# 8         917.82               -582.18                 1,500.00
# 9         588.03             -1,111.97                 1,700.00
# 10      2,321.47                821.47                 1,500.00
# 11        901.11                481.11                   420.00
# 12      2,396.02                636.02                 1,760.00
# 13      1,159.83             -1,540.17                 2,700.00
# 14        520.78               -279.22                   800.00
# 15      2,133.52                933.52                 1,200.00
# 16        133.36                 33.36                   100.00
# 17 -8,019,600.00         -8,019,600.00                      NaN
# 18 -1,103,900.00         -1,103,900.00                      NaN
# 19 -3,630,000.00         -3,630,000.00                      NaN
# 20    -45,600.00            -45,600.00                      NaN
# 21 -7,749,000.00         -7,749,000.00                      NaN
# 22 -1,332,000.00         -1,332,000.00                      NaN
# 23 -3,862,800.00         -3,862,800.00                      NaN
# 24  5,724,000.00          5,724,000.00                      NaN
# 25 -1,437,500.00         -1,437,500.00                      NaN
# 26  5,863,000.00          5,863,000.00                      NaN
# 27    153,000.00            153,000.00                      NaN
# 28   -514,600.00           -514,600.00                      NaN
# 29   -315,000.00           -315,000.00                      NaN
# 30    234,000.00            234,000.00                      NaN
# 31 -1,782,000.00         -1,782,000.00                      NaN
# 32 -8,006,600.00         -8,006,600.00                      NaN
# 33 -1,139,200.00         -1,139,200.00                      NaN
# 34 -2,760,000.00         -2,760,000.00                      NaN
# 35 -2,890,800.00         -2,890,800.00                      NaN
# 36   -255,000.00           -255,000.00                      NaN
#
#     Market Value (End)  P&L - Since inception (End)  \
# 0       -21,851,056.00                          NaN
# 1          -407,025.00                          NaN
# 2            19,417.32                     8,887.32
# 3             1,397.25                   -10,752.75
# 4           160,684.56                    95,884.56
# 5            33,049.22                     8,749.22
# 6             5,222.88                   -10,977.12
# 7            38,394.40                    -4,130.60
# 8            22,445.10                    -7,929.90
# 9            10,052.10                   -24,372.90
# 10           57,183.97                    26,808.97
# 11           16,828.56                     8,323.56
# 12           43,716.91                     8,076.91
# 13           22,784.89                   -31,890.11
# 14            5,587.38                   -10,612.62
# 15           23,869.08                      -430.92
# 16            1,328.40                      -696.60
# 17      239,936,000.00               237,342,200.00
# 18       29,087,100.00                28,794,425.00
# 19      133,800,000.00               132,402,230.00
# 20       29,936,400.00                29,633,040.00
# 21      192,423,000.00               190,406,300.00
# 22       97,308,000.00                96,416,460.00
# 23       73,358,400.00                72,565,308.00
# 24       91,044,000.00                90,244,586.00
# 25      163,012,500.00               161,413,380.00
# 26      206,563,500.00               204,733,100.00
# 27      104,346,000.00               103,442,500.00
# 28       44,239,000.00                42,346,600.00
# 29       20,650,000.00                20,451,066.00
# 30       30,061,200.00                29,753,424.00
# 31       42,087,600.00                41,688,256.00
# 32      168,379,400.00               166,743,330.00
# 33       16,908,800.00                15,110,600.00
# 34       55,720,000.00                55,139,595.00
# 35       61,422,200.00                60,790,020.00
# 36      103,827,500.00               102,843,124.00
#
#     Currency Gain - Since inception (End)
# 0                                     NaN
# 1                              -12,562.50
# 2                                  325.00
# 3                                  375.00
# 4                                2,000.00
# 5                                  750.00
# 6                                  500.00
# 7                                1,312.50
# 8                                  937.50
# 9                                1,062.50
# 10                                 937.50
# 11                                 262.50
# 12                               1,100.00
# 13                               1,687.50
# 14                                 500.00
# 15                                 750.00
# 16                                  62.50
# 17                                    NaN
# 18                                    NaN
# 19                                    NaN
# 20                                    NaN
# 21                                    NaN
# 22                                    NaN
# 23                                    NaN
# 24                                    NaN
# 25                                    NaN
# 26                                    NaN
# 27                                    NaN
# 28                                    NaN
# 29                                    NaN
# 30                                    NaN
# 31                                    NaN
# 32                                    NaN
# 33                                    NaN
# 34                                    NaN
# 35                                    NaN
# 36                                    NaN

# %% [markdown]
# ### 3.1 A2B Currency Gains

# %% [markdown]
# The A2B time window runs between 24th of August 2020 at 01:00 and 28th of August 2020 at 01:00. The following components are returned:

# %%
a2b_df[a2b_df["Instrument Name"] == 'USD']
# Out:
#     Portfolio Scope   Portfolio Code Holding Type Instrument ID  \
# 1  simple-valuation  global-equities            B       CCY_USD
#
#   Instrument Name Holding Currency  Market Value (Start)  \
# 1             USD              USD           -386,925.00
#
#    P&L - Since inception (Start)  Currency Gain - Since inception (Start)  \
# 1                            NaN                                 7,537.50
#
#    P&L (Window)  Market Gain (Window)  Currency Gain (Window)   \
# 1    -20,100.00                   NaN               -20,100.00
#
#    Market Value (End)  P&L - Since inception (End)  \
# 1         -407,025.00                          NaN
#
#    Currency Gain - Since inception (End)
# 1                             -12,562.50

# %% [markdown]
# This USD position is the sum of all the US stocks that were purchased in USD multiplied by the USD/GBP FX rate, since our portfolio base currency is in GBP.
#
# * **Start**:
#   * The start position is a cost of GBP -386,925.00 which is the sum of the opening transactions of USD -502,500.00 multiplied by the USD/GBP FX rate on the 24th of August 2020 at 01:00 of 0.77. Then we calculate the cost in GBP on the date of the opening transactions, 3rd of August 2020 at 01:00 multiplied by the USD/GBP FX rate at the time. We get a Currency Gain of GBP 7,537.50 due to the difference in FX rate.
#
#
# |                  |  USD Cost   |  FX rate  |      GBP      |
# |:----------------:|:-----------:|:---------:|:-------------:|
# | 24th August 2020 | -502,500.00 |   0.77    |  -386,925.00  |
# | 3rd August 2020  | -502,500.00 |   0.785   |  -394,070.00  |
#
#      -386,925.00 - -394,070.00 = 7,537.50
#
#
#
# * **Gains**:
#   *  There is a Currency Loss of GBP 20,100.00 due to the difference in FX rate from the 24th of August 2020 and the 28th August 2020.
#
# |                  |  USD Cost   | FX rate |     GBP     |
# |:----------------:|:-----------:|:-------:|:-----------:|
# | 28th August 2020 | -502,500.00 |  0.81   | -407,025.00 |
# | 24th August 2020 | -502,500.00 |  0.77   | -386,925.00 |
#
#      -407,025.00 - -386,925.00 = -20,100.00
#
#
#
#
# * **End**
#   * The end column shows a sum of all the activities for this position. GBP 7,537.50 + GBP -20,100.00 = GBP -12,562.50
