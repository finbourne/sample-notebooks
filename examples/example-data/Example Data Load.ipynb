# %%
from lusidtools.jupyter_tools import toggle_code

"""Example Data Load

Loads some example data into LUSID

Attributes
----------
transactions
cutlabels
quotes
valuation
portfolio groups

"""

toggle_code("Toggle Docstring")
# Out:
#     <form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Toggle Docstring"></form>
#
#          <script>
#          function code_toggle() {
#              if ($('div.cell.code_cell.rendered.selected div.input').css('display')!='none'){
#                  $('div.cell.code_cell.rendered.selected div.input').hide();
#              } else {
#                  $('div.cell.code_cell.rendered.selected div.input').show();
#              }
#          }
#          </script>

# %% [markdown]
# # Example Data Load

# %%
## Importing required packages
import os
import pandas as pd
import datetime
from datetime import timezone
import pytz
import requests.exceptions

import lusid
import lusid.models as models
from lusidjam.refreshing_token import RefreshingToken
import fbnsdkutilities.utilities as utils

pd.set_option("display.max_columns", None)

# Authenticate our user and create our API client
secrets_path = os.getenv("FBN_SECRETS_PATH")

# Initiate an API Factory which is the client side object for interacting with LUSID APIs
api_factory = utils.ApiClientFactory(
    lusid,
    token=RefreshingToken(),
    api_secrets_filename=secrets_path,
    app_name="LusidJupyterNotebook",
)

# %%
# construct the API we want to use
cut_label_definitions_api = api_factory.build(lusid.api.CutLabelDefinitionsApi)
portfolios_api = api_factory.build(lusid.api.PortfoliosApi)
transaction_portfolios_api = api_factory.build(lusid.api.TransactionPortfoliosApi)
quotes_api = api_factory.build(lusid.api.QuotesApi)
configuration_recipe_api = api_factory.build(lusid.api.ConfigurationRecipeApi)
portfolio_groups_api = api_factory.build(lusid.api.PortfolioGroupsApi)
instruments_api = api_factory.build(lusid.api.InstrumentsApi)
valuations_api = api_factory.build(lusid.api.AggregationApi)

# %%
scope = "Finbourne-Examples"
market_data_scope = "FinbourneMarketData"

datafile = "ExampleData.xlsx"
date = datetime.datetime(2021, 1, 1, 0, 0, 0, 0, tzinfo=timezone.utc)

# %%
## Loading Data
portfolios = pd.read_excel(datafile,sheet_name = 'Portfolios')
holdings = pd.read_excel(datafile,sheet_name = 'Holdings')
transactions = pd.read_excel(datafile,sheet_name = 'Transactions')
instruments = pd.read_excel(datafile,sheet_name = 'Instruments')
quotes = pd.read_excel(datafile,sheet_name = 'Quotes').fillna('')
rates = pd.read_excel(datafile,sheet_name = 'Rates').fillna('')
recipes = pd.read_excel(datafile,sheet_name = 'Recipes')
groups = pd.read_excel(datafile,sheet_name = 'Groups')
# Out:
# /opt/conda/lib/python3.10/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)

# %% [markdown]
# ### Creating CutLabels

# %%
cut_labels = [["LDN_Open","LondonOpen","London Market Open Time", models.CutLocalTime(8, 0), "Europe/London"],
             ["LDN_Close","LondonClose","London Market Close Time", models.CutLocalTime(16, 30), "Europe/London"],
             ["NY_Close","NewYorkClose","New York Market Close Time", models.CutLocalTime(16, 00), "America/New_York"],
             ["NY_Open","NewYorkOpen","New York Market Open Time", models.CutLocalTime(9, 30), "America/New_York"]]

def create_cut_label(cut_label, overwrite=True):
    '''
    Input: 
        cut_label (list): ordered list where 
                            [0] == code (str), 
                            [1] == display_name (str), 
                            [2] == description (str), 
                            [3] == cut_local_time (models.cutLabelTime),
                            [4] == time_zone (str)
        overwrite (bool): whether to overwrite existing cutlabel in the provided code if it exists, defaults to True
    Output:
        resp (lusid.models.cut_label_definition.CutLabelDefinition): Cut Label definition of the created cut label
    '''

    cut_label_req = models.CreateCutLabelDefinitionRequest(code=cut_label[0],
                                                     display_name=cut_label[1],
                                                     description=cut_label[2],
                                                     cut_local_time=cut_label[3],
                                                     time_zone=cut_label[4])
    
    ## Try creating cutLabel, throws exception if already exists
    try:
        cut_label_definitions_api.create_cut_label_definition(create_cut_label_definition_request=cut_label_req)
    except:
        if overwrite:
            resp = cut_label_definitions_api.delete_cut_label_definition(code=cut_label[0])
            cut_label_definitions_api.create_cut_label_definition(create_cut_label_definition_request=cut_label_req)
            
    return cut_label_definitions_api.get_cut_label_definition(code=cut_label[0])

created_cut_labels = [create_cut_label(c) 
                      for c in cut_labels]
        
created_cut_labels
# Out:
# [{'code': 'LDN_Open',
#   'cut_local_time': {'hours': 8, 'minutes': 0},
#   'description': 'London Market Open Time',
#   'display_name': 'LondonOpen',
#   'href': None,
#   'links': [{'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/entities/CutLabelDefinition',
#              'method': 'GET',
#              'relation': 'EntitySchema'},
#             {'description': 'A link to the LUSID Insights website showing all '
#                             'logs related to this request',
#              'href': 'http://fbn-ci.lusid.com/app/insights/logs/0HMQGGAL4G36Q:0000007F',
#              'method': 'GET',
#              'relation': 'RequestLogs'}],
#   'time_zone': 'Europe/London'},
#  {'code': 'LDN_Close',
#   'cut_local_time': {'hours': 16, 'minutes': 30},
#   'description': 'London Market Close Time',
#   'display_name': 'LondonClose',
#   'href': None,
#   'links': [{'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/entities/CutLabelDefinition',
#              'method': 'GET',
#              'relation': 'EntitySchema'},
#             {'description': 'A link to the LUSID Insights website showing all '
#                             'logs related to this request',
#              'href': 'http://fbn-ci.lusid.com/app/insights/logs/0HMQGGAL4G36Q:00000083',
#              'method': 'GET',
#              'relation': 'RequestLogs'}],
#   'time_zone': 'Europe/London'},
#  {'code': 'NY_Close',
#   'cut_local_time': {'hours': 16, 'minutes': 0},
#   'description': 'New York Market Close Time',
#   'display_name': 'NewYorkClose',
#   'href': None,
#   'links': [{'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/entities/CutLabelDefinition',
#              'method': 'GET',
#              'relation': 'EntitySchema'},
#             {'description': 'A link to the LUSID Insights website showing all '
#                             'logs related to this request',
#              'href': 'http://fbn-ci.lusid.com/app/insights/logs/0HMQGGAL4G30V:00000151',
#              'method': 'GET',
#              'relation': 'RequestLogs'}],
#   'time_zone': 'America/New_York'},
#  {'code': 'NY_Open',
#   'cut_local_time': {'hours': 9, 'minutes': 30},
#   'description': 'New York Market Open Time',
#   'display_name': 'NewYorkOpen',
#   'href': None,
#   'links': [{'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/entities/CutLabelDefinition',
#              'method': 'GET',
#              'relation': 'EntitySchema'},
#             {'description': 'A link to the LUSID Insights website showing all '
#                             'logs related to this request',
#              'href': 'http://fbn-ci.lusid.com/app/insights/logs/0HMQGGAL4G30V:00000153',
#              'method': 'GET',
#              'relation': 'RequestLogs'}],
#   'time_zone': 'America/New_York'}]

# %% [markdown]
# ### Creating Instruments

# %%
def create_instrument(instrument, overwrite=True):
    '''
    Input: 
        instrument (dict): dictionary with fields 
                            'name' == name of the instrument (str), 
                            'Figi' == Figi identifier (str), 
                            'P:Instrument/default/Currency' == default currency (str)
        overwrite (bool): whether to overwrite existing instrument (hard-delete) in the provided code if it exists, defaults to True
    Output:
        resp (lusid.models.instrument.Instrument): Instrument that was created
    '''
    ## Checks if Instrument already exist
    try:
        # Check if Instrument with FIGI already exist
        resp = instruments_api.get_instrument("Figi",instrument['Figi'])
        if overwrite:
            resp = instruments_api.delete_instruments(request_body = [resp.lusid_instrument_id],delete_mode = 'Hard')
        else:
            return resp

    except:
        pass

    instrument_req = {"inst":models.InstrumentDefinition(
                                    name=instrument["name"],
                                    identifiers={"Figi":models.InstrumentIdValue(value = instrument['Figi'])},
                                    properties=[lusid.ModelProperty(key="Instrument/default/Currency",
                                                                    value=lusid.PropertyValue(label_value=instrument['P:Instrument/default/Currency'])
                                                                   )
                                               ]
                                    )
                    }
    instruments_api.upsert_instruments(request_body=instrument_req)
    return instruments_api.get_instrument("Figi",instrument['Figi'],property_keys=['Instrument/default/Currency'])

created_instruments = [create_instrument(inst.to_dict()) 
                       for i,inst in instruments.iterrows()]
    
created_instruments
# Out:
# [{'asset_class': 'Unknown',
#   'dom_ccy': 'ZZZ',
#   'href': 'https://fbn-ci.lusid.com/api/api/instruments/LusidInstrumentId/LUID_00070D4R?scope=default',
#   'identifiers': {'Figi': 'BBG000B9XRY4', 'LusidInstrumentId': 'LUID_00070D4R'},
#   'instrument_definition': None,
#   'links': [{'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/entities/Instrument',
#              'method': 'GET',
#              'relation': 'EntitySchema'},
#             {'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/properties?propertyKeys=Instrument%2Fdefault%2FCurrency',
#              'method': 'GET',
#              'relation': 'PropertySchema'},
#             {'description': 'A link to the LUSID Insights website showing all '
#                             'logs related to this request',
#              'href': 'http://fbn-ci.lusid.com/app/insights/logs/0HMQGGAL4G30V:00000156',
#              'method': 'GET',
#              'relation': 'RequestLogs'}],
#   'lookthrough_portfolio': None,
#   'lusid_instrument_id': 'LUID_00070D4R',
#   'name': 'Apple',
#   'properties': [],
#   'relationships': [],
#   'scope': 'default',
#   'state': 'Active',
#   'version': {'as_at_created': datetime.datetime(2023, 5, 9, 12, 53, 29, 14545, tzinfo=tzlocal()),
#               'as_at_date': datetime.datetime(2023, 5, 9, 12, 53, 29, 14545, tzinfo=tzlocal()),
#               'as_at_modified': datetime.datetime(2023, 5, 9, 12, 53, 29, 14545, tzinfo=tzlocal()),
#               'as_at_version_number': 1,
#               'effective_from': datetime.datetime(1, 1, 1, 0, 0, tzinfo=tzlocal()),
#               'user_id_created': '00u4edvny74dXgwzK2p7',
#               'user_id_modified': '00u4edvny74dXgwzK2p7'}},
#  {'asset_class': 'Unknown',
#   'dom_ccy': 'ZZZ',
#   'href': 'https://fbn-ci.lusid.com/api/api/instruments/LusidInstrumentId/LUID_00070D4S?scope=default',
#   'identifiers': {'Figi': 'BBG000DMBXR2', 'LusidInstrumentId': 'LUID_00070D4S'},
#   'instrument_definition': None,
#   'links': [{'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/entities/Instrument',
#              'method': 'GET',
#              'relation': 'EntitySchema'},
#             {'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/properties?propertyKeys=Instrument%2Fdefault%2FCurrency',
#              'method': 'GET',
#              'relation': 'PropertySchema'},
#             {'description': 'A link to the LUSID Insights website showing all '
#                             'logs related to this request',
#              'href': 'http://fbn-ci.lusid.com/app/insights/logs/0HMQGGAL4G36Q:00000086',
#              'method': 'GET',
#              'relation': 'RequestLogs'}],
#   'lookthrough_portfolio': None,
#   'lusid_instrument_id': 'LUID_00070D4S',
#   'name': 'JPMorgan Chase',
#   'properties': [],
#   'relationships': [],
#   'scope': 'default',
#   'state': 'Active',
#   'version': {'as_at_created': datetime.datetime(2023, 5, 9, 12, 53, 30, 168048, tzinfo=tzlocal()),
#               'as_at_date': datetime.datetime(2023, 5, 9, 12, 53, 30, 168048, tzinfo=tzlocal()),
#               'as_at_modified': datetime.datetime(2023, 5, 9, 12, 53, 30, 168048, tzinfo=tzlocal()),
#               'as_at_version_number': 1,
#               'effective_from': datetime.datetime(1, 1, 1, 0, 0, tzinfo=tzlocal()),
#               'user_id_created': '00u4edvny74dXgwzK2p7',
#               'user_id_modified': '00u4edvny74dXgwzK2p7'}},
#  {'asset_class': 'Unknown',
#   'dom_ccy': 'ZZZ',
#   'href': 'https://fbn-ci.lusid.com/api/api/instruments/LusidInstrumentId/LUID_00070D4T?scope=default',
#   'identifiers': {'Figi': 'BBG000C059M6', 'LusidInstrumentId': 'LUID_00070D4T'},
#   'instrument_definition': None,
#   'links': [{'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/entities/Instrument',
#              'method': 'GET',
#              'relation': 'EntitySchema'},
#             {'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/properties?propertyKeys=Instrument%2Fdefault%2FCurrency',
#              'method': 'GET',
#              'relation': 'PropertySchema'},
#             {'description': 'A link to the LUSID Insights website showing all '
#                             'logs related to this request',
#              'href': 'http://fbn-ci.lusid.com/app/insights/logs/0HMQGGAL4G36Q:00000089',
#              'method': 'GET',
#              'relation': 'RequestLogs'}],
#   'lookthrough_portfolio': None,
#   'lusid_instrument_id': 'LUID_00070D4T',
#   'name': 'BP',
#   'properties': [],
#   'relationships': [],
#   'scope': 'default',
#   'state': 'Active',
#   'version': {'as_at_created': datetime.datetime(2023, 5, 9, 12, 53, 31, 255182, tzinfo=tzlocal()),
#               'as_at_date': datetime.datetime(2023, 5, 9, 12, 53, 31, 255182, tzinfo=tzlocal()),
#               'as_at_modified': datetime.datetime(2023, 5, 9, 12, 53, 31, 255182, tzinfo=tzlocal()),
#               'as_at_version_number': 1,
#               'effective_from': datetime.datetime(1, 1, 1, 0, 0, tzinfo=tzlocal()),
#               'user_id_created': '00u4edvny74dXgwzK2p7',
#               'user_id_modified': '00u4edvny74dXgwzK2p7'}},
#  {'asset_class': 'Unknown',
#   'dom_ccy': 'ZZZ',
#   'href': 'https://fbn-ci.lusid.com/api/api/instruments/LusidInstrumentId/LUID_00070D4U?scope=default',
#   'identifiers': {'Figi': 'BBG00DQ4YZ36', 'LusidInstrumentId': 'LUID_00070D4U'},
#   'instrument_definition': None,
#   'links': [{'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/entities/Instrument',
#              'method': 'GET',
#              'relation': 'EntitySchema'},
#             {'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/properties?propertyKeys=Instrument%2Fdefault%2FCurrency',
#              'method': 'GET',
#              'relation': 'PropertySchema'},
#             {'description': 'A link to the LUSID Insights website showing all '
#                             'logs related to this request',
#              'href': 'http://fbn-ci.lusid.com/app/insights/logs/0HMQGGAL4G30V:0000015C',
#              'method': 'GET',
#              'relation': 'RequestLogs'}],
#   'lookthrough_portfolio': None,
#   'lusid_instrument_id': 'LUID_00070D4U',
#   'name': 'Anheuser-Busch InBev',
#   'properties': [],
#   'relationships': [],
#   'scope': 'default',
#   'state': 'Active',
#   'version': {'as_at_created': datetime.datetime(2023, 5, 9, 12, 53, 32, 397483, tzinfo=tzlocal()),
#               'as_at_date': datetime.datetime(2023, 5, 9, 12, 53, 32, 397483, tzinfo=tzlocal()),
#               'as_at_modified': datetime.datetime(2023, 5, 9, 12, 53, 32, 397483, tzinfo=tzlocal()),
#               'as_at_version_number': 1,
#               'effective_from': datetime.datetime(1, 1, 1, 0, 0, tzinfo=tzlocal()),
#               'user_id_created': '00u4edvny74dXgwzK2p7',
#               'user_id_modified': '00u4edvny74dXgwzK2p7'}},
#  {'asset_class': 'Unknown',
#   'dom_ccy': 'ZZZ',
#   'href': 'https://fbn-ci.lusid.com/api/api/instruments/LusidInstrumentId/LUID_00070D4V?scope=default',
#   'identifiers': {'Figi': 'BBG000BCM915', 'LusidInstrumentId': 'LUID_00070D4V'},
#   'instrument_definition': None,
#   'links': [{'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/entities/Instrument',
#              'method': 'GET',
#              'relation': 'EntitySchema'},
#             {'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/properties?propertyKeys=Instrument%2Fdefault%2FCurrency',
#              'method': 'GET',
#              'relation': 'PropertySchema'},
#             {'description': 'A link to the LUSID Insights website showing all '
#                             'logs related to this request',
#              'href': 'http://fbn-ci.lusid.com/app/insights/logs/0HMQGGAL4G34J:000000B2',
#              'method': 'GET',
#              'relation': 'RequestLogs'}],
#   'lookthrough_portfolio': None,
#   'lusid_instrument_id': 'LUID_00070D4V',
#   'name': 'Toyota Motor',
#   'properties': [],
#   'relationships': [],
#   'scope': 'default',
#   'state': 'Active',
#   'version': {'as_at_created': datetime.datetime(2023, 5, 9, 12, 53, 33, 619803, tzinfo=tzlocal()),
#               'as_at_date': datetime.datetime(2023, 5, 9, 12, 53, 33, 671484, tzinfo=tzlocal()),
#               'as_at_modified': datetime.datetime(2023, 5, 9, 12, 53, 33, 619803, tzinfo=tzlocal()),
#               'as_at_version_number': 1,
#               'effective_from': datetime.datetime(1, 1, 1, 0, 0, tzinfo=tzlocal()),
#               'user_id_created': '00u4edvny74dXgwzK2p7',
#               'user_id_modified': '00u4edvny74dXgwzK2p7'}},
#  {'asset_class': 'Unknown',
#   'dom_ccy': 'ZZZ',
#   'href': 'https://fbn-ci.lusid.com/api/api/instruments/LusidInstrumentId/LUID_00070D4W?scope=default',
#   'identifiers': {'Figi': 'BBG000BCH458', 'LusidInstrumentId': 'LUID_00070D4W'},
#   'instrument_definition': None,
#   'links': [{'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/entities/Instrument',
#              'method': 'GET',
#              'relation': 'EntitySchema'},
#             {'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/properties?propertyKeys=Instrument%2Fdefault%2FCurrency',
#              'method': 'GET',
#              'relation': 'PropertySchema'},
#             {'description': 'A link to the LUSID Insights website showing all '
#                             'logs related to this request',
#              'href': 'http://fbn-ci.lusid.com/app/insights/logs/0HMQGGAL4G30V:00000163',
#              'method': 'GET',
#              'relation': 'RequestLogs'}],
#   'lookthrough_portfolio': None,
#   'lusid_instrument_id': 'LUID_00070D4W',
#   'name': 'Volkswagen',
#   'properties': [],
#   'relationships': [],
#   'scope': 'default',
#   'state': 'Active',
#   'version': {'as_at_created': datetime.datetime(2023, 5, 9, 12, 53, 34, 980871, tzinfo=tzlocal()),
#               'as_at_date': datetime.datetime(2023, 5, 9, 12, 53, 35, 355690, tzinfo=tzlocal()),
#               'as_at_modified': datetime.datetime(2023, 5, 9, 12, 53, 34, 980871, tzinfo=tzlocal()),
#               'as_at_version_number': 1,
#               'effective_from': datetime.datetime(1, 1, 1, 0, 0, tzinfo=tzlocal()),
#               'user_id_created': '00u4edvny74dXgwzK2p7',
#               'user_id_modified': '00u4edvny74dXgwzK2p7'}},
#  {'asset_class': 'Unknown',
#   'dom_ccy': 'ZZZ',
#   'href': 'https://fbn-ci.lusid.com/api/api/instruments/LusidInstrumentId/LUID_00070D4X?scope=default',
#   'identifiers': {'Figi': 'BBG000BS1MT4', 'LusidInstrumentId': 'LUID_00070D4X'},
#   'instrument_definition': None,
#   'links': [{'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/entities/Instrument',
#              'method': 'GET',
#              'relation': 'EntitySchema'},
#             {'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/properties?propertyKeys=Instrument%2Fdefault%2FCurrency',
#              'method': 'GET',
#              'relation': 'PropertySchema'},
#             {'description': 'A link to the LUSID Insights website showing all '
#                             'logs related to this request',
#              'href': 'http://fbn-ci.lusid.com/app/insights/logs/0HMQGGAL4G30V:00000166',
#              'method': 'GET',
#              'relation': 'RequestLogs'}],
#   'lookthrough_portfolio': None,
#   'lusid_instrument_id': 'LUID_00070D4X',
#   'name': 'HSBC Holdings',
#   'properties': [],
#   'relationships': [],
#   'scope': 'default',
#   'state': 'Active',
#   'version': {'as_at_created': datetime.datetime(2023, 5, 9, 12, 53, 36, 360916, tzinfo=tzlocal()),
#               'as_at_date': datetime.datetime(2023, 5, 9, 12, 53, 36, 360916, tzinfo=tzlocal()),
#               'as_at_modified': datetime.datetime(2023, 5, 9, 12, 53, 36, 360916, tzinfo=tzlocal()),
#               'as_at_version_number': 1,
#               'effective_from': datetime.datetime(1, 1, 1, 0, 0, tzinfo=tzlocal()),
#               'user_id_created': '00u4edvny74dXgwzK2p7',
#               'user_id_modified': '00u4edvny74dXgwzK2p7'}},
#  {'asset_class': 'Unknown',
#   'dom_ccy': 'ZZZ',
#   'href': 'https://fbn-ci.lusid.com/api/api/instruments/LusidInstrumentId/LUID_00070D4Y?scope=default',
#   'identifiers': {'Figi': 'BBG000BH4R78', 'LusidInstrumentId': 'LUID_00070D4Y'},
#   'instrument_definition': None,
#   'links': [{'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/entities/Instrument',
#              'method': 'GET',
#              'relation': 'EntitySchema'},
#             {'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/properties?propertyKeys=Instrument%2Fdefault%2FCurrency',
#              'method': 'GET',
#              'relation': 'PropertySchema'},
#             {'description': 'A link to the LUSID Insights website showing all '
#                             'logs related to this request',
#              'href': 'http://fbn-ci.lusid.com/app/insights/logs/0HMQGGAL4G36Q:0000008D',
#              'method': 'GET',
#              'relation': 'RequestLogs'}],
#   'lookthrough_portfolio': None,
#   'lusid_instrument_id': 'LUID_00070D4Y',
#   'name': 'Walt Disney',
#   'properties': [],
#   'relationships': [],
#   'scope': 'default',
#   'state': 'Active',
#   'version': {'as_at_created': datetime.datetime(2023, 5, 9, 12, 53, 37, 418959, tzinfo=tzlocal()),
#               'as_at_date': datetime.datetime(2023, 5, 9, 12, 53, 37, 418959, tzinfo=tzlocal()),
#               'as_at_modified': datetime.datetime(2023, 5, 9, 12, 53, 37, 418959, tzinfo=tzlocal()),
#               'as_at_version_number': 1,
#               'effective_from': datetime.datetime(1, 1, 1, 0, 0, tzinfo=tzlocal()),
#               'user_id_created': '00u4edvny74dXgwzK2p7',
#               'user_id_modified': '00u4edvny74dXgwzK2p7'}},
#  {'asset_class': 'Unknown',
#   'dom_ccy': 'ZZZ',
#   'href': 'https://fbn-ci.lusid.com/api/api/instruments/LusidInstrumentId/LUID_00070D4Z?scope=default',
#   'identifiers': {'Figi': 'BBG000BPH459', 'LusidInstrumentId': 'LUID_00070D4Z'},
#   'instrument_definition': None,
#   'links': [{'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/entities/Instrument',
#              'method': 'GET',
#              'relation': 'EntitySchema'},
#             {'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/properties?propertyKeys=Instrument%2Fdefault%2FCurrency',
#              'method': 'GET',
#              'relation': 'PropertySchema'},
#             {'description': 'A link to the LUSID Insights website showing all '
#                             'logs related to this request',
#              'href': 'http://fbn-ci.lusid.com/app/insights/logs/0HMQGGAL4G383:00000003',
#              'method': 'GET',
#              'relation': 'RequestLogs'}],
#   'lookthrough_portfolio': None,
#   'lusid_instrument_id': 'LUID_00070D4Z',
#   'name': 'Microsoft',
#   'properties': [],
#   'relationships': [],
#   'scope': 'default',
#   'state': 'Active',
#   'version': {'as_at_created': datetime.datetime(2023, 5, 9, 12, 53, 38, 688320, tzinfo=tzlocal()),
#               'as_at_date': datetime.datetime(2023, 5, 9, 12, 53, 38, 869193, tzinfo=tzlocal()),
#               'as_at_modified': datetime.datetime(2023, 5, 9, 12, 53, 38, 688320, tzinfo=tzlocal()),
#               'as_at_version_number': 1,
#               'effective_from': datetime.datetime(1, 1, 1, 0, 0, tzinfo=tzlocal()),
#               'user_id_created': '00u4edvny74dXgwzK2p7',
#               'user_id_modified': '00u4edvny74dXgwzK2p7'}},
#  {'asset_class': 'Unknown',
#   'dom_ccy': 'ZZZ',
#   'href': 'https://fbn-ci.lusid.com/api/api/instruments/LusidInstrumentId/LUID_00070D50?scope=default',
#   'identifiers': {'Figi': 'BBG000CLY2D3', 'LusidInstrumentId': 'LUID_00070D50'},
#   'instrument_definition': None,
#   'links': [{'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/entities/Instrument',
#              'method': 'GET',
#              'relation': 'EntitySchema'},
#             {'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/properties?propertyKeys=Instrument%2Fdefault%2FCurrency',
#              'method': 'GET',
#              'relation': 'PropertySchema'},
#             {'description': 'A link to the LUSID Insights website showing all '
#                             'logs related to this request',
#              'href': 'http://fbn-ci.lusid.com/app/insights/logs/0HMQGGAL4G36Q:00000095',
#              'method': 'GET',
#              'relation': 'RequestLogs'}],
#   'lookthrough_portfolio': None,
#   'lusid_instrument_id': 'LUID_00070D50',
#   'name': 'Softbank',
#   'properties': [],
#   'relationships': [],
#   'scope': 'default',
#   'state': 'Active',
#   'version': {'as_at_created': datetime.datetime(2023, 5, 9, 12, 53, 39, 921211, tzinfo=tzlocal()),
#               'as_at_date': datetime.datetime(2023, 5, 9, 12, 53, 39, 921211, tzinfo=tzlocal()),
#               'as_at_modified': datetime.datetime(2023, 5, 9, 12, 53, 39, 921211, tzinfo=tzlocal()),
#               'as_at_version_number': 1,
#               'effective_from': datetime.datetime(1, 1, 1, 0, 0, tzinfo=tzlocal()),
#               'user_id_created': '00u4edvny74dXgwzK2p7',
#               'user_id_modified': '00u4edvny74dXgwzK2p7'}},
#  {'asset_class': 'Unknown',
#   'dom_ccy': 'ZZZ',
#   'href': 'https://fbn-ci.lusid.com/api/api/instruments/LusidInstrumentId/LUID_00070D51?scope=default',
#   'identifiers': {'Figi': 'BBG000C0YGB0', 'LusidInstrumentId': 'LUID_00070D51'},
#   'instrument_definition': None,
#   'links': [{'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/entities/Instrument',
#              'method': 'GET',
#              'relation': 'EntitySchema'},
#             {'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/properties?propertyKeys=Instrument%2Fdefault%2FCurrency',
#              'method': 'GET',
#              'relation': 'PropertySchema'},
#             {'description': 'A link to the LUSID Insights website showing all '
#                             'logs related to this request',
#              'href': 'http://fbn-ci.lusid.com/app/insights/logs/0HMQGGAL4G36Q:00000098',
#              'method': 'GET',
#              'relation': 'RequestLogs'}],
#   'lookthrough_portfolio': None,
#   'lusid_instrument_id': 'LUID_00070D51',
#   'name': 'ASTRAZENECA',
#   'properties': [],
#   'relationships': [],
#   'scope': 'default',
#   'state': 'Active',
#   'version': {'as_at_created': datetime.datetime(2023, 5, 9, 12, 53, 41, 130640, tzinfo=tzlocal()),
#               'as_at_date': datetime.datetime(2023, 5, 9, 12, 53, 41, 130640, tzinfo=tzlocal()),
#               'as_at_modified': datetime.datetime(2023, 5, 9, 12, 53, 41, 130640, tzinfo=tzlocal()),
#               'as_at_version_number': 1,
#               'effective_from': datetime.datetime(1, 1, 1, 0, 0, tzinfo=tzlocal()),
#               'user_id_created': '00u4edvny74dXgwzK2p7',
#               'user_id_modified': '00u4edvny74dXgwzK2p7'}},
#  {'asset_class': 'Unknown',
#   'dom_ccy': 'ZZZ',
#   'href': 'https://fbn-ci.lusid.com/api/api/instruments/LusidInstrumentId/LUID_00070D52?scope=default',
#   'identifiers': {'Figi': 'BBG000C2C436', 'LusidInstrumentId': 'LUID_00070D52'},
#   'instrument_definition': None,
#   'links': [{'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/entities/Instrument',
#              'method': 'GET',
#              'relation': 'EntitySchema'},
#             {'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/properties?propertyKeys=Instrument%2Fdefault%2FCurrency',
#              'method': 'GET',
#              'relation': 'PropertySchema'},
#             {'description': 'A link to the LUSID Insights website showing all '
#                             'logs related to this request',
#              'href': 'http://fbn-ci.lusid.com/app/insights/logs/0HMQGGAL4G36Q:0000009C',
#              'method': 'GET',
#              'relation': 'RequestLogs'}],
#   'lookthrough_portfolio': None,
#   'lusid_instrument_id': 'LUID_00070D52',
#   'name': 'INTERCON. HOTEL',
#   'properties': [],
#   'relationships': [],
#   'scope': 'default',
#   'state': 'Active',
#   'version': {'as_at_created': datetime.datetime(2023, 5, 9, 12, 53, 42, 299399, tzinfo=tzlocal()),
#               'as_at_date': datetime.datetime(2023, 5, 9, 12, 53, 42, 299399, tzinfo=tzlocal()),
#               'as_at_modified': datetime.datetime(2023, 5, 9, 12, 53, 42, 299399, tzinfo=tzlocal()),
#               'as_at_version_number': 1,
#               'effective_from': datetime.datetime(1, 1, 1, 0, 0, tzinfo=tzlocal()),
#               'user_id_created': '00u4edvny74dXgwzK2p7',
#               'user_id_modified': '00u4edvny74dXgwzK2p7'}},
#  {'asset_class': 'Unknown',
#   'dom_ccy': 'ZZZ',
#   'href': 'https://fbn-ci.lusid.com/api/api/instruments/LusidInstrumentId/LUID_00070D53?scope=default',
#   'identifiers': {'Figi': 'BBG000BDQBV1', 'LusidInstrumentId': 'LUID_00070D53'},
#   'instrument_definition': None,
#   'links': [{'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/entities/Instrument',
#              'method': 'GET',
#              'relation': 'EntitySchema'},
#             {'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/properties?propertyKeys=Instrument%2Fdefault%2FCurrency',
#              'method': 'GET',
#              'relation': 'PropertySchema'},
#             {'description': 'A link to the LUSID Insights website showing all '
#                             'logs related to this request',
#              'href': 'http://fbn-ci.lusid.com/app/insights/logs/0HMQGGAL4G36Q:0000009F',
#              'method': 'GET',
#              'relation': 'RequestLogs'}],
#   'lookthrough_portfolio': None,
#   'lusid_instrument_id': 'LUID_00070D53',
#   'name': 'LEGAL&GEN.',
#   'properties': [],
#   'relationships': [],
#   'scope': 'default',
#   'state': 'Active',
#   'version': {'as_at_created': datetime.datetime(2023, 5, 9, 12, 53, 43, 361307, tzinfo=tzlocal()),
#               'as_at_date': datetime.datetime(2023, 5, 9, 12, 53, 43, 361307, tzinfo=tzlocal()),
#               'as_at_modified': datetime.datetime(2023, 5, 9, 12, 53, 43, 361307, tzinfo=tzlocal()),
#               'as_at_version_number': 1,
#               'effective_from': datetime.datetime(1, 1, 1, 0, 0, tzinfo=tzlocal()),
#               'user_id_created': '00u4edvny74dXgwzK2p7',
#               'user_id_modified': '00u4edvny74dXgwzK2p7'}},
#  {'asset_class': 'Unknown',
#   'dom_ccy': 'ZZZ',
#   'href': 'https://fbn-ci.lusid.com/api/api/instruments/LusidInstrumentId/LUID_00070D54?scope=default',
#   'identifiers': {'Figi': 'BBG000BDTRH9', 'LusidInstrumentId': 'LUID_00070D54'},
#   'instrument_definition': None,
#   'links': [{'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/entities/Instrument',
#              'method': 'GET',
#              'relation': 'EntitySchema'},
#             {'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/properties?propertyKeys=Instrument%2Fdefault%2FCurrency',
#              'method': 'GET',
#              'relation': 'PropertySchema'},
#             {'description': 'A link to the LUSID Insights website showing all '
#                             'logs related to this request',
#              'href': 'http://fbn-ci.lusid.com/app/insights/logs/0HMQGGAL4G36Q:000000A2',
#              'method': 'GET',
#              'relation': 'RequestLogs'}],
#   'lookthrough_portfolio': None,
#   'lusid_instrument_id': 'LUID_00070D54',
#   'name': 'MARKS & SP.',
#   'properties': [],
#   'relationships': [],
#   'scope': 'default',
#   'state': 'Active',
#   'version': {'as_at_created': datetime.datetime(2023, 5, 9, 12, 53, 44, 605307, tzinfo=tzlocal()),
#               'as_at_date': datetime.datetime(2023, 5, 9, 12, 53, 44, 605307, tzinfo=tzlocal()),
#               'as_at_modified': datetime.datetime(2023, 5, 9, 12, 53, 44, 605307, tzinfo=tzlocal()),
#               'as_at_version_number': 1,
#               'effective_from': datetime.datetime(1, 1, 1, 0, 0, tzinfo=tzlocal()),
#               'user_id_created': '00u4edvny74dXgwzK2p7',
#               'user_id_modified': '00u4edvny74dXgwzK2p7'}},
#  {'asset_class': 'Unknown',
#   'dom_ccy': 'ZZZ',
#   'href': 'https://fbn-ci.lusid.com/api/api/instruments/LusidInstrumentId/LUID_00070D55?scope=default',
#   'identifiers': {'Figi': 'BBG000FV67D8', 'LusidInstrumentId': 'LUID_00070D55'},
#   'instrument_definition': None,
#   'links': [{'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/entities/Instrument',
#              'method': 'GET',
#              'relation': 'EntitySchema'},
#             {'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/properties?propertyKeys=Instrument%2Fdefault%2FCurrency',
#              'method': 'GET',
#              'relation': 'PropertySchema'},
#             {'description': 'A link to the LUSID Insights website showing all '
#                             'logs related to this request',
#              'href': 'http://fbn-ci.lusid.com/app/insights/logs/0HMQGGAL4G383:00000007',
#              'method': 'GET',
#              'relation': 'RequestLogs'}],
#   'lookthrough_portfolio': None,
#   'lusid_instrument_id': 'LUID_00070D55',
#   'name': 'NATIONAL GRID',
#   'properties': [],
#   'relationships': [],
#   'scope': 'default',
#   'state': 'Active',
#   'version': {'as_at_created': datetime.datetime(2023, 5, 9, 12, 53, 46, 79441, tzinfo=tzlocal()),
#               'as_at_date': datetime.datetime(2023, 5, 9, 12, 53, 46, 79441, tzinfo=tzlocal()),
#               'as_at_modified': datetime.datetime(2023, 5, 9, 12, 53, 46, 79441, tzinfo=tzlocal()),
#               'as_at_version_number': 1,
#               'effective_from': datetime.datetime(1, 1, 1, 0, 0, tzinfo=tzlocal()),
#               'user_id_created': '00u4edvny74dXgwzK2p7',
#               'user_id_modified': '00u4edvny74dXgwzK2p7'}},
#  {'asset_class': 'Unknown',
#   'dom_ccy': 'ZZZ',
#   'href': 'https://fbn-ci.lusid.com/api/api/instruments/LusidInstrumentId/LUID_00070DC2?scope=default',
#   'identifiers': {'Figi': 'BBG000BF4HM7', 'LusidInstrumentId': 'LUID_00070DC2'},
#   'instrument_definition': None,
#   'links': [{'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/entities/Instrument',
#              'method': 'GET',
#              'relation': 'EntitySchema'},
#             {'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/properties?propertyKeys=Instrument%2Fdefault%2FCurrency',
#              'method': 'GET',
#              'relation': 'PropertySchema'},
#             {'description': 'A link to the LUSID Insights website showing all '
#                             'logs related to this request',
#              'href': 'http://fbn-ci.lusid.com/app/insights/logs/0HMQGGAL4G383:00000009',
#              'method': 'GET',
#              'relation': 'RequestLogs'}],
#   'lookthrough_portfolio': None,
#   'lusid_instrument_id': 'LUID_00070DC2',
#   'name': 'TAYLOR WIMPEY',
#   'properties': [],
#   'relationships': [],
#   'scope': 'default',
#   'state': 'Active',
#   'version': {'as_at_created': datetime.datetime(2023, 5, 9, 12, 53, 47, 316073, tzinfo=tzlocal()),
#               'as_at_date': datetime.datetime(2023, 5, 9, 12, 53, 47, 316073, tzinfo=tzlocal()),
#               'as_at_modified': datetime.datetime(2023, 5, 9, 12, 53, 47, 316073, tzinfo=tzlocal()),
#               'as_at_version_number': 1,
#               'effective_from': datetime.datetime(1, 1, 1, 0, 0, tzinfo=tzlocal()),
#               'user_id_created': '00u4edvny74dXgwzK2p7',
#               'user_id_modified': '00u4edvny74dXgwzK2p7'}},
#  {'asset_class': 'Unknown',
#   'dom_ccy': 'ZZZ',
#   'href': 'https://fbn-ci.lusid.com/api/api/instruments/LusidInstrumentId/LUID_00070DC3?scope=default',
#   'identifiers': {'Figi': 'BBG000C6K5W3', 'LusidInstrumentId': 'LUID_00070DC3'},
#   'instrument_definition': None,
#   'links': [{'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/entities/Instrument',
#              'method': 'GET',
#              'relation': 'EntitySchema'},
#             {'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/properties?propertyKeys=Instrument%2Fdefault%2FCurrency',
#              'method': 'GET',
#              'relation': 'PropertySchema'},
#             {'description': 'A link to the LUSID Insights website showing all '
#                             'logs related to this request',
#              'href': 'http://fbn-ci.lusid.com/app/insights/logs/0HMQGGAL4G36Q:000000AA',
#              'method': 'GET',
#              'relation': 'RequestLogs'}],
#   'lookthrough_portfolio': None,
#   'lusid_instrument_id': 'LUID_00070DC3',
#   'name': 'VODAFONE GRP.',
#   'properties': [],
#   'relationships': [],
#   'scope': 'default',
#   'state': 'Active',
#   'version': {'as_at_created': datetime.datetime(2023, 5, 9, 12, 53, 48, 485078, tzinfo=tzlocal()),
#               'as_at_date': datetime.datetime(2023, 5, 9, 12, 53, 48, 485078, tzinfo=tzlocal()),
#               'as_at_modified': datetime.datetime(2023, 5, 9, 12, 53, 48, 485078, tzinfo=tzlocal()),
#               'as_at_version_number': 1,
#               'effective_from': datetime.datetime(1, 1, 1, 0, 0, tzinfo=tzlocal()),
#               'user_id_created': '00u4edvny74dXgwzK2p7',
#               'user_id_modified': '00u4edvny74dXgwzK2p7'}},
#  {'asset_class': 'Unknown',
#   'dom_ccy': 'ZZZ',
#   'href': 'https://fbn-ci.lusid.com/api/api/instruments/LusidInstrumentId/LUID_00070DC4?scope=default',
#   'identifiers': {'Figi': 'BBG000BRVG61', 'LusidInstrumentId': 'LUID_00070DC4'},
#   'instrument_definition': None,
#   'links': [{'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/entities/Instrument',
#              'method': 'GET',
#              'relation': 'EntitySchema'},
#             {'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/properties?propertyKeys=Instrument%2Fdefault%2FCurrency',
#              'method': 'GET',
#              'relation': 'PropertySchema'},
#             {'description': 'A link to the LUSID Insights website showing all '
#                             'logs related to this request',
#              'href': 'http://fbn-ci.lusid.com/app/insights/logs/0HMQGGAL4G36Q:000000AD',
#              'method': 'GET',
#              'relation': 'RequestLogs'}],
#   'lookthrough_portfolio': None,
#   'lusid_instrument_id': 'LUID_00070DC4',
#   'name': 'WHITBREAD',
#   'properties': [],
#   'relationships': [],
#   'scope': 'default',
#   'state': 'Active',
#   'version': {'as_at_created': datetime.datetime(2023, 5, 9, 12, 53, 49, 604248, tzinfo=tzlocal()),
#               'as_at_date': datetime.datetime(2023, 5, 9, 12, 53, 49, 604248, tzinfo=tzlocal()),
#               'as_at_modified': datetime.datetime(2023, 5, 9, 12, 53, 49, 604248, tzinfo=tzlocal()),
#               'as_at_version_number': 1,
#               'effective_from': datetime.datetime(1, 1, 1, 0, 0, tzinfo=tzlocal()),
#               'user_id_created': '00u4edvny74dXgwzK2p7',
#               'user_id_modified': '00u4edvny74dXgwzK2p7'}},
#  {'asset_class': 'Unknown',
#   'dom_ccy': 'ZZZ',
#   'href': 'https://fbn-ci.lusid.com/api/api/instruments/LusidInstrumentId/LUID_00070DC5?scope=default',
#   'identifiers': {'Figi': 'BBG006XYRVX1', 'LusidInstrumentId': 'LUID_00070DC5'},
#   'instrument_definition': None,
#   'links': [{'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/entities/Instrument',
#              'method': 'GET',
#              'relation': 'EntitySchema'},
#             {'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/properties?propertyKeys=Instrument%2Fdefault%2FCurrency',
#              'method': 'GET',
#              'relation': 'PropertySchema'},
#             {'description': 'A link to the LUSID Insights website showing all '
#                             'logs related to this request',
#              'href': 'http://fbn-ci.lusid.com/app/insights/logs/0HMQGGAL4G36U:00000075',
#              'method': 'GET',
#              'relation': 'RequestLogs'}],
#   'lookthrough_portfolio': None,
#   'lusid_instrument_id': 'LUID_00070DC5',
#   'name': 'T 2.375% Aug 15, 2024',
#   'properties': [],
#   'relationships': [],
#   'scope': 'default',
#   'state': 'Active',
#   'version': {'as_at_created': datetime.datetime(2023, 5, 9, 12, 53, 50, 967272, tzinfo=tzlocal()),
#               'as_at_date': datetime.datetime(2023, 5, 9, 12, 53, 50, 967272, tzinfo=tzlocal()),
#               'as_at_modified': datetime.datetime(2023, 5, 9, 12, 53, 50, 967272, tzinfo=tzlocal()),
#               'as_at_version_number': 1,
#               'effective_from': datetime.datetime(1, 1, 1, 0, 0, tzinfo=tzlocal()),
#               'user_id_created': '00u4edvny74dXgwzK2p7',
#               'user_id_modified': '00u4edvny74dXgwzK2p7'}},
#  {'asset_class': 'Unknown',
#   'dom_ccy': 'ZZZ',
#   'href': 'https://fbn-ci.lusid.com/api/api/instruments/LusidInstrumentId/LUID_00070DC6?scope=default',
#   'identifiers': {'Figi': 'BBG009R4CLR3', 'LusidInstrumentId': 'LUID_00070DC6'},
#   'instrument_definition': None,
#   'links': [{'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/entities/Instrument',
#              'method': 'GET',
#              'relation': 'EntitySchema'},
#             {'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/properties?propertyKeys=Instrument%2Fdefault%2FCurrency',
#              'method': 'GET',
#              'relation': 'PropertySchema'},
#             {'description': 'A link to the LUSID Insights website showing all '
#                             'logs related to this request',
#              'href': 'http://fbn-ci.lusid.com/app/insights/logs/0HMQGGAL4G36U:00000076',
#              'method': 'GET',
#              'relation': 'RequestLogs'}],
#   'lookthrough_portfolio': None,
#   'lusid_instrument_id': 'LUID_00070DC6',
#   'name': 'T 2% Aug 15, 2025',
#   'properties': [],
#   'relationships': [],
#   'scope': 'default',
#   'state': 'Active',
#   'version': {'as_at_created': datetime.datetime(2023, 5, 9, 12, 53, 52, 181877, tzinfo=tzlocal()),
#               'as_at_date': datetime.datetime(2023, 5, 9, 12, 53, 52, 181877, tzinfo=tzlocal()),
#               'as_at_modified': datetime.datetime(2023, 5, 9, 12, 53, 52, 181877, tzinfo=tzlocal()),
#               'as_at_version_number': 1,
#               'effective_from': datetime.datetime(1, 1, 1, 0, 0, tzinfo=tzlocal()),
#               'user_id_created': '00u4edvny74dXgwzK2p7',
#               'user_id_modified': '00u4edvny74dXgwzK2p7'}},
#  {'asset_class': 'Unknown',
#   'dom_ccy': 'ZZZ',
#   'href': 'https://fbn-ci.lusid.com/api/api/instruments/LusidInstrumentId/LUID_00070DC7?scope=default',
#   'identifiers': {'Figi': 'BBG00FX263Y5', 'LusidInstrumentId': 'LUID_00070DC7'},
#   'instrument_definition': None,
#   'links': [{'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/entities/Instrument',
#              'method': 'GET',
#              'relation': 'EntitySchema'},
#             {'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/properties?propertyKeys=Instrument%2Fdefault%2FCurrency',
#              'method': 'GET',
#              'relation': 'PropertySchema'},
#             {'description': 'A link to the LUSID Insights website showing all '
#                             'logs related to this request',
#              'href': 'http://fbn-ci.lusid.com/app/insights/logs/0HMQGGAL4G36Q:000000B0',
#              'method': 'GET',
#              'relation': 'RequestLogs'}],
#   'lookthrough_portfolio': None,
#   'lusid_instrument_id': 'LUID_00070DC7',
#   'name': 'T 2.25% Feb 15, 2027',
#   'properties': [],
#   'relationships': [],
#   'scope': 'default',
#   'state': 'Active',
#   'version': {'as_at_created': datetime.datetime(2023, 5, 9, 12, 53, 53, 308123, tzinfo=tzlocal()),
#               'as_at_date': datetime.datetime(2023, 5, 9, 12, 53, 53, 308123, tzinfo=tzlocal()),
#               'as_at_modified': datetime.datetime(2023, 5, 9, 12, 53, 53, 308123, tzinfo=tzlocal()),
#               'as_at_version_number': 1,
#               'effective_from': datetime.datetime(1, 1, 1, 0, 0, tzinfo=tzlocal()),
#               'user_id_created': '00u4edvny74dXgwzK2p7',
#               'user_id_modified': '00u4edvny74dXgwzK2p7'}},
#  {'asset_class': 'Unknown',
#   'dom_ccy': 'ZZZ',
#   'href': 'https://fbn-ci.lusid.com/api/api/instruments/LusidInstrumentId/LUID_00070DC8?scope=default',
#   'identifiers': {'Figi': 'BBG006C082Q1', 'LusidInstrumentId': 'LUID_00070DC8'},
#   'instrument_definition': None,
#   'links': [{'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/entities/Instrument',
#              'method': 'GET',
#              'relation': 'EntitySchema'},
#             {'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/properties?propertyKeys=Instrument%2Fdefault%2FCurrency',
#              'method': 'GET',
#              'relation': 'PropertySchema'},
#             {'description': 'A link to the LUSID Insights website showing all '
#                             'logs related to this request',
#              'href': 'http://fbn-ci.lusid.com/app/insights/logs/0HMQGGAL4G36U:0000007A',
#              'method': 'GET',
#              'relation': 'RequestLogs'}],
#   'lookthrough_portfolio': None,
#   'lusid_instrument_id': 'LUID_00070DC8',
#   'name': 'T 2.25% Apr 30, 2021',
#   'properties': [],
#   'relationships': [],
#   'scope': 'default',
#   'state': 'Active',
#   'version': {'as_at_created': datetime.datetime(2023, 5, 9, 12, 53, 54, 808019, tzinfo=tzlocal()),
#               'as_at_date': datetime.datetime(2023, 5, 9, 12, 53, 54, 866977, tzinfo=tzlocal()),
#               'as_at_modified': datetime.datetime(2023, 5, 9, 12, 53, 54, 808019, tzinfo=tzlocal()),
#               'as_at_version_number': 1,
#               'effective_from': datetime.datetime(1, 1, 1, 0, 0, tzinfo=tzlocal()),
#               'user_id_created': '00u4edvny74dXgwzK2p7',
#               'user_id_modified': '00u4edvny74dXgwzK2p7'}},
#  {'asset_class': 'Unknown',
#   'dom_ccy': 'ZZZ',
#   'href': 'https://fbn-ci.lusid.com/api/api/instruments/LusidInstrumentId/LUID_00070DC9?scope=default',
#   'identifiers': {'Figi': 'BBG007GY2HH4', 'LusidInstrumentId': 'LUID_00070DC9'},
#   'instrument_definition': None,
#   'links': [{'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/entities/Instrument',
#              'method': 'GET',
#              'relation': 'EntitySchema'},
#             {'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/properties?propertyKeys=Instrument%2Fdefault%2FCurrency',
#              'method': 'GET',
#              'relation': 'PropertySchema'},
#             {'description': 'A link to the LUSID Insights website showing all '
#                             'logs related to this request',
#              'href': 'http://fbn-ci.lusid.com/app/insights/logs/0HMQGGAL4G36Q:000000B4',
#              'method': 'GET',
#              'relation': 'RequestLogs'}],
#   'lookthrough_portfolio': None,
#   'lusid_instrument_id': 'LUID_00070DC9',
#   'name': 'T 2.25% Nov 15, 2024',
#   'properties': [],
#   'relationships': [],
#   'scope': 'default',
#   'state': 'Active',
#   'version': {'as_at_created': datetime.datetime(2023, 5, 9, 12, 53, 55, 966882, tzinfo=tzlocal()),
#               'as_at_date': datetime.datetime(2023, 5, 9, 12, 53, 56, 287465, tzinfo=tzlocal()),
#               'as_at_modified': datetime.datetime(2023, 5, 9, 12, 53, 55, 966882, tzinfo=tzlocal()),
#               'as_at_version_number': 1,
#               'effective_from': datetime.datetime(1, 1, 1, 0, 0, tzinfo=tzlocal()),
#               'user_id_created': '00u4edvny74dXgwzK2p7',
#               'user_id_modified': '00u4edvny74dXgwzK2p7'}},
#  {'asset_class': 'Unknown',
#   'dom_ccy': 'ZZZ',
#   'href': 'https://fbn-ci.lusid.com/api/api/instruments/LusidInstrumentId/LUID_00070DCA?scope=default',
#   'identifiers': {'Figi': 'BBG00F5RQCH8', 'LusidInstrumentId': 'LUID_00070DCA'},
#   'instrument_definition': None,
#   'links': [{'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/entities/Instrument',
#              'method': 'GET',
#              'relation': 'EntitySchema'},
#             {'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/properties?propertyKeys=Instrument%2Fdefault%2FCurrency',
#              'method': 'GET',
#              'relation': 'PropertySchema'},
#             {'description': 'A link to the LUSID Insights website showing all '
#                             'logs related to this request',
#              'href': 'http://fbn-ci.lusid.com/app/insights/logs/0HMQGGAL4G36U:00000080',
#              'method': 'GET',
#              'relation': 'RequestLogs'}],
#   'lookthrough_portfolio': None,
#   'lusid_instrument_id': 'LUID_00070DCA',
#   'name': 'T 2.875% Nov 15, 2046',
#   'properties': [],
#   'relationships': [],
#   'scope': 'default',
#   'state': 'Active',
#   'version': {'as_at_created': datetime.datetime(2023, 5, 9, 12, 53, 57, 411498, tzinfo=tzlocal()),
#               'as_at_date': datetime.datetime(2023, 5, 9, 12, 53, 57, 411498, tzinfo=tzlocal()),
#               'as_at_modified': datetime.datetime(2023, 5, 9, 12, 53, 57, 411498, tzinfo=tzlocal()),
#               'as_at_version_number': 1,
#               'effective_from': datetime.datetime(1, 1, 1, 0, 0, tzinfo=tzlocal()),
#               'user_id_created': '00u4edvny74dXgwzK2p7',
#               'user_id_modified': '00u4edvny74dXgwzK2p7'}},
#  {'asset_class': 'Unknown',
#   'dom_ccy': 'ZZZ',
#   'href': 'https://fbn-ci.lusid.com/api/api/instruments/LusidInstrumentId/LUID_00070DCB?scope=default',
#   'identifiers': {'Figi': 'BBG00827QXY6', 'LusidInstrumentId': 'LUID_00070DCB'},
#   'instrument_definition': None,
#   'links': [{'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/entities/Instrument',
#              'method': 'GET',
#              'relation': 'EntitySchema'},
#             {'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/properties?propertyKeys=Instrument%2Fdefault%2FCurrency',
#              'method': 'GET',
#              'relation': 'PropertySchema'},
#             {'description': 'A link to the LUSID Insights website showing all '
#                             'logs related to this request',
#              'href': 'http://fbn-ci.lusid.com/app/insights/logs/0HMQGGAL4G36U:00000084',
#              'method': 'GET',
#              'relation': 'RequestLogs'}],
#   'lookthrough_portfolio': None,
#   'lusid_instrument_id': 'LUID_00070DCB',
#   'name': 'T 2% Feb 15, 2025',
#   'properties': [],
#   'relationships': [],
#   'scope': 'default',
#   'state': 'Active',
#   'version': {'as_at_created': datetime.datetime(2023, 5, 9, 12, 53, 58, 577318, tzinfo=tzlocal()),
#               'as_at_date': datetime.datetime(2023, 5, 9, 12, 53, 58, 577318, tzinfo=tzlocal()),
#               'as_at_modified': datetime.datetime(2023, 5, 9, 12, 53, 58, 577318, tzinfo=tzlocal()),
#               'as_at_version_number': 1,
#               'effective_from': datetime.datetime(1, 1, 1, 0, 0, tzinfo=tzlocal()),
#               'user_id_created': '00u4edvny74dXgwzK2p7',
#               'user_id_modified': '00u4edvny74dXgwzK2p7'}},
#  {'asset_class': 'Unknown',
#   'dom_ccy': 'ZZZ',
#   'href': 'https://fbn-ci.lusid.com/api/api/instruments/LusidInstrumentId/LUID_00070DCC?scope=default',
#   'identifiers': {'Figi': 'BBG000DFN2D7', 'LusidInstrumentId': 'LUID_00070DCC'},
#   'instrument_definition': None,
#   'links': [{'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/entities/Instrument',
#              'method': 'GET',
#              'relation': 'EntitySchema'},
#             {'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/properties?propertyKeys=Instrument%2Fdefault%2FCurrency',
#              'method': 'GET',
#              'relation': 'PropertySchema'},
#             {'description': 'A link to the LUSID Insights website showing all '
#                             'logs related to this request',
#              'href': 'http://fbn-ci.lusid.com/app/insights/logs/0HMQGGAL4G34J:000000CE',
#              'method': 'GET',
#              'relation': 'RequestLogs'}],
#   'lookthrough_portfolio': None,
#   'lusid_instrument_id': 'LUID_00070DCC',
#   'name': 'T 7.125% Feb 15, 2023',
#   'properties': [],
#   'relationships': [],
#   'scope': 'default',
#   'state': 'Active',
#   'version': {'as_at_created': datetime.datetime(2023, 5, 9, 12, 53, 59, 768517, tzinfo=tzlocal()),
#               'as_at_date': datetime.datetime(2023, 5, 9, 12, 53, 59, 768517, tzinfo=tzlocal()),
#               'as_at_modified': datetime.datetime(2023, 5, 9, 12, 53, 59, 768517, tzinfo=tzlocal()),
#               'as_at_version_number': 1,
#               'effective_from': datetime.datetime(1, 1, 1, 0, 0, tzinfo=tzlocal()),
#               'user_id_created': '00u4edvny74dXgwzK2p7',
#               'user_id_modified': '00u4edvny74dXgwzK2p7'}},
#  {'asset_class': 'Unknown',
#   'dom_ccy': 'ZZZ',
#   'href': 'https://fbn-ci.lusid.com/api/api/instruments/LusidInstrumentId/LUID_00070DCD?scope=default',
#   'identifiers': {'Figi': 'BBG009TCBQV8', 'LusidInstrumentId': 'LUID_00070DCD'},
#   'instrument_definition': None,
#   'links': [{'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/entities/Instrument',
#              'method': 'GET',
#              'relation': 'EntitySchema'},
#             {'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/properties?propertyKeys=Instrument%2Fdefault%2FCurrency',
#              'method': 'GET',
#              'relation': 'PropertySchema'},
#             {'description': 'A link to the LUSID Insights website showing all '
#                             'logs related to this request',
#              'href': 'http://fbn-ci.lusid.com/app/insights/logs/0HMQGGAL4G36U:00000088',
#              'method': 'GET',
#              'relation': 'RequestLogs'}],
#   'lookthrough_portfolio': None,
#   'lusid_instrument_id': 'LUID_00070DCD',
#   'name': 'T 1.875% Aug 31, 2022',
#   'properties': [],
#   'relationships': [],
#   'scope': 'default',
#   'state': 'Active',
#   'version': {'as_at_created': datetime.datetime(2023, 5, 9, 12, 54, 0, 845775, tzinfo=tzlocal()),
#               'as_at_date': datetime.datetime(2023, 5, 9, 12, 54, 0, 845775, tzinfo=tzlocal()),
#               'as_at_modified': datetime.datetime(2023, 5, 9, 12, 54, 0, 845775, tzinfo=tzlocal()),
#               'as_at_version_number': 1,
#               'effective_from': datetime.datetime(1, 1, 1, 0, 0, tzinfo=tzlocal()),
#               'user_id_created': '00u4edvny74dXgwzK2p7',
#               'user_id_modified': '00u4edvny74dXgwzK2p7'}},
#  {'asset_class': 'Unknown',
#   'dom_ccy': 'ZZZ',
#   'href': 'https://fbn-ci.lusid.com/api/api/instruments/LusidInstrumentId/LUID_00070DCE?scope=default',
#   'identifiers': {'Figi': 'BBG0084GPDG9', 'LusidInstrumentId': 'LUID_00070DCE'},
#   'instrument_definition': None,
#   'links': [{'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/entities/Instrument',
#              'method': 'GET',
#              'relation': 'EntitySchema'},
#             {'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/properties?propertyKeys=Instrument%2Fdefault%2FCurrency',
#              'method': 'GET',
#              'relation': 'PropertySchema'},
#             {'description': 'A link to the LUSID Insights website showing all '
#                             'logs related to this request',
#              'href': 'http://fbn-ci.lusid.com/app/insights/logs/0HMQGGAL4G36U:0000008C',
#              'method': 'GET',
#              'relation': 'RequestLogs'}],
#   'lookthrough_portfolio': None,
#   'lusid_instrument_id': 'LUID_00070DCE',
#   'name': 'T 1.75% Feb 28, 2022',
#   'properties': [],
#   'relationships': [],
#   'scope': 'default',
#   'state': 'Active',
#   'version': {'as_at_created': datetime.datetime(2023, 5, 9, 12, 54, 1, 968082, tzinfo=tzlocal()),
#               'as_at_date': datetime.datetime(2023, 5, 9, 12, 54, 1, 968082, tzinfo=tzlocal()),
#               'as_at_modified': datetime.datetime(2023, 5, 9, 12, 54, 1, 968082, tzinfo=tzlocal()),
#               'as_at_version_number': 1,
#               'effective_from': datetime.datetime(1, 1, 1, 0, 0, tzinfo=tzlocal()),
#               'user_id_created': '00u4edvny74dXgwzK2p7',
# ...
#               'as_at_date': datetime.datetime(2023, 5, 9, 12, 54, 3, 100567, tzinfo=tzlocal()),
#               'as_at_modified': datetime.datetime(2023, 5, 9, 12, 54, 3, 100567, tzinfo=tzlocal()),
#               'as_at_version_number': 1,
#               'effective_from': datetime.datetime(1, 1, 1, 0, 0, tzinfo=tzlocal()),
#               'user_id_created': '00u4edvny74dXgwzK2p7',
#               'user_id_modified': '00u4edvny74dXgwzK2p7'}},
#  {'asset_class': 'Unknown',
#   'dom_ccy': 'ZZZ',
#   'href': 'https://fbn-ci.lusid.com/api/api/instruments/LusidInstrumentId/LUID_00070DCG?scope=default',
#   'identifiers': {'Figi': 'BBG00D1PBRL9', 'LusidInstrumentId': 'LUID_00070DCG'},
#   'instrument_definition': None,
#   'links': [{'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/entities/Instrument',
#              'method': 'GET',
#              'relation': 'EntitySchema'},
#             {'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/properties?propertyKeys=Instrument%2Fdefault%2FCurrency',
#              'method': 'GET',
#              'relation': 'PropertySchema'},
#             {'description': 'A link to the LUSID Insights website showing all '
#                             'logs related to this request',
#              'href': 'http://fbn-ci.lusid.com/app/insights/logs/0HMQGGAL4G383:00000017',
#              'method': 'GET',
#              'relation': 'RequestLogs'}],
#   'lookthrough_portfolio': None,
#   'lusid_instrument_id': 'LUID_00070DCG',
#   'name': 'GE 4.418% Nov 15, 2035',
#   'properties': [],
#   'relationships': [],
#   'scope': 'default',
#   'state': 'Active',
#   'version': {'as_at_created': datetime.datetime(2023, 5, 9, 12, 54, 4, 375577, tzinfo=tzlocal()),
#               'as_at_date': datetime.datetime(2023, 5, 9, 12, 54, 4, 375577, tzinfo=tzlocal()),
#               'as_at_modified': datetime.datetime(2023, 5, 9, 12, 54, 4, 375577, tzinfo=tzlocal()),
#               'as_at_version_number': 1,
#               'effective_from': datetime.datetime(1, 1, 1, 0, 0, tzinfo=tzlocal()),
#               'user_id_created': '00u4edvny74dXgwzK2p7',
#               'user_id_modified': '00u4edvny74dXgwzK2p7'}},
#  {'asset_class': 'Unknown',
#   'dom_ccy': 'ZZZ',
#   'href': 'https://fbn-ci.lusid.com/api/api/instruments/LusidInstrumentId/LUID_00070DCH?scope=default',
#   'identifiers': {'Figi': 'BBG00BW1V2M4', 'LusidInstrumentId': 'LUID_00070DCH'},
#   'instrument_definition': None,
#   'links': [{'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/entities/Instrument',
#              'method': 'GET',
#              'relation': 'EntitySchema'},
#             {'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/properties?propertyKeys=Instrument%2Fdefault%2FCurrency',
#              'method': 'GET',
#              'relation': 'PropertySchema'},
#             {'description': 'A link to the LUSID Insights website showing all '
#                             'logs related to this request',
#              'href': 'http://fbn-ci.lusid.com/app/insights/logs/0HMQGGAL4G383:00000019',
#              'method': 'GET',
#              'relation': 'RequestLogs'}],
#   'lookthrough_portfolio': None,
#   'lusid_instrument_id': 'LUID_00070DCH',
#   'name': 'ANHEUSER-BUSCH 4.9% Feb 01, 2046',
#   'properties': [],
#   'relationships': [],
#   'scope': 'default',
#   'state': 'Active',
#   'version': {'as_at_created': datetime.datetime(2023, 5, 9, 12, 54, 5, 487915, tzinfo=tzlocal()),
#               'as_at_date': datetime.datetime(2023, 5, 9, 12, 54, 5, 487915, tzinfo=tzlocal()),
#               'as_at_modified': datetime.datetime(2023, 5, 9, 12, 54, 5, 487915, tzinfo=tzlocal()),
#               'as_at_version_number': 1,
#               'effective_from': datetime.datetime(1, 1, 1, 0, 0, tzinfo=tzlocal()),
#               'user_id_created': '00u4edvny74dXgwzK2p7',
#               'user_id_modified': '00u4edvny74dXgwzK2p7'}},
#  {'asset_class': 'Unknown',
#   'dom_ccy': 'ZZZ',
#   'href': 'https://fbn-ci.lusid.com/api/api/instruments/LusidInstrumentId/LUID_00070DCI?scope=default',
#   'identifiers': {'Figi': 'BBG00K85WG22', 'LusidInstrumentId': 'LUID_00070DCI'},
#   'instrument_definition': None,
#   'links': [{'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/entities/Instrument',
#              'method': 'GET',
#              'relation': 'EntitySchema'},
#             {'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/properties?propertyKeys=Instrument%2Fdefault%2FCurrency',
#              'method': 'GET',
#              'relation': 'PropertySchema'},
#             {'description': 'A link to the LUSID Insights website showing all '
#                             'logs related to this request',
#              'href': 'http://fbn-ci.lusid.com/app/insights/logs/0HMQGGAL4G36U:00000098',
#              'method': 'GET',
#              'relation': 'RequestLogs'}],
#   'lookthrough_portfolio': None,
#   'lusid_instrument_id': 'LUID_00070DCI',
#   'name': 'CVS 4.3% Mar 25, 2028',
#   'properties': [],
#   'relationships': [],
#   'scope': 'default',
#   'state': 'Active',
#   'version': {'as_at_created': datetime.datetime(2023, 5, 9, 12, 54, 6, 525791, tzinfo=tzlocal()),
#               'as_at_date': datetime.datetime(2023, 5, 9, 12, 54, 6, 525791, tzinfo=tzlocal()),
#               'as_at_modified': datetime.datetime(2023, 5, 9, 12, 54, 6, 525791, tzinfo=tzlocal()),
#               'as_at_version_number': 1,
#               'effective_from': datetime.datetime(1, 1, 1, 0, 0, tzinfo=tzlocal()),
#               'user_id_created': '00u4edvny74dXgwzK2p7',
#               'user_id_modified': '00u4edvny74dXgwzK2p7'}},
#  {'asset_class': 'Unknown',
#   'dom_ccy': 'ZZZ',
#   'href': 'https://fbn-ci.lusid.com/api/api/instruments/LusidInstrumentId/LUID_00070DCJ?scope=default',
#   'identifiers': {'Figi': 'BBG00K85WH93', 'LusidInstrumentId': 'LUID_00070DCJ'},
#   'instrument_definition': None,
#   'links': [{'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/entities/Instrument',
#              'method': 'GET',
#              'relation': 'EntitySchema'},
#             {'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/properties?propertyKeys=Instrument%2Fdefault%2FCurrency',
#              'method': 'GET',
#              'relation': 'PropertySchema'},
#             {'description': 'A link to the LUSID Insights website showing all '
#                             'logs related to this request',
#              'href': 'http://fbn-ci.lusid.com/app/insights/logs/0HMQGGAL4G36Q:000000BE',
#              'method': 'GET',
#              'relation': 'RequestLogs'}],
#   'lookthrough_portfolio': None,
#   'lusid_instrument_id': 'LUID_00070DCJ',
#   'name': 'CVS 5.05% Mar 25, 2048',
#   'properties': [],
#   'relationships': [],
#   'scope': 'default',
#   'state': 'Active',
#   'version': {'as_at_created': datetime.datetime(2023, 5, 9, 12, 54, 7, 800350, tzinfo=tzlocal()),
#               'as_at_date': datetime.datetime(2023, 5, 9, 12, 54, 7, 943403, tzinfo=tzlocal()),
#               'as_at_modified': datetime.datetime(2023, 5, 9, 12, 54, 7, 800350, tzinfo=tzlocal()),
#               'as_at_version_number': 1,
#               'effective_from': datetime.datetime(1, 1, 1, 0, 0, tzinfo=tzlocal()),
#               'user_id_created': '00u4edvny74dXgwzK2p7',
#               'user_id_modified': '00u4edvny74dXgwzK2p7'}},
#  {'asset_class': 'Unknown',
#   'dom_ccy': 'ZZZ',
#   'href': 'https://fbn-ci.lusid.com/api/api/instruments/LusidInstrumentId/LUID_00070DCK?scope=default',
#   'identifiers': {'Figi': 'BBG0000H5309', 'LusidInstrumentId': 'LUID_00070DCK'},
#   'instrument_definition': None,
#   'links': [{'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/entities/Instrument',
#              'method': 'GET',
#              'relation': 'EntitySchema'},
#             {'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/properties?propertyKeys=Instrument%2Fdefault%2FCurrency',
#              'method': 'GET',
#              'relation': 'PropertySchema'},
#             {'description': 'A link to the LUSID Insights website showing all '
#                             'logs related to this request',
#              'href': 'http://fbn-ci.lusid.com/app/insights/logs/0HMQGGAL4G36Q:000000C1',
#              'method': 'GET',
#              'relation': 'RequestLogs'}],
#   'lookthrough_portfolio': None,
#   'lusid_instrument_id': 'LUID_00070DCK',
#   'name': 'GOLDMAN 6.75% Oct 01, 2037',
#   'properties': [],
#   'relationships': [],
#   'scope': 'default',
#   'state': 'Active',
#   'version': {'as_at_created': datetime.datetime(2023, 5, 9, 12, 54, 8, 983333, tzinfo=tzlocal()),
#               'as_at_date': datetime.datetime(2023, 5, 9, 12, 54, 8, 983333, tzinfo=tzlocal()),
#               'as_at_modified': datetime.datetime(2023, 5, 9, 12, 54, 8, 983333, tzinfo=tzlocal()),
#               'as_at_version_number': 1,
#               'effective_from': datetime.datetime(1, 1, 1, 0, 0, tzinfo=tzlocal()),
#               'user_id_created': '00u4edvny74dXgwzK2p7',
#               'user_id_modified': '00u4edvny74dXgwzK2p7'}},
#  {'asset_class': 'Unknown',
#   'dom_ccy': 'ZZZ',
#   'href': 'https://fbn-ci.lusid.com/api/api/instruments/LusidInstrumentId/LUID_00070DCL?scope=default',
#   'identifiers': {'Figi': 'BBG00K85TYW4', 'LusidInstrumentId': 'LUID_00070DCL'},
#   'instrument_definition': None,
#   'links': [{'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/entities/Instrument',
#              'method': 'GET',
#              'relation': 'EntitySchema'},
#             {'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/properties?propertyKeys=Instrument%2Fdefault%2FCurrency',
#              'method': 'GET',
#              'relation': 'PropertySchema'},
#             {'description': 'A link to the LUSID Insights website showing all '
#                             'logs related to this request',
#              'href': 'http://fbn-ci.lusid.com/app/insights/logs/0HMQGGAL4G34J:000000D2',
#              'method': 'GET',
#              'relation': 'RequestLogs'}],
#   'lookthrough_portfolio': None,
#   'lusid_instrument_id': 'LUID_00070DCL',
#   'name': 'CVS 3.7% Mar 09, 2023',
#   'properties': [],
#   'relationships': [],
#   'scope': 'default',
#   'state': 'Active',
#   'version': {'as_at_created': datetime.datetime(2023, 5, 9, 12, 54, 10, 204866, tzinfo=tzlocal()),
#               'as_at_date': datetime.datetime(2023, 5, 9, 12, 54, 10, 204866, tzinfo=tzlocal()),
#               'as_at_modified': datetime.datetime(2023, 5, 9, 12, 54, 10, 204866, tzinfo=tzlocal()),
#               'as_at_version_number': 1,
#               'effective_from': datetime.datetime(1, 1, 1, 0, 0, tzinfo=tzlocal()),
#               'user_id_created': '00u4edvny74dXgwzK2p7',
#               'user_id_modified': '00u4edvny74dXgwzK2p7'}},
#  {'asset_class': 'Unknown',
#   'dom_ccy': 'ZZZ',
#   'href': 'https://fbn-ci.lusid.com/api/api/instruments/LusidInstrumentId/LUID_00070DCM?scope=default',
#   'identifiers': {'Figi': 'BBG00BW1LJT1', 'LusidInstrumentId': 'LUID_00070DCM'},
#   'instrument_definition': None,
#   'links': [{'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/entities/Instrument',
#              'method': 'GET',
#              'relation': 'EntitySchema'},
#             {'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/properties?propertyKeys=Instrument%2Fdefault%2FCurrency',
#              'method': 'GET',
#              'relation': 'PropertySchema'},
#             {'description': 'A link to the LUSID Insights website showing all '
#                             'logs related to this request',
#              'href': 'http://fbn-ci.lusid.com/app/insights/logs/0HMQGGAL4G36U:0000009F',
#              'method': 'GET',
#              'relation': 'RequestLogs'}],
#   'lookthrough_portfolio': None,
#   'lusid_instrument_id': 'LUID_00070DCM',
#   'name': 'ANHEUSER-BUSCH 3.3% Feb 01, 2023',
#   'properties': [],
#   'relationships': [],
#   'scope': 'default',
#   'state': 'Active',
#   'version': {'as_at_created': datetime.datetime(2023, 5, 9, 12, 54, 11, 407772, tzinfo=tzlocal()),
#               'as_at_date': datetime.datetime(2023, 5, 9, 12, 54, 11, 407772, tzinfo=tzlocal()),
#               'as_at_modified': datetime.datetime(2023, 5, 9, 12, 54, 11, 407772, tzinfo=tzlocal()),
#               'as_at_version_number': 1,
#               'effective_from': datetime.datetime(1, 1, 1, 0, 0, tzinfo=tzlocal()),
#               'user_id_created': '00u4edvny74dXgwzK2p7',
#               'user_id_modified': '00u4edvny74dXgwzK2p7'}},
#  {'asset_class': 'Unknown',
#   'dom_ccy': 'ZZZ',
#   'href': 'https://fbn-ci.lusid.com/api/api/instruments/LusidInstrumentId/LUID_00070DCN?scope=default',
#   'identifiers': {'Figi': 'BBG0083CP3G1', 'LusidInstrumentId': 'LUID_00070DCN'},
#   'instrument_definition': None,
#   'links': [{'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/entities/Instrument',
#              'method': 'GET',
#              'relation': 'EntitySchema'},
#             {'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/properties?propertyKeys=Instrument%2Fdefault%2FCurrency',
#              'method': 'GET',
#              'relation': 'PropertySchema'},
#             {'description': 'A link to the LUSID Insights website showing all '
#                             'logs related to this request',
#              'href': 'http://fbn-ci.lusid.com/app/insights/logs/0HMQGGAL4G34J:000000D9',
#              'method': 'GET',
#              'relation': 'RequestLogs'}],
#   'lookthrough_portfolio': None,
#   'lusid_instrument_id': 'LUID_00070DCN',
#   'name': 'VERIZON 4.862% Aug 21, 2046',
#   'properties': [],
#   'relationships': [],
#   'scope': 'default',
#   'state': 'Active',
#   'version': {'as_at_created': datetime.datetime(2023, 5, 9, 12, 54, 12, 496582, tzinfo=tzlocal()),
#               'as_at_date': datetime.datetime(2023, 5, 9, 12, 54, 12, 496582, tzinfo=tzlocal()),
#               'as_at_modified': datetime.datetime(2023, 5, 9, 12, 54, 12, 496582, tzinfo=tzlocal()),
#               'as_at_version_number': 1,
#               'effective_from': datetime.datetime(1, 1, 1, 0, 0, tzinfo=tzlocal()),
#               'user_id_created': '00u4edvny74dXgwzK2p7',
#               'user_id_modified': '00u4edvny74dXgwzK2p7'}},
#  {'asset_class': 'Unknown',
#   'dom_ccy': 'ZZZ',
#   'href': 'https://fbn-ci.lusid.com/api/api/instruments/LusidInstrumentId/LUID_00070DCO?scope=default',
#   'identifiers': {'Figi': 'BBG004HST063', 'LusidInstrumentId': 'LUID_00070DCO'},
#   'instrument_definition': None,
#   'links': [{'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/entities/Instrument',
#              'method': 'GET',
#              'relation': 'EntitySchema'},
#             {'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/properties?propertyKeys=Instrument%2Fdefault%2FCurrency',
#              'method': 'GET',
#              'relation': 'PropertySchema'},
#             {'description': 'A link to the LUSID Insights website showing all '
#                             'logs related to this request',
#              'href': 'http://fbn-ci.lusid.com/app/insights/logs/0HMQGGAL4G34J:000000DC',
#              'method': 'GET',
#              'relation': 'RequestLogs'}],
#   'lookthrough_portfolio': None,
#   'lusid_instrument_id': 'LUID_00070DCO',
#   'name': 'APPLE 2.4% May 03, 2023',
#   'properties': [],
#   'relationships': [],
#   'scope': 'default',
#   'state': 'Active',
#   'version': {'as_at_created': datetime.datetime(2023, 5, 9, 12, 54, 13, 723448, tzinfo=tzlocal()),
#               'as_at_date': datetime.datetime(2023, 5, 9, 12, 54, 13, 723448, tzinfo=tzlocal()),
#               'as_at_modified': datetime.datetime(2023, 5, 9, 12, 54, 13, 723448, tzinfo=tzlocal()),
#               'as_at_version_number': 1,
#               'effective_from': datetime.datetime(1, 1, 1, 0, 0, tzinfo=tzlocal()),
#               'user_id_created': '00u4edvny74dXgwzK2p7',
#               'user_id_modified': '00u4edvny74dXgwzK2p7'}}]

# %% [markdown]
# ### Creating Portfolios

# %%
def create_portfolio(portfolio, overwrite=True):
    '''
    Input: 
        portfolio (dict): dictionary with fields 
                            'Code' == Code for the portfolio (str), 
                            'Display Name' == Display name of the identifier (str), 
                            'Base Currency' == Base Currency (str)
        overwrite (bool): whether to overwrite existing portfolio (hard-delete) in the provided code if it exists, defaults to True
    Output:
        resp (lusid.models.portfolio.Portfolio): Portfolio that was created
    '''
    port_req = models.CreateTransactionPortfolioRequest(code=portfolio['Code'],
                                                       display_name=portfolio['Display Name'],
                                                       base_currency=portfolio['Base Currency'],
                                                       created=date)
    
    ## Try creating portfolio, throws exception if already exists
    try:
        transaction_portfolios_api.create_portfolio(scope=scope,create_transaction_portfolio_request=port_req)
    except:
        if overwrite:
            portfolios_api.delete_portfolio(scope=scope,code=portfolio['Code'])
            transaction_portfolios_api.create_portfolio(scope=scope,create_transaction_portfolio_request=port_req)
    
    return portfolios_api.get_portfolio(scope=scope,code=portfolio['Code'])

created_portfolios = [create_portfolio(port.to_dict()) 
                      for i,port in portfolios.iterrows()]

created_portfolios
# Out:
# [{'accounting_method': 'Default',
#   'amortisation_method': 'NoAmortisation',
#   'base_currency': 'GBP',
#   'created': datetime.datetime(2021, 1, 1, 0, 0, tzinfo=tzlocal()),
#   'description': None,
#   'display_name': 'UK Equity Fund',
#   'href': 'https://fbn-ci.lusid.com/api/api/portfolios/Finbourne-Examples/UK-Equities?effectiveAt=2023-05-09T12%3A54%3A15.7244980%2B00%3A00&asAt=2023-05-09T12%3A54%3A15.3480880%2B00%3A00',
#   'id': {'code': 'UK-Equities', 'scope': 'Finbourne-Examples'},
#   'instrument_scopes': [],
#   'is_derived': False,
#   'links': [{'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/portfolios/Finbourne-Examples/UK-Equities/properties?effectiveAt=2023-05-09T12%3A54%3A15.7244980%2B00%3A00&asAt=2023-05-09T12%3A54%3A15.3480880%2B00%3A00',
#              'method': 'GET',
#              'relation': 'Properties'},
#             {'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/portfolios/Finbourne-Examples/UK-Equities/commands?toAsAt=2023-05-09T12%3A54%3A15.3480880%2B00%3A00',
#              'method': 'GET',
#              'relation': 'Commands'},
#             {'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/transactionportfolios/Finbourne-Examples/UK-Equities/details?effectiveAt=2023-05-09T12%3A54%3A15.7244980%2B00%3A00&asAt=2023-05-09T12%3A54%3A15.3480880%2B00%3A00',
#              'method': 'GET',
#              'relation': 'Details'},
#             {'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/transactionportfolios/Finbourne-Examples/UK-Equities/transactions?effectiveAt=2023-05-09T12%3A54%3A15.7244980%2B00%3A00&asAt=2023-05-09T12%3A54%3A15.3480880%2B00%3A00',
#              'method': 'GET',
#              'relation': 'Transactions'},
#             {'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/transactionportfolios/Finbourne-Examples/UK-Equities/holdings?effectiveAt=2023-05-09T12%3A54%3A15.7244980%2B00%3A00&asAt=2023-05-09T12%3A54%3A15.3480880%2B00%3A00',
#              'method': 'GET',
#              'relation': 'Holdings'},
#             {'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/transactionportfolios/Finbourne-Examples/UK-Equities/holdingsadjustments/2023-05-09T12%3A54%3A15.7244980%2B00%3A00?asAt=2023-05-09T12%3A54%3A15.3480880%2B00%3A00',
#              'method': 'GET',
#              'relation': 'HoldingsAdjustments'},
#             {'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/entities/Portfolio',
#              'method': 'GET',
#              'relation': 'EntitySchema'},
#             {'description': 'A link to the LUSID Insights website showing all '
#                             'logs related to this request',
#              'href': 'http://fbn-ci.lusid.com/app/insights/logs/0HMQGGAL4G34J:000000DE',
#              'method': 'GET',
#              'relation': 'RequestLogs'}],
#   'parent_portfolio_id': None,
#   'properties': {},
#   'relationships': [],
#   'type': 'Transaction',
#   'version': {'as_at_created': datetime.datetime(2023, 5, 9, 12, 54, 15, 348088, tzinfo=tzlocal()),
#               'as_at_date': datetime.datetime(2023, 5, 9, 12, 54, 15, 348088, tzinfo=tzlocal()),
#               'as_at_modified': datetime.datetime(2023, 5, 9, 12, 54, 15, 348088, tzinfo=tzlocal()),
#               'as_at_version_number': 1,
#               'effective_from': datetime.datetime(2023, 5, 9, 12, 54, 15, 724498, tzinfo=tzlocal()),
#               'user_id_created': '00u4edvny74dXgwzK2p7',
#               'user_id_modified': '00u4edvny74dXgwzK2p7'}},
#  {'accounting_method': 'Default',
#   'amortisation_method': 'NoAmortisation',
#   'base_currency': 'GBP',
#   'created': datetime.datetime(2021, 1, 1, 0, 0, tzinfo=tzlocal()),
#   'description': None,
#   'display_name': 'Global Equity Fund',
#   'href': 'https://fbn-ci.lusid.com/api/api/portfolios/Finbourne-Examples/Global-Equity?effectiveAt=2023-05-09T12%3A54%3A17.1821650%2B00%3A00&asAt=2023-05-09T12%3A54%3A16.7134140%2B00%3A00',
#   'id': {'code': 'Global-Equity', 'scope': 'Finbourne-Examples'},
#   'instrument_scopes': [],
#   'is_derived': False,
#   'links': [{'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/portfolios/Finbourne-Examples/Global-Equity/properties?effectiveAt=2023-05-09T12%3A54%3A17.1821650%2B00%3A00&asAt=2023-05-09T12%3A54%3A16.7134140%2B00%3A00',
#              'method': 'GET',
#              'relation': 'Properties'},
#             {'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/portfolios/Finbourne-Examples/Global-Equity/commands?toAsAt=2023-05-09T12%3A54%3A16.7134140%2B00%3A00',
#              'method': 'GET',
#              'relation': 'Commands'},
#             {'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/transactionportfolios/Finbourne-Examples/Global-Equity/details?effectiveAt=2023-05-09T12%3A54%3A17.1821650%2B00%3A00&asAt=2023-05-09T12%3A54%3A16.7134140%2B00%3A00',
#              'method': 'GET',
#              'relation': 'Details'},
#             {'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/transactionportfolios/Finbourne-Examples/Global-Equity/transactions?effectiveAt=2023-05-09T12%3A54%3A17.1821650%2B00%3A00&asAt=2023-05-09T12%3A54%3A16.7134140%2B00%3A00',
#              'method': 'GET',
#              'relation': 'Transactions'},
#             {'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/transactionportfolios/Finbourne-Examples/Global-Equity/holdings?effectiveAt=2023-05-09T12%3A54%3A17.1821650%2B00%3A00&asAt=2023-05-09T12%3A54%3A16.7134140%2B00%3A00',
#              'method': 'GET',
#              'relation': 'Holdings'},
#             {'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/transactionportfolios/Finbourne-Examples/Global-Equity/holdingsadjustments/2023-05-09T12%3A54%3A17.1821650%2B00%3A00?asAt=2023-05-09T12%3A54%3A16.7134140%2B00%3A00',
#              'method': 'GET',
#              'relation': 'HoldingsAdjustments'},
#             {'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/entities/Portfolio',
#              'method': 'GET',
#              'relation': 'EntitySchema'},
#             {'description': 'A link to the LUSID Insights website showing all '
#                             'logs related to this request',
#              'href': 'http://fbn-ci.lusid.com/app/insights/logs/0HMQGGAL4G34J:000000E1',
#              'method': 'GET',
#              'relation': 'RequestLogs'}],
#   'parent_portfolio_id': None,
#   'properties': {},
#   'relationships': [],
#   'type': 'Transaction',
#   'version': {'as_at_created': datetime.datetime(2023, 5, 9, 12, 54, 16, 713414, tzinfo=tzlocal()),
#               'as_at_date': datetime.datetime(2023, 5, 9, 12, 54, 16, 713414, tzinfo=tzlocal()),
#               'as_at_modified': datetime.datetime(2023, 5, 9, 12, 54, 16, 713414, tzinfo=tzlocal()),
#               'as_at_version_number': 1,
#               'effective_from': datetime.datetime(2023, 5, 9, 12, 54, 17, 182165, tzinfo=tzlocal()),
#               'user_id_created': '00u4edvny74dXgwzK2p7',
#               'user_id_modified': '00u4edvny74dXgwzK2p7'}},
#  {'accounting_method': 'Default',
#   'amortisation_method': 'NoAmortisation',
#   'base_currency': 'USD',
#   'created': datetime.datetime(2021, 1, 1, 0, 0, tzinfo=tzlocal()),
#   'description': None,
#   'display_name': 'US$ Treasury Bond Fund',
#   'href': 'https://fbn-ci.lusid.com/api/api/portfolios/Finbourne-Examples/US-Treasury-Bond?effectiveAt=2023-05-09T12%3A54%3A18.5384160%2B00%3A00&asAt=2023-05-09T12%3A54%3A18.1459390%2B00%3A00',
#   'id': {'code': 'US-Treasury-Bond', 'scope': 'Finbourne-Examples'},
#   'instrument_scopes': [],
#   'is_derived': False,
#   'links': [{'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/portfolios/Finbourne-Examples/US-Treasury-Bond/properties?effectiveAt=2023-05-09T12%3A54%3A18.5384160%2B00%3A00&asAt=2023-05-09T12%3A54%3A18.1459390%2B00%3A00',
#              'method': 'GET',
#              'relation': 'Properties'},
#             {'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/portfolios/Finbourne-Examples/US-Treasury-Bond/commands?toAsAt=2023-05-09T12%3A54%3A18.1459390%2B00%3A00',
#              'method': 'GET',
#              'relation': 'Commands'},
#             {'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/transactionportfolios/Finbourne-Examples/US-Treasury-Bond/details?effectiveAt=2023-05-09T12%3A54%3A18.5384160%2B00%3A00&asAt=2023-05-09T12%3A54%3A18.1459390%2B00%3A00',
#              'method': 'GET',
#              'relation': 'Details'},
#             {'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/transactionportfolios/Finbourne-Examples/US-Treasury-Bond/transactions?effectiveAt=2023-05-09T12%3A54%3A18.5384160%2B00%3A00&asAt=2023-05-09T12%3A54%3A18.1459390%2B00%3A00',
#              'method': 'GET',
#              'relation': 'Transactions'},
#             {'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/transactionportfolios/Finbourne-Examples/US-Treasury-Bond/holdings?effectiveAt=2023-05-09T12%3A54%3A18.5384160%2B00%3A00&asAt=2023-05-09T12%3A54%3A18.1459390%2B00%3A00',
#              'method': 'GET',
#              'relation': 'Holdings'},
#             {'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/transactionportfolios/Finbourne-Examples/US-Treasury-Bond/holdingsadjustments/2023-05-09T12%3A54%3A18.5384160%2B00%3A00?asAt=2023-05-09T12%3A54%3A18.1459390%2B00%3A00',
#              'method': 'GET',
#              'relation': 'HoldingsAdjustments'},
#             {'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/entities/Portfolio',
#              'method': 'GET',
#              'relation': 'EntitySchema'},
#             {'description': 'A link to the LUSID Insights website showing all '
#                             'logs related to this request',
#              'href': 'http://fbn-ci.lusid.com/app/insights/logs/0HMQGGAL4G34J:000000E5',
#              'method': 'GET',
#              'relation': 'RequestLogs'}],
#   'parent_portfolio_id': None,
#   'properties': {},
#   'relationships': [],
#   'type': 'Transaction',
#   'version': {'as_at_created': datetime.datetime(2023, 5, 9, 12, 54, 18, 145939, tzinfo=tzlocal()),
#               'as_at_date': datetime.datetime(2023, 5, 9, 12, 54, 18, 145939, tzinfo=tzlocal()),
#               'as_at_modified': datetime.datetime(2023, 5, 9, 12, 54, 18, 145939, tzinfo=tzlocal()),
#               'as_at_version_number': 1,
#               'effective_from': datetime.datetime(2023, 5, 9, 12, 54, 18, 538416, tzinfo=tzlocal()),
#               'user_id_created': '00u4edvny74dXgwzK2p7',
#               'user_id_modified': '00u4edvny74dXgwzK2p7'}},
#  {'accounting_method': 'Default',
#   'amortisation_method': 'NoAmortisation',
#   'base_currency': 'USD',
#   'created': datetime.datetime(2021, 1, 1, 0, 0, tzinfo=tzlocal()),
#   'description': None,
#   'display_name': 'US Corporate Bond Fund',
#   'href': 'https://fbn-ci.lusid.com/api/api/portfolios/Finbourne-Examples/US-Corporate-Bond?effectiveAt=2023-05-09T12%3A54%3A19.8760640%2B00%3A00&asAt=2023-05-09T12%3A54%3A19.4836860%2B00%3A00',
#   'id': {'code': 'US-Corporate-Bond', 'scope': 'Finbourne-Examples'},
#   'instrument_scopes': [],
#   'is_derived': False,
#   'links': [{'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/portfolios/Finbourne-Examples/US-Corporate-Bond/properties?effectiveAt=2023-05-09T12%3A54%3A19.8760640%2B00%3A00&asAt=2023-05-09T12%3A54%3A19.4836860%2B00%3A00',
#              'method': 'GET',
#              'relation': 'Properties'},
#             {'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/portfolios/Finbourne-Examples/US-Corporate-Bond/commands?toAsAt=2023-05-09T12%3A54%3A19.4836860%2B00%3A00',
#              'method': 'GET',
#              'relation': 'Commands'},
#             {'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/transactionportfolios/Finbourne-Examples/US-Corporate-Bond/details?effectiveAt=2023-05-09T12%3A54%3A19.8760640%2B00%3A00&asAt=2023-05-09T12%3A54%3A19.4836860%2B00%3A00',
#              'method': 'GET',
#              'relation': 'Details'},
#             {'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/transactionportfolios/Finbourne-Examples/US-Corporate-Bond/transactions?effectiveAt=2023-05-09T12%3A54%3A19.8760640%2B00%3A00&asAt=2023-05-09T12%3A54%3A19.4836860%2B00%3A00',
#              'method': 'GET',
#              'relation': 'Transactions'},
#             {'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/transactionportfolios/Finbourne-Examples/US-Corporate-Bond/holdings?effectiveAt=2023-05-09T12%3A54%3A19.8760640%2B00%3A00&asAt=2023-05-09T12%3A54%3A19.4836860%2B00%3A00',
#              'method': 'GET',
#              'relation': 'Holdings'},
#             {'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/transactionportfolios/Finbourne-Examples/US-Corporate-Bond/holdingsadjustments/2023-05-09T12%3A54%3A19.8760640%2B00%3A00?asAt=2023-05-09T12%3A54%3A19.4836860%2B00%3A00',
#              'method': 'GET',
#              'relation': 'HoldingsAdjustments'},
#             {'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/entities/Portfolio',
#              'method': 'GET',
#              'relation': 'EntitySchema'},
#             {'description': 'A link to the LUSID Insights website showing all '
#                             'logs related to this request',
#              'href': 'http://fbn-ci.lusid.com/app/insights/logs/0HMQGGAL4G34J:000000E9',
#              'method': 'GET',
#              'relation': 'RequestLogs'}],
#   'parent_portfolio_id': None,
#   'properties': {},
#   'relationships': [],
#   'type': 'Transaction',
#   'version': {'as_at_created': datetime.datetime(2023, 5, 9, 12, 54, 19, 483686, tzinfo=tzlocal()),
#               'as_at_date': datetime.datetime(2023, 5, 9, 12, 54, 19, 483686, tzinfo=tzlocal()),
#               'as_at_modified': datetime.datetime(2023, 5, 9, 12, 54, 19, 483686, tzinfo=tzlocal()),
#               'as_at_version_number': 1,
#               'effective_from': datetime.datetime(2023, 5, 9, 12, 54, 19, 876064, tzinfo=tzlocal()),
#               'user_id_created': '00u4edvny74dXgwzK2p7',
#               'user_id_modified': '00u4edvny74dXgwzK2p7'}}]

# %% [markdown]
# ### Creating Portfolio Groups

# %%
port_groups = groups[['Group Name', 'Display Name', 'Description','Created Date']].drop_duplicates().reset_index(drop=True)
port_groups['Sub-groups'] = [list(set(groups.query(f"`Group Name`=='{grp['Group Name']}' and `Display Name`=='{grp['Display Name']}' and Description == '{grp['Description']}' and `Created Date` == '{grp['Created Date']}' ").dropna(subset=['Sub-groups'])['Sub-groups'])) 
                            for i,grp in port_groups.iterrows()]
port_groups['Portfolios'] = [list(set(groups.query(f"`Group Name`=='{grp['Group Name']}' and `Display Name`=='{grp['Display Name']}' and Description == '{grp['Description']}' and `Created Date` == '{grp['Created Date']}' ").dropna(subset=['Portfolios'])['Portfolios'])) 
                            for i,grp in port_groups.iterrows()]
portfolio_groups = [port_groups.iloc[i].to_dict() for i in range(len(port_groups))]
portfolio_groups.reverse()

def create_portfolio_group(portfolio_group, overwrite=True):
    '''
    Input: 
        portfolio_group (dict): dictionary with fields 
                                'Group Name': code of the portfolio group (str),
                                'Display Name': Display name of the portfolio group (str),
                                'Description': Description of the portfolio group (str),
                                'Created Date': Date of creation in YYYY-MM-DDTHH:mm:ssZ (str),
                                'Sub-groups': list of codes of sub portfolio groups that must exist (list[(str)]),
                                'Portfolios': list of codes of portfolio that must exist (list[(str)])
        overwrite (bool): whether to overwrite existing portfolioGroup (hard-delete) in the provided code if it exists, defaults to True
    Output:
        resp (lusid.models.portfolio_group.PortfolioGroup): portfolio_group that was created
    '''
    port_grp_req = models.CreatePortfolioGroupRequest(code=portfolio_group['Group Name'],
                                                    created=portfolio_group['Created Date'],
                                                    values=[lusid.ResourceId(scope=scope, code = port) 
                                                            for port in portfolio_group['Portfolios']], 
                                                    sub_groups=[lusid.ResourceId(scope=scope, code = subGrp) 
                                                                for subGrp in portfolio_group['Sub-groups']],
                                                    description=portfolio_group['Description'],
                                                    display_name=portfolio_group['Display Name'])
    
    ## Try creating portfolio, throws exception if already exists
    try:
        portfolio_groups_api.create_portfolio_group(scope=scope,create_portfolio_group_request=port_grp_req)
    except:
        if overwrite:
            portfolio_groups_api.delete_portfolio_group(scope=scope, code= portfolio_group['Group Name'])
            portfolio_groups_api.create_portfolio_group(scope=scope,create_portfolio_group_request=port_grp_req)
    
    return portfolio_groups_api.get_portfolio_group(scope=scope, code= portfolio_group['Group Name'])

created_portfolio_groups = [create_portfolio_group(grp) 
                            for grp in portfolio_groups]
    
created_portfolio_groups
# Out:
# [{'created': datetime.datetime(2021, 1, 1, 0, 0, tzinfo=tzlocal()),
#   'description': 'Contains Finbourne US Fixed Income portfolios',
#   'display_name': 'US Fixed Income group',
#   'href': 'https://fbn-ci.lusid.com/api/api/portfoliogroups/Finbourne-Examples/US-FI?effectiveAt=2021-01-01T00%3A00%3A00.0000000%2B00%3A00&asAt=2023-05-09T12%3A54%3A20.7615180%2B00%3A00',
#   'id': {'code': 'US-FI', 'scope': 'Finbourne-Examples'},
#   'links': [{'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/entities/PortfolioGroup',
#              'method': 'GET',
#              'relation': 'EntitySchema'},
#             {'description': 'A link to the LUSID Insights website showing all '
#                             'logs related to this request',
#              'href': 'http://fbn-ci.lusid.com/app/insights/logs/0HMQGGAL4G36Q:000000CD',
#              'method': 'GET',
#              'relation': 'RequestLogs'}],
#   'portfolios': [{'code': 'US-Treasury-Bond', 'scope': 'Finbourne-Examples'},
#                  {'code': 'US-Corporate-Bond', 'scope': 'Finbourne-Examples'}],
#   'relationships': [],
#   'sub_groups': [],
#   'version': {'as_at_created': datetime.datetime(2023, 5, 9, 12, 54, 20, 761518, tzinfo=tzlocal()),
#               'as_at_date': datetime.datetime(2023, 5, 9, 12, 54, 20, 761518, tzinfo=tzlocal()),
#               'as_at_modified': datetime.datetime(2023, 5, 9, 12, 54, 20, 761518, tzinfo=tzlocal()),
#               'as_at_version_number': 1,
#               'effective_from': datetime.datetime(2021, 1, 1, 0, 0, tzinfo=tzlocal()),
#               'user_id_created': '00u4edvny74dXgwzK2p7',
#               'user_id_modified': '00u4edvny74dXgwzK2p7'}},
#  {'created': datetime.datetime(2021, 1, 1, 0, 0, tzinfo=tzlocal()),
#   'description': 'Contains Finbourne Examples portfolios',
#   'display_name': 'Finbourne Examples group',
#   'href': 'https://fbn-ci.lusid.com/api/api/portfoliogroups/Finbourne-Examples/Finbourne-Examples-Fund?effectiveAt=2021-01-01T00%3A00%3A00.0000000%2B00%3A00&asAt=2023-05-09T12%3A54%3A21.6382810%2B00%3A00',
#   'id': {'code': 'Finbourne-Examples-Fund', 'scope': 'Finbourne-Examples'},
#   'links': [{'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/entities/PortfolioGroup',
#              'method': 'GET',
#              'relation': 'EntitySchema'},
#             {'description': 'A link to the LUSID Insights website showing all '
#                             'logs related to this request',
#              'href': 'http://fbn-ci.lusid.com/app/insights/logs/0HMQGGAL4G34J:000000EF',
#              'method': 'GET',
#              'relation': 'RequestLogs'}],
#   'portfolios': [{'code': 'UK-Equities', 'scope': 'Finbourne-Examples'},
#                  {'code': 'Global-Equity', 'scope': 'Finbourne-Examples'}],
#   'relationships': [],
#   'sub_groups': [{'code': 'US-FI', 'scope': 'Finbourne-Examples'}],
#   'version': {'as_at_created': datetime.datetime(2023, 5, 9, 12, 54, 21, 638281, tzinfo=tzlocal()),
#               'as_at_date': datetime.datetime(2023, 5, 9, 12, 54, 21, 638281, tzinfo=tzlocal()),
#               'as_at_modified': datetime.datetime(2023, 5, 9, 12, 54, 21, 638281, tzinfo=tzlocal()),
#               'as_at_version_number': 1,
#               'effective_from': datetime.datetime(2021, 1, 1, 0, 0, tzinfo=tzlocal()),
#               'user_id_created': '00u4edvny74dXgwzK2p7',
#               'user_id_modified': '00u4edvny74dXgwzK2p7'}}]

# %% [markdown]
# ### Set Holdings

# %%
def set_holdings(scope, port, port_holdings):
    '''
    Input: 
        port_holdings (pandas.DataFrame): pandas dataframe with the following columns 
                                'Portfolio Code': code of the portfolio (str),
                                'instrument_uid': identifier of the instrument (identifierkey:value) (dict),
                                'Instrument Name': name of the instrument (str),
                                'Holding Type': type of the holding (str),
                                'units': number of the given instrument (float),
                                'price': price of the instrument (float),
                                'cost.currency': CCY code (str),
                                'purchase_date': purchase date in UTC (pandas._libs.tslibs.timestamps.Timestamp),
                                'settlement_date': settlmeent date in UTC (pandas._libs.tslibs.timestamps.Timestamp),
                                'cost.amount': cost of the transaction to get this holding in cost currency (float),
                                'portfolio_cost': cost of the transaction to get this holding in portfolio currency (float)
    Output:
        resp (lusid.models.adjust_holding.AdjustHolding): AdjustHolding response
    '''
    holdingsReq = [models.AdjustHoldingRequest(instrument_identifiers={hold['instrument_uid'].split(':')[0]:hold['instrument_uid'].split(':')[1]},
                                           tax_lots=[models.TargetTaxLotRequest(units=hold['units'],
                                                                                cost=models.CurrencyAndAmount(amount=hold['cost.amount'],
                                                                                                              currency=hold['cost.currency']),
                                                                                portfolio_cost=hold['portfolio_cost'],
                                                                                price=hold['price'],
                                                                                purchase_date=pytz.timezone('UTC').localize(hold['purchase_date'].to_pydatetime()).isoformat(),
                                                                                settlement_date=pytz.timezone('UTC').localize(hold['settlement_date'].to_pydatetime()).isoformat())],
                                          currency=hold['cost.currency']) 
               for i,hold in port_holdings.iterrows()]

    resp = transaction_portfolios_api.set_holdings(scope=scope,
                                          code=port,
                                          effective_at=date.isoformat(),
                                          adjust_holding_request=holdingsReq)
    return resp

set_holdings_response = [set_holdings(scope, port, holdings.query(f"`Portfolio Code` == '{port}'")) 
                         for port in holdings['Portfolio Code'].unique()]
    
set_holdings_response
# Out:
# [{'href': 'https://fbn-ci.lusid.com/api/api/transactionportfolios/Finbourne-Examples/Global-Equity/holdings?asAt=2023-05-09T12%3A54%3A16.7134140%2B00%3A00',
#   'links': [{'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/portfolios/Finbourne-Examples/Global-Equity?effectiveAt=2021-01-01T00%3A00%3A00.0000000%2B00%3A00&asAt=2023-05-09T12%3A54%3A16.7134140%2B00%3A00',
#              'method': 'GET',
#              'relation': 'Root'},
#             {'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/transactionportfolios/Finbourne-Examples/Global-Equity/holdings?effectiveAt=2021-01-01T00%3A00%3A00.0000000%2B00%3A00&asAt=2023-05-09T12%3A54%3A16.7134140%2B00%3A00',
#              'method': 'GET',
#              'relation': 'Holdings'},
#             {'description': 'A link to the LUSID Insights website showing all '
#                             'logs related to this request',
#              'href': 'http://fbn-ci.lusid.com/app/insights/logs/0HMQGGAL4G34J:000000F0',
#              'method': 'GET',
#              'relation': 'RequestLogs'}],
#   'metadata': {},
#   'version': {'as_at_created': datetime.datetime(2023, 5, 9, 12, 54, 16, 713414, tzinfo=tzlocal()),
#               'as_at_date': datetime.datetime(2023, 5, 9, 12, 54, 22, 875328, tzinfo=tzlocal()),
#               'as_at_modified': datetime.datetime(2023, 5, 9, 12, 54, 16, 713414, tzinfo=tzlocal()),
#               'as_at_version_number': 1,
#               'effective_from': datetime.datetime(2021, 1, 1, 0, 0, tzinfo=tzlocal()),
#               'user_id_created': '00u4edvny74dXgwzK2p7',
#               'user_id_modified': '00u4edvny74dXgwzK2p7'}},
#  {'href': 'https://fbn-ci.lusid.com/api/api/transactionportfolios/Finbourne-Examples/UK-Equities/holdings?asAt=2023-05-09T12%3A54%3A15.3480880%2B00%3A00',
#   'links': [{'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/portfolios/Finbourne-Examples/UK-Equities?effectiveAt=2021-01-01T00%3A00%3A00.0000000%2B00%3A00&asAt=2023-05-09T12%3A54%3A15.3480880%2B00%3A00',
#              'method': 'GET',
#              'relation': 'Root'},
#             {'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/transactionportfolios/Finbourne-Examples/UK-Equities/holdings?effectiveAt=2021-01-01T00%3A00%3A00.0000000%2B00%3A00&asAt=2023-05-09T12%3A54%3A15.3480880%2B00%3A00',
#              'method': 'GET',
#              'relation': 'Holdings'},
#             {'description': 'A link to the LUSID Insights website showing all '
#                             'logs related to this request',
#              'href': 'http://fbn-ci.lusid.com/app/insights/logs/0HMQGGAL4G34J:000000F1',
#              'method': 'GET',
#              'relation': 'RequestLogs'}],
#   'metadata': {},
#   'version': {'as_at_created': datetime.datetime(2023, 5, 9, 12, 54, 15, 348088, tzinfo=tzlocal()),
#               'as_at_date': datetime.datetime(2023, 5, 9, 12, 54, 23, 536786, tzinfo=tzlocal()),
#               'as_at_modified': datetime.datetime(2023, 5, 9, 12, 54, 15, 348088, tzinfo=tzlocal()),
#               'as_at_version_number': 1,
#               'effective_from': datetime.datetime(2021, 1, 1, 0, 0, tzinfo=tzlocal()),
#               'user_id_created': '00u4edvny74dXgwzK2p7',
#               'user_id_modified': '00u4edvny74dXgwzK2p7'}},
#  {'href': 'https://fbn-ci.lusid.com/api/api/transactionportfolios/Finbourne-Examples/US-Treasury-Bond/holdings?asAt=2023-05-09T12%3A54%3A18.1459390%2B00%3A00',
#   'links': [{'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/portfolios/Finbourne-Examples/US-Treasury-Bond?effectiveAt=2021-01-01T00%3A00%3A00.0000000%2B00%3A00&asAt=2023-05-09T12%3A54%3A18.1459390%2B00%3A00',
#              'method': 'GET',
#              'relation': 'Root'},
#             {'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/transactionportfolios/Finbourne-Examples/US-Treasury-Bond/holdings?effectiveAt=2021-01-01T00%3A00%3A00.0000000%2B00%3A00&asAt=2023-05-09T12%3A54%3A18.1459390%2B00%3A00',
#              'method': 'GET',
#              'relation': 'Holdings'},
#             {'description': 'A link to the LUSID Insights website showing all '
#                             'logs related to this request',
#              'href': 'http://fbn-ci.lusid.com/app/insights/logs/0HMQGGAL4G34J:000000F2',
#              'method': 'GET',
#              'relation': 'RequestLogs'}],
#   'metadata': {},
#   'version': {'as_at_created': datetime.datetime(2023, 5, 9, 12, 54, 18, 145939, tzinfo=tzlocal()),
#               'as_at_date': datetime.datetime(2023, 5, 9, 12, 54, 24, 311902, tzinfo=tzlocal()),
#               'as_at_modified': datetime.datetime(2023, 5, 9, 12, 54, 18, 145939, tzinfo=tzlocal()),
#               'as_at_version_number': 1,
#               'effective_from': datetime.datetime(2021, 1, 1, 0, 0, tzinfo=tzlocal()),
#               'user_id_created': '00u4edvny74dXgwzK2p7',
#               'user_id_modified': '00u4edvny74dXgwzK2p7'}},
#  {'href': 'https://fbn-ci.lusid.com/api/api/transactionportfolios/Finbourne-Examples/US-Corporate-Bond/holdings?asAt=2023-05-09T12%3A54%3A19.4836860%2B00%3A00',
#   'links': [{'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/portfolios/Finbourne-Examples/US-Corporate-Bond?effectiveAt=2021-01-01T00%3A00%3A00.0000000%2B00%3A00&asAt=2023-05-09T12%3A54%3A19.4836860%2B00%3A00',
#              'method': 'GET',
#              'relation': 'Root'},
#             {'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/transactionportfolios/Finbourne-Examples/US-Corporate-Bond/holdings?effectiveAt=2021-01-01T00%3A00%3A00.0000000%2B00%3A00&asAt=2023-05-09T12%3A54%3A19.4836860%2B00%3A00',
#              'method': 'GET',
#              'relation': 'Holdings'},
#             {'description': 'A link to the LUSID Insights website showing all '
#                             'logs related to this request',
#              'href': 'http://fbn-ci.lusid.com/app/insights/logs/0HMQGGAL4G34J:000000F3',
#              'method': 'GET',
#              'relation': 'RequestLogs'}],
#   'metadata': {},
#   'version': {'as_at_created': datetime.datetime(2023, 5, 9, 12, 54, 19, 483686, tzinfo=tzlocal()),
#               'as_at_date': datetime.datetime(2023, 5, 9, 12, 54, 25, 13732, tzinfo=tzlocal()),
#               'as_at_modified': datetime.datetime(2023, 5, 9, 12, 54, 19, 483686, tzinfo=tzlocal()),
#               'as_at_version_number': 1,
#               'effective_from': datetime.datetime(2021, 1, 1, 0, 0, tzinfo=tzlocal()),
#               'user_id_created': '00u4edvny74dXgwzK2p7',
#               'user_id_modified': '00u4edvny74dXgwzK2p7'}}]

# %% [markdown]
# ### Create Transactions

# %%
upsert_transaction_response = []

def upsert_transactions(scope, port, port_trans):
    '''
    Input: 
        port_trans (pandas.DataFrame): pandas dataframe with the following columns 
                                'Portfolio Code': code of the portfolio (str),
                                'transaction_id' : ID of this transaction (str),
                                'instrument_uid': identifier of the instrument (identifierkey:value) (dict),
                                'type' : type of this transaction (str),
                                'transaction_date' : transaction date in UTC (pandas._libs.tslibs.timestamps.Timestamp),
                                'settlement_date': settlement date in UTC (pandas._libs.tslibs.timestamps.Timestamp),
                                'units': number of the given instrument (float),
                                'total_consideration.currency' : CCY code (str),
                                'transaction_price.price' : price at which the instrument was transacted at (float),
                                'total_consideration.amount' : amount of the particular instrument transacted (float),
                                'source : source of this transaction (str)'
    Output:
        resp (lusid.models.adjust_holding.AdjustHolding): AdjustHolding response
    '''
    trans_req = [models.TransactionRequest(transaction_id=trans['transaction_id'], 
                                          type=trans['type'],
                                          instrument_identifiers={trans['instrument_uid'].split(':')[0]:trans['instrument_uid'].split(':')[1]}, 
                                          transaction_date=pytz.timezone('UTC').localize(trans['transaction_date'].to_pydatetime()).isoformat(),
                                          settlement_date=pytz.timezone('UTC').localize(trans['settlement_date'].to_pydatetime()).isoformat(), 
                                          units=trans['units'],
                                          transaction_price=models.TransactionPrice(price=trans['transaction_price.price']),
                                          total_consideration=models.CurrencyAndAmount(amount=trans['total_consideration.amount'],
                                                                                       currency=trans['total_consideration.currency']),
                                          source=trans['source'])
                for i,trans in port_trans.iterrows()]

    resp = transaction_portfolios_api.upsert_transactions(scope=scope,
                                                        code=port,
                                                        transaction_request=trans_req)
    return resp


upsert_transaction_response = [upsert_transactions(scope, port, transactions.query(f"`Portfolio Code` == '{port}'")) 
                               for port in transactions['Portfolio Code'].unique()]    

upsert_transaction_response
# Out:
# [{'href': 'https://fbn-ci.lusid.com/api/api/transactionportfolios/Finbourne-Examples/Global-Equity/transactions?asAt=2023-05-09T12%3A54%3A26.1059000%2B00%3A00',
#   'links': [{'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/portfolios/Finbourne-Examples/Global-Equity?effectiveAt=2021-05-02T00%3A00%3A00.0000000%2B00%3A00&asAt=2023-05-09T12%3A54%3A26.1059000%2B00%3A00',
#              'method': 'GET',
#              'relation': 'Root'},
#             {'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/entities/UpsertPortfolioTransactionsResponse',
#              'method': 'GET',
#              'relation': 'EntitySchema'},
#             {'description': 'A link to the LUSID Insights website showing all '
#                             'logs related to this request',
#              'href': 'http://fbn-ci.lusid.com/app/insights/logs/0HMQGGAL4G383:00000020',
#              'method': 'GET',
#              'relation': 'RequestLogs'}],
#   'metadata': {},
#   'version': {'as_at_created': datetime.datetime(2023, 5, 9, 12, 54, 16, 713414, tzinfo=tzlocal()),
#               'as_at_date': datetime.datetime(2023, 5, 9, 12, 54, 26, 105900, tzinfo=tzlocal()),
#               'as_at_modified': datetime.datetime(2023, 5, 9, 12, 54, 16, 713414, tzinfo=tzlocal()),
#               'as_at_version_number': 1,
#               'effective_from': datetime.datetime(2021, 5, 2, 0, 0, tzinfo=tzlocal()),
#               'user_id_created': '00u4edvny74dXgwzK2p7',
#               'user_id_modified': '00u4edvny74dXgwzK2p7'}},
#  {'href': 'https://fbn-ci.lusid.com/api/api/transactionportfolios/Finbourne-Examples/UK-Equities/transactions?asAt=2023-05-09T12%3A54%3A27.0256190%2B00%3A00',
#   'links': [{'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/portfolios/Finbourne-Examples/UK-Equities?effectiveAt=2021-04-15T00%3A00%3A00.0000000%2B00%3A00&asAt=2023-05-09T12%3A54%3A27.0256190%2B00%3A00',
#              'method': 'GET',
#              'relation': 'Root'},
#             {'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/entities/UpsertPortfolioTransactionsResponse',
#              'method': 'GET',
#              'relation': 'EntitySchema'},
#             {'description': 'A link to the LUSID Insights website showing all '
#                             'logs related to this request',
#              'href': 'http://fbn-ci.lusid.com/app/insights/logs/0HMQGGAL4G34J:000000F4',
#              'method': 'GET',
#              'relation': 'RequestLogs'}],
#   'metadata': {},
#   'version': {'as_at_created': datetime.datetime(2023, 5, 9, 12, 54, 15, 348088, tzinfo=tzlocal()),
#               'as_at_date': datetime.datetime(2023, 5, 9, 12, 54, 27, 25619, tzinfo=tzlocal()),
#               'as_at_modified': datetime.datetime(2023, 5, 9, 12, 54, 15, 348088, tzinfo=tzlocal()),
#               'as_at_version_number': 1,
#               'effective_from': datetime.datetime(2021, 4, 15, 0, 0, tzinfo=tzlocal()),
#               'user_id_created': '00u4edvny74dXgwzK2p7',
#               'user_id_modified': '00u4edvny74dXgwzK2p7'}},
#  {'href': 'https://fbn-ci.lusid.com/api/api/transactionportfolios/Finbourne-Examples/US-Treasury-Bond/transactions?asAt=2023-05-09T12%3A54%3A28.0933910%2B00%3A00',
#   'links': [{'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/portfolios/Finbourne-Examples/US-Treasury-Bond?effectiveAt=2021-04-15T00%3A00%3A00.0000000%2B00%3A00&asAt=2023-05-09T12%3A54%3A28.0933910%2B00%3A00',
#              'method': 'GET',
#              'relation': 'Root'},
#             {'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/entities/UpsertPortfolioTransactionsResponse',
#              'method': 'GET',
#              'relation': 'EntitySchema'},
#             {'description': 'A link to the LUSID Insights website showing all '
#                             'logs related to this request',
#              'href': 'http://fbn-ci.lusid.com/app/insights/logs/0HMQGGAL4G36Q:000000D4',
#              'method': 'GET',
#              'relation': 'RequestLogs'}],
#   'metadata': {},
#   'version': {'as_at_created': datetime.datetime(2023, 5, 9, 12, 54, 18, 145939, tzinfo=tzlocal()),
#               'as_at_date': datetime.datetime(2023, 5, 9, 12, 54, 28, 93391, tzinfo=tzlocal()),
#               'as_at_modified': datetime.datetime(2023, 5, 9, 12, 54, 18, 145939, tzinfo=tzlocal()),
#               'as_at_version_number': 1,
#               'effective_from': datetime.datetime(2021, 4, 15, 0, 0, tzinfo=tzlocal()),
#               'user_id_created': '00u4edvny74dXgwzK2p7',
#               'user_id_modified': '00u4edvny74dXgwzK2p7'}},
#  {'href': 'https://fbn-ci.lusid.com/api/api/transactionportfolios/Finbourne-Examples/US-Corporate-Bond/transactions?asAt=2023-05-09T12%3A54%3A29.1424960%2B00%3A00',
#   'links': [{'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/portfolios/Finbourne-Examples/US-Corporate-Bond?effectiveAt=2021-04-15T00%3A00%3A00.0000000%2B00%3A00&asAt=2023-05-09T12%3A54%3A29.1424960%2B00%3A00',
#              'method': 'GET',
#              'relation': 'Root'},
#             {'description': None,
#              'href': 'https://fbn-ci.lusid.com/api/api/schemas/entities/UpsertPortfolioTransactionsResponse',
#              'method': 'GET',
#              'relation': 'EntitySchema'},
#             {'description': 'A link to the LUSID Insights website showing all '
#                             'logs related to this request',
#              'href': 'http://fbn-ci.lusid.com/app/insights/logs/0HMQGGAL4G383:00000023',
#              'method': 'GET',
#              'relation': 'RequestLogs'}],
#   'metadata': {},
#   'version': {'as_at_created': datetime.datetime(2023, 5, 9, 12, 54, 19, 483686, tzinfo=tzlocal()),
#               'as_at_date': datetime.datetime(2023, 5, 9, 12, 54, 29, 142496, tzinfo=tzlocal()),
#               'as_at_modified': datetime.datetime(2023, 5, 9, 12, 54, 19, 483686, tzinfo=tzlocal()),
#               'as_at_version_number': 1,
#               'effective_from': datetime.datetime(2021, 4, 15, 0, 0, tzinfo=tzlocal()),
#               'user_id_created': '00u4edvny74dXgwzK2p7',
#               'user_id_modified': '00u4edvny74dXgwzK2p7'}}]

# %% [markdown]
# ### Create Quotes

# %%
quotes_req = {
    f"{quote['instrument_uid']}-{str(quote['effective_at'])}-{quote['field']}":
    lusid.UpsertQuoteRequest(
        quote_id=lusid.QuoteId(
            quote_series_id = lusid.QuoteSeriesId(provider = quote['provider'],
                                                  price_source=quote["source"],
                                                  instrument_id = quote['instrument_uid'], 
                                                  instrument_id_type=quote['instrument_uid_type'], 
                                                  quote_type=quote['quote_type'], 
                                                  field=quote['field']),
            effective_at= pytz.timezone('UTC').localize(quote['effective_at'].to_pydatetime()).isoformat()), 
        metric_value=lusid.MetricValue(value=quote['metric_value'],
                                       unit=quote['metric_unit']))
    for i,quote in quotes.iterrows()
}
    
## Upserting Quotes
quote_numbers = len(quotes_req)
max_per_upsert = 500
number_of_Req = quote_numbers/max_per_upsert
quote_keys = list(quotes_req.keys())
upsert_results = []
for i in range(int(number_of_Req)):
    request_keys = quote_keys[i*max_per_upsert : (i+1)*max_per_upsert]
    request = dict(zip(request_keys, [quotes_req[key] for key in request_keys]))
    upsert_results.append(quotes_api.upsert_quotes(scope=market_data_scope, request_body=request))
    
if quote_numbers - ((i+1)*max_per_upsert) > 0:
    request_keys = quote_keys[((i+1)*max_per_upsert) : ]
    request = dict(zip(request_keys, [quotes_req[key] for key in request_keys]))
    upsert_results.append(quotes_api.upsert_quotes(scope=market_data_scope, request_body=request))

    
print("Failures: ", [i.failed for i in upsert_results])
# Out:
# Failures:  [{}, {}, {}, {}, {}]

# %% [markdown]
# ### Create FX Rates

# %%
rates_req = {
    f"{rate['instrument_uid']}-{str(rate['effective_at'])}-{rate['field']}" :
    lusid.UpsertQuoteRequest(
        quote_id=lusid.QuoteId(
            quote_series_id = lusid.QuoteSeriesId(provider = 'Client', 
                                                  price_source=rate["source"],
                                                  instrument_id = rate['instrument_uid'], 
                                                  instrument_id_type=rate['instrument_uid_type'], 
                                                  quote_type=rate['quote_type'], 
                                                  field=rate['field']),
            effective_at = pytz.timezone('UTC').localize(rate['effective_at'].to_pydatetime()).isoformat()), 
        metric_value=lusid.MetricValue(value=rate['metric_value'],
                                       unit=rate['metric_unit']))
    for i,rate in rates.iterrows()
}

## Upserting Quotes
quote_numbers = len(rates_req)
max_per_upsert = 500
number_of_Req = quote_numbers/max_per_upsert
quote_keys = list(rates_req.keys())
upsert_results = []
for i in range(int(number_of_Req)):
    request_keys = quote_keys[i*max_per_upsert : (i+1)*max_per_upsert]
    request = dict(zip(request_keys, [rates_req[key] for key in request_keys]))
    upsert_results.append(quotes_api.upsert_quotes(scope=market_data_scope, request_body=request))
    
if quote_numbers - ((i+1)*max_per_upsert) > 0:
    request_keys = quote_keys[((i+1)*max_per_upsert) : ]
    request = dict(zip(request_keys, [rates_req[key] for key in request_keys]))
    upsert_results.append(quotes_api.upsert_quotes(scope=market_data_scope, request_body=request))

    
print("Failures: ", [i.failed for i in upsert_results])
# Out:
# Failures:  [{}, {}, {}, {}, {}]

# %% [markdown]
# ### Create Recipes

# %%
created_recipes = []

def create_recipe(code, rec_rules):
    '''
    Input: 
        rec_rules (pandas.DataFrame): pandas dataframe with the following columns 
                                'Description' : description of the recipe (str),
                                'Key' : market data key (str),
                                'Supplier' : supplier of the market data (str),
                                'QuoteType' : type of the quote (str),
                                'QuoteInterval' : interval of the quote (str),
                                'Field' : field of the quote (str)
    Output:
        resp (lusid.models.adjust_holding.AdjustHolding): AdjustHolding response
    '''
    description = rec_rules.Description.unique()[0]
    supplier = "Client" #rec_rules.Supplier.unique()[0]
    recipe_req = models.UpsertRecipeRequest(
                        configuration_recipe=lusid.ConfigurationRecipe(
                            scope=scope,
                            code=code,
                            description=description,
                            market=models.MarketContext(market_rules=[
                                models.MarketDataKeyRule(key=rule['Key'],
                                   supplier=rule['Supplier'],
                                   data_scope=market_data_scope,
                                   quote_type=rule['QuoteType'],
                                   field=rule['Field'],
                                   quote_interval=rule['QuoteInterval'])
                            for i,rule in rec_rules.iterrows()],
                            suppliers=lusid.MarketContextSuppliers(
                                commodity=supplier,
                                credit=supplier,
                                equity=supplier,
                                fx=supplier,
                                rates=supplier),
                           options=models.MarketOptions(
                                default_supplier='DataScope',
                                default_instrument_code_type='Figi',
                                default_scope=market_data_scope)
                               )
                        )
                ) 

    configuration_recipe_api.upsert_configuration_recipe(upsert_recipe_request = recipe_req)
    return configuration_recipe_api.get_configuration_recipe(scope=scope, code=code)

created_recipes = [create_recipe(rec, recipes.query(f"Code == '{rec}'")) 
                   for rec in recipes['Code'].unique()]

created_recipes
# Out:
# [{'href': None,
#   'links': [{'description': 'A link to the LUSID Insights website showing all '
#                             'logs related to this request',
#              'href': 'http://fbn-ci.lusid.com/app/insights/logs/0HMQGGAL4G383:0000003D',
#              'method': 'GET',
#              'relation': 'RequestLogs'}],
#   'value': {'aggregation': {'options': {'allow_partial_entitlement_success': False,
#                                         'apply_iso4217_rounding': False,
#                                         'use_ansi_like_syntax': False}},
#             'code': 'FinbourneExamplesRecipeMidThenBid',
#             'description': 'For each instrument (Equity and Fx) use Mid Price '
#                            'if available, Bid if not',
#             'holding': {'tax_lot_level_holdings': True},
#             'inherited_recipes': [],
#             'market': {'market_rules': [{'as_at': None,
#                                          'data_scope': 'FinbourneMarketData',
#                                          'field': 'Mid',
#                                          'key': 'Equity.Figi.*',
#                                          'mask': None,
#                                          'price_source': '',
#                                          'quote_interval': '10Y.0D',
#                                          'quote_type': 'Price',
#                                          'source_system': 'Lusid',
#                                          'supplier': 'Client'},
#                                         {'as_at': None,
#                                          'data_scope': 'FinbourneMarketData',
#                                          'field': 'Bid',
#                                          'key': 'Equity.Figi.*',
#                                          'mask': None,
#                                          'price_source': '',
#                                          'quote_interval': '10Y.0D',
#                                          'quote_type': 'Price',
#                                          'source_system': 'Lusid',
#                                          'supplier': 'Client'},
#                                         {'as_at': None,
#                                          'data_scope': 'FinbourneMarketData',
#                                          'field': 'Mid',
#                                          'key': 'Equity.LusidInstrumentId.*',
#                                          'mask': None,
#                                          'price_source': '',
#                                          'quote_interval': '10Y.0D',
#                                          'quote_type': 'Price',
#                                          'source_system': 'Lusid',
#                                          'supplier': 'Client'},
#                                         {'as_at': None,
#                                          'data_scope': 'FinbourneMarketData',
#                                          'field': 'Bid',
#                                          'key': 'Equity.LusidInstrumentId.*',
#                                          'mask': None,
#                                          'price_source': '',
#                                          'quote_interval': '10Y.0D',
#                                          'quote_type': 'Price',
#                                          'source_system': 'Lusid',
#                                          'supplier': 'Client'},
#                                         {'as_at': None,
#                                          'data_scope': 'FinbourneMarketData',
#                                          'field': 'Mid',
#                                          'key': 'Fx.CurrencyPair.*',
#                                          'mask': None,
#                                          'price_source': '',
#                                          'quote_interval': '10Y.0D',
#                                          'quote_type': 'Price',
#                                          'source_system': 'Lusid',
#                                          'supplier': 'Client'},
#                                         {'as_at': None,
#                                          'data_scope': 'FinbourneMarketData',
#                                          'field': 'Bid',
#                                          'key': 'Fx.CurrencyPair.*',
#                                          'mask': None,
#                                          'price_source': '',
#                                          'quote_interval': '10Y.0D',
#                                          'quote_type': 'Price',
#                                          'source_system': 'Lusid',
#                                          'supplier': 'Client'}],
#                        'options': {'attempt_to_infer_missing_fx': False,
#                                    'calendar_scope': 'CoppClarkHolidayCalendars',
#                                    'convention_scope': 'Conventions',
#                                    'default_instrument_code_type': 'Figi',
#                                    'default_scope': 'FinbourneMarketData',
#                                    'default_supplier': 'DataScope'},
#                        'specific_rules': [],
#                        'suppliers': {'commodity': 'Client',
#                                      'credit': 'Client',
#                                      'equity': 'Client',
#                                      'fx': 'Client',
#                                      'rates': 'Client'}},
#             'pricing': {'model_choice': {},
#                         'model_rules': [],
#                         'options': {'allow_any_instruments_with_sec_uid_to_price_off_lookup': False,
#                                     'allow_partially_successful_evaluation': False,
#                                     'conserved_quantity_for_lookthrough_expansion': 'PV',
#                                     'enable_use_of_cached_unit_results': False,
#                                     'model_selection': {'library': 'Lusid',
#                                                         'model': 'SimpleStatic'},
#                                     'produce_separate_result_for_linear_otc_legs': False,
#                                     'remove_contingent_cashflows_in_payment_diary': False,
#                                     'use_child_sub_holding_keys_for_portfolio_expansion': False,
#                                     'use_instrument_type_to_determine_pricer': False,
#                                     'validate_domestic_and_quote_currencies_are_consistent': False,
#                                     'window_valuation_on_instrument_start_end': False},
#                         'result_data_rules': []},
#             'scope': 'Finbourne-Examples'}},
#  {'href': None,
#   'links': [{'description': 'A link to the LUSID Insights website showing all '
#                             'logs related to this request',
#              'href': 'http://fbn-ci.lusid.com/app/insights/logs/0HMQGGAL4G36U:000000A6',
#              'method': 'GET',
#              'relation': 'RequestLogs'}],
#   'value': {'aggregation': {'options': {'allow_partial_entitlement_success': False,
#                                         'apply_iso4217_rounding': False,
#                                         'use_ansi_like_syntax': False}},
#             'code': 'FinbourneExamplesRecipeBidThenMid',
#             'description': 'For each instrument (Equity and Fx) use Bid Price '
#                            'if available, Mid if not',
#             'holding': {'tax_lot_level_holdings': True},
#             'inherited_recipes': [],
#             'market': {'market_rules': [{'as_at': None,
#                                          'data_scope': 'FinbourneMarketData',
#                                          'field': 'Bid',
#                                          'key': 'Equity.Figi.*',
#                                          'mask': None,
#                                          'price_source': '',
#                                          'quote_interval': '10Y.0D',
#                                          'quote_type': 'Price',
#                                          'source_system': 'Lusid',
#                                          'supplier': 'Client'},
#                                         {'as_at': None,
#                                          'data_scope': 'FinbourneMarketData',
#                                          'field': 'Mid',
#                                          'key': 'Equity.Figi.*',
#                                          'mask': None,
#                                          'price_source': '',
#                                          'quote_interval': '10Y.0D',
#                                          'quote_type': 'Price',
#                                          'source_system': 'Lusid',
#                                          'supplier': 'Client'},
#                                         {'as_at': None,
#                                          'data_scope': 'FinbourneMarketData',
#                                          'field': 'Bid',
#                                          'key': 'Equity.LusidInstrumentId.*',
#                                          'mask': None,
#                                          'price_source': '',
#                                          'quote_interval': '10Y.0D',
#                                          'quote_type': 'Price',
#                                          'source_system': 'Lusid',
#                                          'supplier': 'Client'},
#                                         {'as_at': None,
#                                          'data_scope': 'FinbourneMarketData',
#                                          'field': 'Mid',
#                                          'key': 'Equity.LusidInstrumentId.*',
#                                          'mask': None,
#                                          'price_source': '',
#                                          'quote_interval': '10Y.0D',
#                                          'quote_type': 'Price',
#                                          'source_system': 'Lusid',
#                                          'supplier': 'Client'},
#                                         {'as_at': None,
#                                          'data_scope': 'FinbourneMarketData',
#                                          'field': 'Bid',
#                                          'key': 'Fx.CurrencyPair.*',
#                                          'mask': None,
#                                          'price_source': '',
#                                          'quote_interval': '10Y.0D',
#                                          'quote_type': 'Price',
#                                          'source_system': 'Lusid',
#                                          'supplier': 'Client'},
#                                         {'as_at': None,
#                                          'data_scope': 'FinbourneMarketData',
#                                          'field': 'Mid',
#                                          'key': 'Fx.CurrencyPair.*',
#                                          'mask': None,
#                                          'price_source': '',
#                                          'quote_interval': '10Y.0D',
#                                          'quote_type': 'Price',
#                                          'source_system': 'Lusid',
#                                          'supplier': 'Client'}],
#                        'options': {'attempt_to_infer_missing_fx': False,
#                                    'calendar_scope': 'CoppClarkHolidayCalendars',
#                                    'convention_scope': 'Conventions',
#                                    'default_instrument_code_type': 'Figi',
#                                    'default_scope': 'FinbourneMarketData',
#                                    'default_supplier': 'DataScope'},
#                        'specific_rules': [],
#                        'suppliers': {'commodity': 'Client',
#                                      'credit': 'Client',
#                                      'equity': 'Client',
#                                      'fx': 'Client',
#                                      'rates': 'Client'}},
#             'pricing': {'model_choice': {},
#                         'model_rules': [],
#                         'options': {'allow_any_instruments_with_sec_uid_to_price_off_lookup': False,
#                                     'allow_partially_successful_evaluation': False,
#                                     'conserved_quantity_for_lookthrough_expansion': 'PV',
#                                     'enable_use_of_cached_unit_results': False,
#                                     'model_selection': {'library': 'Lusid',
#                                                         'model': 'SimpleStatic'},
#                                     'produce_separate_result_for_linear_otc_legs': False,
#                                     'remove_contingent_cashflows_in_payment_diary': False,
#                                     'use_child_sub_holding_keys_for_portfolio_expansion': False,
#                                     'use_instrument_type_to_determine_pricer': False,
#                                     'validate_domestic_and_quote_currencies_are_consistent': False,
#                                     'window_valuation_on_instrument_start_end': False},
#                         'result_data_rules': []},
#             'scope': 'Finbourne-Examples'}},
#  {'href': None,
#   'links': [{'description': 'A link to the LUSID Insights website showing all '
#                             'logs related to this request',
#              'href': 'http://fbn-ci.lusid.com/app/insights/logs/0HMQGGAL4G383:00000040',
#              'method': 'GET',
#              'relation': 'RequestLogs'}],
#   'value': {'aggregation': {'options': {'allow_partial_entitlement_success': False,
#                                         'apply_iso4217_rounding': False,
#                                         'use_ansi_like_syntax': False}},
#             'code': 'FinbourneExamplesRecipeLusidFlatFX',
#             'description': 'Change supplier to Lusid for FX, to show an '
#                            'arbitrary constant FX rate',
#             'holding': {'tax_lot_level_holdings': True},
#             'inherited_recipes': [],
#             'market': {'market_rules': [{'as_at': None,
#                                          'data_scope': 'FinbourneMarketData',
#                                          'field': 'Mid',
#                                          'key': 'Equity.Figi.*',
#                                          'mask': None,
#                                          'price_source': '',
#                                          'quote_interval': '10Y.0D',
#                                          'quote_type': 'Price',
#                                          'source_system': 'Lusid',
#                                          'supplier': 'Lusid'},
#                                         {'as_at': None,
#                                          'data_scope': 'FinbourneMarketData',
#                                          'field': 'Mid',
#                                          'key': 'Equity.LusidInstrumentId.*',
#                                          'mask': None,
#                                          'price_source': '',
#                                          'quote_interval': '10Y.0D',
#                                          'quote_type': 'Price',
#                                          'source_system': 'Lusid',
#                                          'supplier': 'Lusid'},
#                                         {'as_at': None,
#                                          'data_scope': 'FinbourneMarketData',
#                                          'field': 'Mid',
#                                          'key': 'Fx.CurrencyPair.*',
#                                          'mask': None,
#                                          'price_source': '',
#                                          'quote_interval': '10Y.0D',
#                                          'quote_type': 'Price',
#                                          'source_system': 'Lusid',
#                                          'supplier': 'Lusid'}],
#                        'options': {'attempt_to_infer_missing_fx': False,
#                                    'calendar_scope': 'CoppClarkHolidayCalendars',
#                                    'convention_scope': 'Conventions',
#                                    'default_instrument_code_type': 'Figi',
#                                    'default_scope': 'FinbourneMarketData',
#                                    'default_supplier': 'DataScope'},
#                        'specific_rules': [],
#                        'suppliers': {'commodity': 'Client',
#                                      'credit': 'Client',
#                                      'equity': 'Client',
#                                      'fx': 'Client',
#                                      'rates': 'Client'}},
#             'pricing': {'model_choice': {},
#                         'model_rules': [],
#                         'options': {'allow_any_instruments_with_sec_uid_to_price_off_lookup': False,
#                                     'allow_partially_successful_evaluation': False,
#                                     'conserved_quantity_for_lookthrough_expansion': 'PV',
#                                     'enable_use_of_cached_unit_results': False,
#                                     'model_selection': {'library': 'Lusid',
#                                                         'model': 'SimpleStatic'},
#                                     'produce_separate_result_for_linear_otc_legs': False,
#                                     'remove_contingent_cashflows_in_payment_diary': False,
#                                     'use_child_sub_holding_keys_for_portfolio_expansion': False,
#                                     'use_instrument_type_to_determine_pricer': False,
#                                     'validate_domestic_and_quote_currencies_are_consistent': False,
#                                     'window_valuation_on_instrument_start_end': False},
#                         'result_data_rules': []},
#             'scope': 'Finbourne-Examples'}}]

# %%
[i.value.code for i in created_recipes]
# Out:
# ['FinbourneExamplesRecipeMidThenBid',
#  'FinbourneExamplesRecipeBidThenMid',
#  'FinbourneExamplesRecipeLusidFlatFX']

# %% [markdown]
# ### Test Aggregation using created Recipe

# %%
AGG_INSTR = "Instrument/default/Name"
AGG_UID = "Instrument/default/LusidInstrumentId"
AGG_PV = "Holding/default/PV"
AGG_PRC = "Holding/default/Price"
AGG_UNITS = "Holding/default/Units"
AGG_COST = "Holding/default/Cost"
AGG_TYPE = "Holding/default/Type"
AGG_RATE = "Holding/default/ExchangeRate"


metrics = [
    models.AggregateSpec(AGG_INSTR, "Value"),
    models.AggregateSpec(AGG_UID, "Value"),
    models.AggregateSpec(AGG_TYPE, "Value"),
    models.AggregateSpec(AGG_PV, "Value"),
    models.AggregateSpec(AGG_UNITS, "Value"),
    models.AggregateSpec(AGG_COST, "Value"),
    models.AggregateSpec(AGG_RATE, "Value"),
    models.AggregateSpec(AGG_PRC, "Value"),
    ]


valuation_request = models.ValuationRequest(
    recipe_id=models.ResourceId(scope, created_recipes[0].value.code),
    valuation_schedule=models.ValuationSchedule(effective_at=pd.to_datetime('2021-05-17', utc=True).isoformat()),
    portfolio_entity_ids=[
        models.PortfolioEntityId(
                scope=created_portfolios[1].id.scope,
                code=created_portfolios[1].id.code,
                portfolio_entity_type="SinglePortfolio")
    ],
    metrics=metrics
)

valuations_api.get_valuation(valuation_request=valuation_request)
# Out:
# {'aggregation_as_at': datetime.datetime(2023, 5, 9, 12, 54, 58, 892719, tzinfo=tzlocal()),
#  'aggregation_currency': 'GBP',
#  'aggregation_effective_at': datetime.datetime(2021, 5, 17, 0, 0, tzinfo=tzlocal()),
#  'aggregation_failures': [],
#  'data': [{'Holding/default/Cost': 2390760000.0,
#            'Holding/default/ExchangeRate': 1.0,
#            'Holding/default/PV': 2268000000.0,
#            'Holding/default/Price': 189.0,
#            'Holding/default/Type': 'Position',
#            'Holding/default/Units': 12000000.0,
#            'Instrument/default/LusidInstrumentId': 'LUID_00070D4R',
#            'Instrument/default/Name': 'Apple'},
#           {'Holding/default/Cost': 2379056470.59,
#            'Holding/default/ExchangeRate': 1.0,
#            'Holding/default/PV': 2365265294.117647,
#            'Holding/default/Price': 110.77,
#            'Holding/default/Type': 'Position',
#            'Holding/default/Units': 21352941.17647059,
#            'Instrument/default/LusidInstrumentId': 'LUID_00070D4S',
#            'Instrument/default/Name': 'JPMorgan Chase'},
#           {'Holding/default/Cost': 1390072117.65,
#            'Holding/default/ExchangeRate': 1.0,
#            'Holding/default/PV': 1633331764.7058823,
#            'Holding/default/Price': 556.0,
#            'Holding/default/Type': 'Position',
#            'Holding/default/Units': 2937647.0588235296,
#            'Instrument/default/LusidInstrumentId': 'LUID_00070D4T',
#            'Instrument/default/Name': 'BP'},
#           {'Holding/default/Cost': 1257652294.12,
#            'Holding/default/ExchangeRate': 1.0,
#            'Holding/default/PV': 1156719882.3529413,
#            'Holding/default/Price': 74.3,
#            'Holding/default/Type': 'Position',
#            'Holding/default/Units': 15568235.294117646,
#            'Instrument/default/LusidInstrumentId': 'LUID_00070D4U',
#            'Instrument/default/Name': 'Anheuser-Busch InBev'},
#           {'Holding/default/Cost': 71971057729.0,
#            'Holding/default/ExchangeRate': 1.0,
#            'Holding/default/PV': 71434758458.82353,
#            'Holding/default/Price': 6502.0,
#            'Holding/default/Type': 'Position',
#            'Holding/default/Units': 10986582.352941176,
#            'Instrument/default/LusidInstrumentId': 'LUID_00070D4V',
#            'Instrument/default/Name': 'Toyota Motor'},
#           {'Holding/default/Cost': 1329858354.41,
#            'Holding/default/ExchangeRate': 1.0,
#            'Holding/default/PV': 1256862974.7058823,
#            'Holding/default/Price': 149.8,
#            'Holding/default/Type': 'Position',
#            'Holding/default/Units': 8390273.529411765,
#            'Instrument/default/LusidInstrumentId': 'LUID_00070D4W',
#            'Instrument/default/Name': 'Volkswagen'},
#           {'Holding/default/Cost': 310973764.71,
#            'Holding/default/ExchangeRate': 1.0,
#            'Holding/default/PV': 310404823.52941173,
#            'Holding/default/Price': 654.7,
#            'Holding/default/Type': 'Position',
#            'Holding/default/Units': 474117.6470588235,
#            'Instrument/default/LusidInstrumentId': 'LUID_00070D4X',
#            'Instrument/default/Name': 'HSBC Holdings'},
#           {'Holding/default/Cost': -1092849358.82,
#            'Holding/default/ExchangeRate': 1.0,
#            'Holding/default/PV': -1106176188.235294,
#            'Holding/default/Price': 135.04,
#            'Holding/default/Type': 'Position',
#            'Holding/default/Units': -8191470.588235294,
#            'Instrument/default/LusidInstrumentId': 'LUID_00070D4Y',
#            'Instrument/default/Name': 'Walt Disney'},
#           {'Holding/default/Cost': 1314567397.06,
#            'Holding/default/ExchangeRate': 1.0,
#            'Holding/default/PV': 1390802532.3529413,
#            'Holding/default/Price': 128.07,
#            'Holding/default/Type': 'Position',
#            'Holding/default/Units': 10859705.88235294,
#            'Instrument/default/LusidInstrumentId': 'LUID_00070D4Z',
#            'Instrument/default/Name': 'Microsoft'},
#           {'Holding/default/Cost': 98147500000.0,
#            'Holding/default/ExchangeRate': 1.0,
#            'Holding/default/PV': 85490000000.0,
#            'Holding/default/Price': 10300.0,
#            'Holding/default/Type': 'Position',
#            'Holding/default/Units': 8300000.0,
#            'Instrument/default/LusidInstrumentId': 'LUID_00070D50',
#            'Instrument/default/Name': 'Softbank'},
#           {'Holding/default/Cost': -24505476.47,
#            'Holding/default/ExchangeRate': 1.0,
#            'Holding/default/PV': -24505476.47058823,
#            'Holding/default/Price': 1.0,
#            'Holding/default/Type': 'Balance',
#            'Holding/default/Units': -24505476.47058823,
#            'Instrument/default/LusidInstrumentId': 'CCY_USD',
#            'Instrument/default/Name': 'USD'},
#           {'Holding/default/Cost': -27346764.71,
#            'Holding/default/ExchangeRate': 1.0,
#            'Holding/default/PV': -27346764.705882356,
#            'Holding/default/Price': 1.0,
#            'Holding/default/Type': 'Balance',
#            'Holding/default/Units': -27346764.705882356,
#            'Instrument/default/LusidInstrumentId': 'CCY_GBP',
#            'Instrument/default/Name': 'GBP'},
#           {'Holding/default/Cost': 2076854226.47,
#            'Holding/default/ExchangeRate': 1.0,
#            'Holding/default/PV': 2076854226.4705884,
#            'Holding/default/Price': 1.0,
#            'Holding/default/Type': 'Balance',
#            'Holding/default/Units': 2076854226.4705884,
#            'Instrument/default/LusidInstrumentId': 'CCY_EUR',
#            'Instrument/default/Name': 'EUR'},
#           {'Holding/default/Cost': -35846029.0,
#            'Holding/default/ExchangeRate': 1.0,
#            'Holding/default/PV': -35846029.4117647,
#            'Holding/default/Price': 1.0,
#            'Holding/default/Type': 'Balance',
#            'Holding/default/Units': -35846029.4117647,
#            'Instrument/default/LusidInstrumentId': 'CCY_JPY',
#            'Instrument/default/Name': 'JPY'}],
#  'data_schema': {'address_schema': {'Holding/default/Cost': {'description': 'The '
#                                                                             'cost '
#                                                                             'of '
#                                                                             'the '
#                                                                             'holding '
#                                                                             'in '
#                                                                             'the '
#                                                                             'portfolio '
#                                                                             'currency.',
#                                                              'display_name': 'Cost',
#                                                              'documentation_link': '',
#                                                              'life_cycle_status': 'Experimental',
#                                                              'removal_date': None,
#                                                              'type': 'Decimal'},
#                                     'Holding/default/ExchangeRate': {'description': 'DEPRECATED '
#                                                                                     'LEGACY '
#                                                                                     'Key. '
#                                                                                     'Full '
#                                                                                     'documentation '
#                                                                                     'is '
#                                                                                     'removed '
#                                                                                     'or '
#                                                                                     'otherwise '
#                                                                                     'not '
#                                                                                     'available.',
#                                                                      'display_name': 'Exchange '
#                                                                                      'Rate',
#                                                                      'documentation_link': '',
#                                                                      'life_cycle_status': 'Deprecated',
#                                                                      'removal_date': datetime.datetime(2021, 9, 1, 0, 0, tzinfo=tzlocal()),
#                                                                      'type': 'Decimal'},
#                                     'Holding/default/PV': {'description': 'DEPRECATED '
#                                                                           'LEGACY '
#                                                                           'Key. '
#                                                                           'Full '
#                                                                           'documentation '
#                                                                           'is '
#                                                                           'removed '
#                                                                           'or '
#                                                                           'otherwise '
#                                                                           'not '
#                                                                           'available.',
#                                                            'display_name': 'PV',
#                                                            'documentation_link': '',
#                                                            'life_cycle_status': 'Deprecated',
#                                                            'removal_date': datetime.datetime(2021, 9, 1, 0, 0, tzinfo=tzlocal()),
#                                                            'type': 'Decimal'},
#                                     'Holding/default/Price': {'description': 'DEPRECATED '
#                                                                              'LEGACY '
#                                                                              'Key. '
#                                                                              'Full '
#                                                                              'documentation '
#                                                                              'is '
#                                                                              'removed '
#                                                                              'or '
#                                                                              'otherwise '
#                                                                              'not '
#                                                                              'available.',
#                                                               'display_name': 'Price',
#                                                               'documentation_link': '',
#                                                               'life_cycle_status': 'Deprecated',
#                                                               'removal_date': datetime.datetime(2021, 9, 1, 0, 0, tzinfo=tzlocal()),
#                                                               'type': 'Decimal'},
#                                     'Holding/default/Type': {'description': 'The '
#                                                                             'type '
#                                                                             'of '
#                                                                             'the '
#                                                                             'holding '
#                                                                             '(buy, '
#                                                                             'sell, '
#                                                                             'fx, '
#                                                                             'etc.).',
#                                                              'display_name': 'Type',
#                                                              'documentation_link': '',
#                                                              'life_cycle_status': 'Experimental',
#                                                              'removal_date': None,
#                                                              'type': 'String'},
#                                     'Holding/default/Units': {'description': 'The '
#                                                                              'quantity '
#                                                                              'of, '
#                                                                              'e.g. '
#                                                                              'shares, '
#                                                                              'owned '
#                                                                              'or '
#                                                                              'held '
#                                                                              'in '
#                                                                              'a '
#                                                                              'particular '
#                                                                              'holding. '
#                                                                              'Can '
#                                                                              'relate '
#                                                                              'closely '
#                                                                              'to '
#                                                                              'the '
#                                                                              'quantity '
#                                                                              'in '
#                                                                              'an '
#                                                                              'instrument '
#                                                                              'with '
#                                                                              'an '
#                                                                              'extended '
#                                                                              'definition.',
#                                                               'display_name': 'Units',
#                                                               'documentation_link': '',
#                                                               'life_cycle_status': 'Experimental',
#                                                               'removal_date': None,
#                                                               'type': 'Decimal'},
#                                     'Instrument/default/LusidInstrumentId': {'description': 'DEPRECATED '
#                                                                                             'LEGACY '
#                                                                                             'Key. '
#                                                                                             'Full '
#                                                                                             'documentation '
#                                                                                             'is '
#                                                                                             'removed '
#                                                                                             'or '
#                                                                                             'otherwise '
#                                                                                             'not '
#                                                                                             'available.',
#                                                                              'display_name': 'LUSID '
#                                                                                              'unique '
#                                                                                              'ID '
#                                                                                              '(LUID)',
#                                                                              'documentation_link': '',
#                                                                              'life_cycle_status': 'Deprecated',
#                                                                              'removal_date': datetime.datetime(2021, 9, 1, 0, 0, tzinfo=tzlocal()),
#                                                                              'type': 'String'},
#                                     'Instrument/default/Name': {'description': 'DEPRECATED '
#                                                                                'LEGACY '
#                                                                                'Key. '
#                                                                                'Full '
#                                                                                'documentation '
#                                                                                'is '
#                                                                                'removed '
#                                                                                'or '
#                                                                                'otherwise '
#                                                                                'not '
#                                                                                'available.',
#                                                                 'display_name': 'Name',
#                                                                 'documentation_link': '',
#                                                                 'life_cycle_status': 'Deprecated',
#                                                                 'removal_date': datetime.datetime(2021, 9, 1, 0, 0, tzinfo=tzlocal()),
#                                                                 'type': 'String'}},
#                  'node_value_schema': None,
#                  'property_schema': {'Holding/default/Cost': {'description': 'The '
#                                                                              'cost '
#                                                                              'of '
#                                                                              'the '
#                                                                              'holding '
#                                                                              'in '
#                                                                              'the '
#                                                                              'portfolio '
#                                                                              'currency.',
#                                                               'display_name': 'Cost',
#                                                               'display_order': 0,
#                                                               'id': {'code': 'Cost',
#                                                                      'scope': 'default'},
#                                                               'type': 'Decimal'},
#                                      'Holding/default/ExchangeRate': {'description': 'DEPRECATED '
#                                                                                      'LEGACY '
#                                                                                      'Key. '
#                                                                                      'Full '
#                                                                                      'documentation '
#                                                                                      'is '
#                                                                                      'removed '
#                                                                                      'or '
#                                                                                      'otherwise '
#                                                                                      'not '
#                                                                                      'available.',
#                                                                       'display_name': 'Exchange '
#                                                                                       'Rate',
#                                                                       'display_order': 0,
#                                                                       'id': {'code': 'ExchangeRate',
#                                                                              'scope': 'default'},
#                                                                       'type': 'Decimal'},
#                                      'Holding/default/PV': {'description': 'DEPRECATED '
#                                                                            'LEGACY '
#                                                                            'Key. '
#                                                                            'Full '
#                                                                            'documentation '
#                                                                            'is '
#                                                                            'removed '
#                                                                            'or '
#                                                                            'otherwise '
#                                                                            'not '
#                                                                            'available.',
#                                                             'display_name': 'PV',
#                                                             'display_order': 0,
#                                                             'id': {'code': 'PV',
#                                                                    'scope': 'default'},
#                                                             'type': 'Decimal'},
#                                      'Holding/default/Price': {'description': 'DEPRECATED '
#                                                                               'LEGACY '
#                                                                               'Key. '
#                                                                               'Full '
#                                                                               'documentation '
#                                                                               'is '
#                                                                               'removed '
#                                                                               'or '
#                                                                               'otherwise '
#                                                                               'not '
#                                                                               'available.',
#                                                                'display_name': 'Price',
#                                                                'display_order': 0,
#                                                                'id': {'code': 'Price',
#                                                                       'scope': 'default'},
#                                                                'type': 'Decimal'},
#                                      'Holding/default/Type': {'description': 'The '
#                                                                              'type '
#                                                                              'of '
#                                                                              'the '
#                                                                              'holding '
#                                                                              '(buy, '
#                                                                              'sell, '
#                                                                              'fx, '
#                                                                              'etc.).',
#                                                               'display_name': 'Type',
#                                                               'display_order': 0,
#                                                               'id': {'code': 'Type',
#                                                                      'scope': 'default'},
#                                                               'type': 'String'},
#                                      'Holding/default/Units': {'description': 'The '
#                                                                               'quantity '
#                                                                               'of, '
#                                                                               'e.g. '
#                                                                               'shares, '
#                                                                               'owned '
#                                                                               'or '
#                                                                               'held '
#                                                                               'in '
#                                                                               'a '
#                                                                               'particular '
#                                                                               'holding. '
#                                                                               'Can '
#                                                                               'relate '
#                                                                               'closely '
#                                                                               'to '
#                                                                               'the '
#                                                                               'quantity '
#                                                                               'in '
#                                                                               'an '
#                                                                               'instrument '
#                                                                               'with '
#                                                                               'an '
#                                                                               'extended '
#                                                                               'definition.',
#                                                                'display_name': 'Units',
#                                                                'display_order': 0,
#                                                                'id': {'code': 'Units',
#                                                                       'scope': 'default'},
#                                                                'type': 'Decimal'},
#                                      'Instrument/default/LusidInstrumentId': {'description': 'DEPRECATED '
#                                                                                              'LEGACY '
#                                                                                              'Key. '
#                                                                                              'Full '
#                                                                                              'documentation '
#                                                                                              'is '
#                                                                                              'removed '
#                                                                                              'or '
#                                                                                              'otherwise '
#                                                                                              'not '
#                                                                                              'available.',
#                                                                               'display_name': 'LUSID '
#                                                                                               'unique '
#                                                                                               'ID '
#                                                                                               '(LUID)',
#                                                                               'display_order': 0,
#                                                                               'id': {'code': 'LusidInstrumentId',
#                                                                                      'scope': 'default'},
#                                                                               'type': 'String'},
#                                      'Instrument/default/Name': {'description': 'DEPRECATED '
#                                                                                 'LEGACY '
#                                                                                 'Key. '
#                                                                                 'Full '
#                                                                                 'documentation '
#                                                                                 'is '
#                                                                                 'removed '
#                                                                                 'or '
#                                                                                 'otherwise '
#                                                                                 'not '
#                                                                                 'available.',
#                                                                  'display_name': 'Name',
#                                                                  'display_order': 0,
#                                                                  'id': {'code': 'Name',
#                                                                         'scope': 'default'},
#                                                                  'type': 'String'}}},
#  'href': None,
#  'links': [{'description': 'A link to the LUSID Insights website showing all '
#                            'logs related to this request',
#             'href': 'http://fbn-ci.lusid.com/app/insights/logs/0HMQGGAL4G30V:00000177',
#             'method': 'GET',
#             'relation': 'RequestLogs'}]}
