# %%
"""Paging and limiting LUSID's API calls

Shows how to slice up large requests to LUSID into smaller requests using the limit and page parameters.

Attributes
----------
paging
"""
# Out:
# "Paging and limiting LUSID's API calls\n\nShows how to slice up large requests to LUSID into smaller requests using the limit and page parameters.\n\nAttributes\n----------\npaging\n"

# %% [markdown]
# # Paging and limiting LUSID's API calls
#
# This notebooks shows how you can use the <b>limit</b> and <b>page</b> parameters of a LUSID call to slice up large requests into numerous smaller requests. For the purposes of this demonstration, we will use the [<b>list instruments</b>](https://www.lusid.com/docs/api/#operation/ListInstruments) API.

# %% [markdown]
# ## Setup LUSID

# %%
# Import general purpose Python packages
import os

# Import lusid specific packages
# These are the core lusid packages for interacting with the API via Python
import lusid
import lusid.models as models
from lusidjam.refreshing_token import RefreshingToken
from lusidtools.pandas_utils.lusid_pandas import lusid_response_to_data_frame
import fbnsdkutilities.utilities as utils

# Import data wrangling packages
import pandas as pd
import json

# Authenticate our user and create our API client
secrets_path = os.getenv("FBN_SECRETS_PATH")

# Initiate an API Factory which is the client side object for interacting with LUSID APIs
api_factory = utils.ApiClientFactory(
    lusid,
    token=RefreshingToken(),
    api_secrets_filename = secrets_path,
    app_name="LusidJupyterNotebook")

# %%
# Load a mapping file for formatting DataFrame columns

with open(r"config/list_instruments_mapping.json") as mappings_file:
    json_mappings = json.load(mappings_file)

# %% [markdown]
# ## Create an instruments API object and call the "list instruments" method

# %%
instruments_api = api_factory.build(lusid.api.InstrumentsApi)

# %%
list_instruments = instruments_api.list_instruments()
lusid_response_to_data_frame(list_instruments,
                             column_name_mapping=json_mappings).drop(columns={"href"}).head(10)
# Out:
#      scope           Luid              EffectiveFrom
# 0  default  LUID_8XYN62RM  0001-01-01 00:00:00+00:00  \
# 1  default  LUID_LQ1FQFRG  0001-01-01 00:00:00+00:00
# 2  default  LUID_592BI14N  0001-01-01 00:00:00+00:00
# 3  default  LUID_Y3WLG2LP  0001-01-01 00:00:00+00:00
# 4  default  LUID_VQN7QB7S  0001-01-01 00:00:00+00:00
# 5  default  LUID_AJMSV9DW  0001-01-01 00:00:00+00:00
# 6  default  LUID_KIKBQ7HR  0001-01-01 00:00:00+00:00
# 7  default  LUID_G64ROSWP  0001-01-01 00:00:00+00:00
# 8  default  LUID_3SAJ62X9  0001-01-01 00:00:00+00:00
# 9  default  LUID_GIZGEWW8  0001-01-01 00:00:00+00:00
#
#                               AsAt                     InstrumentName
# 0 2023-05-09 13:12:39.178177+00:00                      TestSecurity5  \
# 1 2023-05-09 13:12:39.178177+00:00                      TestSecurity1
# 2 2023-05-09 13:12:39.178177+00:00                      TestSecurity3
# 3 2023-05-09 13:12:39.178177+00:00                      TestSecurity2
# 4 2023-05-09 13:12:39.178177+00:00                      TestSecurity4
# 5 2023-05-09 13:12:39.178177+00:00  test-instrument-FIGI_BBG000FF0LP5
# 6 2023-05-09 13:12:39.178177+00:00  test-instrument-FIGI_BBG000C1SBB6
# 7 2023-05-09 13:12:39.178177+00:00                           Security
# 8 2023-05-09 13:12:39.178177+00:00      TestInstrumentWithLookthrough
# 9 2023-05-09 13:12:39.178177+00:00  test-instrument-FIGI_BBG001S7Z574
#
#                   ClientInternalId LusidInstrumentId properties   state
# 0                  TestSecurityId5     LUID_8XYN62RM         []  Active  \
# 1                  TestSecurityId1     LUID_LQ1FQFRG         []  Active
# 2                  TestSecurityId3     LUID_592BI14N         []  Active
# 3                  TestSecurityId2     LUID_Y3WLG2LP         []  Active
# 4                  TestSecurityId4     LUID_VQN7QB7S         []  Active
# 5                FIGI_BBG000FF0LP5     LUID_AJMSV9DW         []  Active
# 6                FIGI_BBG000C1SBB6     LUID_KIKBQ7HR         []  Active
# 7                         Security     LUID_G64ROSWP         []  Active
# 8  TestInstrumentIdWithLookthrough     LUID_3SAJ62X9         []  Active
# 9                FIGI_BBG001S7Z574     LUID_GIZGEWW8         []  Active
#
#   asset_class dom_ccy relationships                               LTScope
# 0     Unknown     ZZZ            []                                   NaN  \
# 1     Unknown     ZZZ            []                                   NaN
# 2     Unknown     ZZZ            []                                   NaN
# 3     Unknown     ZZZ            []                                   NaN
# 4     Unknown     ZZZ            []                                   NaN
# 5     Unknown     ZZZ            []                                   NaN
# 6     Unknown     ZZZ            []                                   NaN
# 7     Unknown     ZZZ            []                                   NaN
# 8     Unknown     ZZZ            []  04594d65-78f0-473e-858e-7e33bba9f2aa
# 9     Unknown     ZZZ            []                                   NaN
#
#         LTCode
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8  Lookthrough
# 9          NaN

# %% [markdown]
# ## Get a list of instruments, limited to 100 returned items

# %%
first_list_instruments_response = instruments_api.list_instruments(limit=100)
lusid_response_to_data_frame(first_list_instruments_response,
                             column_name_mapping=json_mappings).drop(columns={"href"})
# Out:
#       scope           Luid              EffectiveFrom
# 0   default  LUID_8XYN62RM  0001-01-01 00:00:00+00:00  \
# 1   default  LUID_LQ1FQFRG  0001-01-01 00:00:00+00:00
# 2   default  LUID_592BI14N  0001-01-01 00:00:00+00:00
# 3   default  LUID_Y3WLG2LP  0001-01-01 00:00:00+00:00
# 4   default  LUID_VQN7QB7S  0001-01-01 00:00:00+00:00
# ..      ...            ...                        ...
# 95  default  LUID_G0HCYFRR  0001-01-01 00:00:00+00:00
# 96  default  LUID_8BSVH4U9  0001-01-01 00:00:00+00:00
# 97  default  LUID_O3VNHTQU  0001-01-01 00:00:00+00:00
# 98  default  LUID_0FTPUE3M  0001-01-01 00:00:00+00:00
# 99  default  LUID_Y29SBCLX  0001-01-01 00:00:00+00:00
#
#                                AsAt                     InstrumentName
# 0  2023-05-09 13:12:42.091377+00:00                      TestSecurity5  \
# 1  2023-05-09 13:12:42.091377+00:00                      TestSecurity1
# 2  2023-05-09 13:12:42.091377+00:00                      TestSecurity3
# 3  2023-05-09 13:12:42.091377+00:00                      TestSecurity2
# 4  2023-05-09 13:12:42.091377+00:00                      TestSecurity4
# ..                              ...                                ...
# 95 2023-05-09 13:12:42.091377+00:00  test-instrument-FIGI_BBG000BLW521
# 96 2023-05-09 13:12:42.091377+00:00  test-instrument-FIGI_BBG000BGDB66
# 97 2023-05-09 13:12:42.091377+00:00  test-instrument-FIGI_BBG005WQR5L1
# 98 2023-05-09 13:12:42.091377+00:00  test-instrument-FIGI_BBG005XFHM29
# 99 2023-05-09 13:12:42.091377+00:00  test-instrument-FIGI_BBG000BBNQC6
#
#      ClientInternalId LusidInstrumentId properties   state asset_class
# 0     TestSecurityId5     LUID_8XYN62RM         []  Active     Unknown  \
# 1     TestSecurityId1     LUID_LQ1FQFRG         []  Active     Unknown
# 2     TestSecurityId3     LUID_592BI14N         []  Active     Unknown
# 3     TestSecurityId2     LUID_Y3WLG2LP         []  Active     Unknown
# 4     TestSecurityId4     LUID_VQN7QB7S         []  Active     Unknown
# ..                ...               ...        ...     ...         ...
# 95  FIGI_BBG000BLW521     LUID_G0HCYFRR         []  Active     Unknown
# 96  FIGI_BBG000BGDB66     LUID_8BSVH4U9         []  Active     Unknown
# 97  FIGI_BBG005WQR5L1     LUID_O3VNHTQU         []  Active     Unknown
# 98  FIGI_BBG005XFHM29     LUID_0FTPUE3M         []  Active     Unknown
# 99  FIGI_BBG000BBNQC6     LUID_Y29SBCLX         []  Active     Unknown
#
#    dom_ccy relationships LTScope LTCode
# 0      ZZZ            []     NaN    NaN
# 1      ZZZ            []     NaN    NaN
# 2      ZZZ            []     NaN    NaN
# 3      ZZZ            []     NaN    NaN
# 4      ZZZ            []     NaN    NaN
# ..     ...           ...     ...    ...
# 95     ZZZ            []     NaN    NaN
# 96     ZZZ            []     NaN    NaN
# 97     ZZZ            []     NaN    NaN
# 98     ZZZ            []     NaN    NaN
# 99     ZZZ            []     NaN    NaN
#
# [100 rows x 14 columns]

# %%
# get the token for the next page, this will be empty if it is the last page
next_page_token = first_list_instruments_response.next_page

# get the token for the previous page
previous_page_token = first_list_instruments_response.previous_page

# %%
print(f"The token for the next page is {next_page_token}")
print(f"The token for the previous page is {previous_page_token}")
# Out:
# The token for the next page is ZAA+AGZibi1jaTpkZWZhdWx0L0luc3RydW1lbnQvNWJkOTQ3ZjktYTQ2Ni00MDdmLWEyOGEtYzhkNDEyN2Y5NjJlajJREo9Q2wgAAAAAAAAAAHLqmhKPUNsIAAAAAAAAAAAmzeKhAAAAAA==
# The token for the previous page is None

# %% [markdown]
# ## Get the next 100 instruments

# %%
# The next page token is passed to the page parameter

second_list_instruments_response = instruments_api.list_instruments(
    page=next_page_token, limit=100)

lusid_response_to_data_frame(second_list_instruments_response,
                             column_name_mapping=json_mappings).drop(columns={"href"})
# Out:
#       scope           Luid              EffectiveFrom
# 0   default  LUID_VCJF16KJ  0001-01-01 00:00:00+00:00  \
# 1   default  LUID_4M902B88  0001-01-01 00:00:00+00:00
# 2   default  LUID_F1JGF873  0001-01-01 00:00:00+00:00
# 3   default  LUID_6GKO80KV  0001-01-01 00:00:00+00:00
# 4   default  LUID_UW709QTS  0001-01-01 00:00:00+00:00
# ..      ...            ...                        ...
# 95  default  LUID_K31HX0MB  0001-01-01 00:00:00+00:00
# 96  default  LUID_R8XUEI3W  0001-01-01 00:00:00+00:00
# 97  default  LUID_G9D7Q252  0001-01-01 00:00:00+00:00
# 98  default  LUID_UFP80TWM  0001-01-01 00:00:00+00:00
# 99  default  LUID_R916X53A  0001-01-01 00:00:00+00:00
#
#                                AsAt                     InstrumentName
# 0  2023-05-09 13:12:42.091377+00:00  test-instrument-FIGI_BBG000QQ0KQ0  \
# 1  2023-05-09 13:12:42.091377+00:00  test-instrument-FIGI_BBG000BD0RT7
# 2  2023-05-09 13:12:42.091377+00:00  test-instrument-FIGI_BBG000HHP5P7
# 3  2023-05-09 13:12:42.091377+00:00  test-instrument-FIGI_BBG003FZ2QK7
# 4  2023-05-09 13:12:42.091377+00:00  test-instrument-FIGI_BBG000BDCD60
# ..                              ...                                ...
# 95 2023-05-09 13:12:42.091377+00:00  test-instrument-FIGI_BBG000C05BD1
# 96 2023-05-09 13:12:42.091377+00:00  test-instrument-FIGI_BBG000BFR1G4
# 97 2023-05-09 13:12:42.091377+00:00  test-instrument-FIGI_BBG000C0KDR5
# 98 2023-05-09 13:12:42.091377+00:00  test-instrument-FIGI_BBG000N2C023
# 99 2023-05-09 13:12:42.091377+00:00  test-instrument-FIGI_BBG000BDLT47
#
#      ClientInternalId LusidInstrumentId properties   state asset_class
# 0   FIGI_BBG000QQ0KQ0     LUID_VCJF16KJ         []  Active     Unknown  \
# 1   FIGI_BBG000BD0RT7     LUID_4M902B88         []  Active     Unknown
# 2   FIGI_BBG000HHP5P7     LUID_F1JGF873         []  Active     Unknown
# 3   FIGI_BBG003FZ2QK7     LUID_6GKO80KV         []  Active     Unknown
# 4   FIGI_BBG000BDCD60     LUID_UW709QTS         []  Active     Unknown
# ..                ...               ...        ...     ...         ...
# 95  FIGI_BBG000C05BD1     LUID_K31HX0MB         []  Active     Unknown
# 96  FIGI_BBG000BFR1G4     LUID_R8XUEI3W         []  Active     Unknown
# 97  FIGI_BBG000C0KDR5     LUID_G9D7Q252         []  Active     Unknown
# 98  FIGI_BBG000N2C023     LUID_UFP80TWM         []  Active     Unknown
# 99  FIGI_BBG000BDLT47     LUID_R916X53A         []  Active     Unknown
#
#    dom_ccy relationships
# 0      ZZZ            []
# 1      ZZZ            []
# 2      ZZZ            []
# 3      ZZZ            []
# 4      ZZZ            []
# ..     ...           ...
# 95     ZZZ            []
# 96     ZZZ            []
# 97     ZZZ            []
# 98     ZZZ            []
# 99     ZZZ            []
#
# [100 rows x 12 columns]
