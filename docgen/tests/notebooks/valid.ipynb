# %%
"""Notebook title

Longer description of notebook

Attributes
----------
transaction config
properties
derived portfolios
"""
# Out:
#   File "<ipython-input-1-6cf848d69283>", line 3
#     """"
#
# ^
# SyntaxError: EOL while scanning string literal
