# %%
from lusidtools.jupyter_tools import toggle_code

"""Luminesce Providers and Views

Attributes
----------

"""

toggle_code("Toggle Docstring")
# Out:
#     <form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Toggle Docstring"></form>
#
#          <script>
#          function code_toggle() {
#              if ($('div.cell.code_cell.rendered.selected div.input').css('display')!='none'){
#                  $('div.cell.code_cell.rendered.selected div.input').hide();
#              } else {
#                  $('div.cell.code_cell.rendered.selected div.input').show();
#              }
#          }
#          </script>

# %%
import os
from lusidjam import RefreshingToken
import lusid as lu
import pandas as pd
import lusid_drive
import lusid_drive.rest
import lusid.rest
from lusid_drive.rest import ApiException
from pprint import pprint
import json
import fbnsdkutilities.utilities as utils

pd.set_option('display.max_colwidth', None)
secrets_path = os.getenv("FBN_SECRETS_PATH")

api_factory = utils.ApiClientFactory(
    lu,
    token = RefreshingToken(), 
    api_secrets_filename = secrets_path,
    app_name = "LusidJupyterNotebook"
)

# Confirm success by printing SDK version
api_status = pd.DataFrame(api_factory.build(lu.ApplicationMetadataApi).get_lusid_versions().to_dict())
display(api_status)
# Out:
#   api_version build_version excel_version
# 0          v0   0.6.11275.0      0.5.3237  \
#
#                                                                                                                                                                                                                       links
# 0  {'relation': 'RequestLogs', 'href': 'http://fbn-ci.lusid.com/app/insights/logs/0HMQGO0VJGBGA:000002AE', 'description': 'A link to the LUSID Insights website showing all logs related to this request', 'method': 'GET'}

# %%
# here's some sample equities we've prepared earlier
uk_equity_instruments = pd.read_csv('_data/uk_equity_instruments.csv')
us_equity_instruments = pd.read_csv('_data/us_equity_instruments.csv')

# %%
# don't show exception if error is due to upsert
def exception_guard(e, code):
    return e.status and e.status != '400 Bad Request' and e.body and json.loads(e.body)["code"] == code

scope = 'FBNUniversity' # str | The scope of the portfolio.

# %%
# create a request to upsert a bunch of instruments.
def generate_upsert_instrument_request(api_instance, name, ccy, figi, isin, other_identifier_name, other_identifier):
    request_id = name + isin
    request ={"name":name,
                     "identifiers":{ "Figi":{"value":figi},
                                     "Isin":{"value":isin},
                                     other_identifier_name:{"value":other_identifier}
                                   },

                     "definition":{"instrumentType":"Equity", "domCcy":ccy}}
    return request_id, request

# %%
# Create an instance of the API class
api_instance = api_factory.build(lu.InstrumentsApi)

# We're going to load some american and UK equities into LUSID

other_identifier_name = 'Sedol'
ccy = 'GBP'
upsert_body_tuple = (generate_upsert_instrument_request(api_instance, name, ccy, figi, isin, other_identifier_name, other_identifier)
               for 
               index, ticker, name, _, isin, other_identifier, figi
               in uk_equity_instruments.itertuples())
uk_equity_body_dict = {request_id:request_body for request_id,request_body in upsert_body_tuple}
other_identifier_name = 'Cusip'
ccy = 'USD'
upsert_body_tuple = (generate_upsert_instrument_request(api_instance, name, ccy, figi, isin, other_identifier_name, other_identifier)
               for 
               index, ticker, name, _, isin, other_identifier, figi
               in us_equity_instruments.itertuples())
us_equity_body_dict = {request_id:request_body for request_id,request_body in upsert_body_tuple}

request_body_dict = us_equity_body_dict | uk_equity_body_dict

try:
    # UpsertInstruments: Upsert instruments
    api_response = api_instance.upsert_instruments(request_body_dict, scope=scope)
#     pprint(api_response)
except lusid.rest.ApiException as e:
    print("Exception when calling InstrumentsApi->upsert_instruments: %s\n" % e)

# %%
api_instance = api_factory.build(lu.TransactionPortfoliosApi)
code = 'Module-T2-3' # str | The code of the portfolio. Together with the scope this uniquely identifies the portfolio.
create_transaction_portfolio_request = {"displayName":"Training module T2.3", "baseCurrency":"GBP", "code":code} # UpdatePortfolioRequest | The updated portfolio definition.
try:
    # CreatePortfolio: Create portfolio
    api_response = api_instance.create_portfolio(scope, create_transaction_portfolio_request)
except lusid.rest.ApiException as e:
    if not exception_guard(e, 112):
        print(e)

# %%
# let's chuck a file containing a randomly selected subset of 25 instruments with their sectors into drive for some examples:

subset_file = open('_data/instrument_subset.csv').read()

drive_config = lusid_drive.Configuration(
    host = f'{api_instance.api_client.configuration.host[:-4]}/drive'
)
drive_config.access_token = api_factory.api_client.configuration.access_token

# Enter a context with an instance of the API client
with lusid_drive.ApiClient(drive_config) as api_client:
    # Create an instance of the API class
    api_instance = lusid_drive.FoldersApi(api_client)
    create_folder = {"path":"/","name":"finbourne university"} # CreateFolder | A CreateFolder object that defines the name and path of the new folder

    try:
        # [EARLY ACCESS] CreateFolder: Create a new folder in LUSID Drive
        api_response = api_instance.create_folder(create_folder)
        pprint(api_response)
    except ApiException as e:
        if not exception_guard(e, 664):
            print("Exception when calling FilesApi->create_file: %s\n" % e)
        
        
    api_instance = lusid_drive.FilesApi(api_client)
    x_lusid_drive_filename = 'instrument_subsetT2.3.csv' # str | File name.
    x_lusid_drive_path = '/finbourne university/' # str | File path.
    content_length = len(subset_file.encode('UTF-8'))
    body = subset_file # str | 

    try:
        # [EARLY ACCESS] CreateFile: Uploads a file to Lusid Drive. If using an SDK, consider using the UploadAsStreamAsync function for larger files instead.
        api_response = api_instance.create_file(x_lusid_drive_filename, x_lusid_drive_path, content_length, body)
    except lusid_drive.rest.ApiException as e:
        if not exception_guard(e, 671):
            print("Exception when calling FilesApi->create_file: %s\n" % e)

# %% [markdown]
# # Providers and Views

# %% [markdown]
# A provider is a component that enables you to write a Luminesce SQL query for a data source in situ, without first having to extract, transform or load data from that source.
#
# We supply providers for numerous data sources, including for the investment data stored in LUSID itself and for files stored in Drive.

# %% [markdown]
# In this part of the course we will cover:

# %% [markdown]
# - Data providers
# - Direct providers
# - Write providers
# - Provider parameters
# - Using Luminesce views
# - Writing Luminesce views

# %% [markdown]
# ## Data providers

# %% [markdown]
# A data provider is designed to query a data source whose shape is known. It therefore returns a table of results with a fixed number of fields (columns).
#
# Most of the providers we supply to query the investment management data stored in LUSID itself are data providers with a fixed number of fields, making it easier to query the data using standard SQL query syntax and luminesce extensions.
#
# A data provider does not have to query a datasource, as long as it returns some data.For example, we supply providers that perform calculations on demand, such as `Lusid.Portfolio.Valuation`, where the data returned doesn't actually exist anywhere but rather is calculated each time the provider is queried.

# %% [markdown]
# ## Direct providers

# %% [markdown]
# A direct provider is designed to query a data source whose shape is not known, and thus cannot return a table of results with a fixed number of fields (columns).
#
# A Luminesce query for a direct provider uses an arbitrary syntax, which may differ for each provider, and is defined by the writer of the provider.
#
#     @variable = use Some.Provider [wait]
#     <arbitrary-syntax>
#     enduse;
#     select * from @variable

# %% [markdown]
#
# Some direct providers can also interpolate table and scalar parameters into their arbritrary syntax, enabling the use of parameters within the direct provider query using the WITH syntax:
#
#     @@today = select strftime('%Y%m%d', 'now');
#     @table_of_results = use Drive.Csv with @@today
#     --file=/trade-files/eod-{@@today}.csv
#     --noHeader
#     --names=Equity,Units,Cost
#     enduse;
#     select * from @table_of_results

# %% [markdown]
# ## Write providers

# %% [markdown]
# As mentioned earlier, data providers aren't limited to reading data from a datasource. Some providers' primary role is to write data to some target.
#
# Using a write provider is straightforward. Query the Provider passing the data you'd like to write as parameters to fields specified by the provider, for example:
#
#     @table_of_data = <select-statement>;
#     select * from <Provider>.Writer where toWrite = @table_of_data;
#
# By convention, many write providers accept a table of values as a parameter, and specify the expected columns in their fields.

# %% [markdown]
# ## Examples of Lusid Providers

# %% [markdown]
# In this section we'll demonstrate some simple examples using the different types of provider.

# %%
# Enable luminesce magic
import os
from IPython.core.magic import (register_line_cell_magic)
from lumipy.client import Client
from lusidjam import RefreshingToken

token = RefreshingToken()
lusid_api_url = api_factory.api_client.configuration.host
lumi_api_url = lusid_api_url[: lusid_api_url.rfind("/") + 1] + "honeycomb"
os.environ["FBN_LUMI_API_URL"] = lumi_api_url
lumi_url = os.getenv("FBN_LUMI_API_URL")

@register_line_cell_magic
def luminesce(line, cell=None):
    query = cell if cell is not None else line

    lm_client = Client(token=token, api_url=lumi_url)

    df = lm_client.query_and_fetch(query)
            
    return df

# In an interactive session, we need to delete to avoid
# name conflicts for automagic to work on line magics.
del luminesce

# %% [markdown]
# ### Data Providers

# %% [markdown]
# #### Lusid.Instrument.Equity Provider

# %% [markdown]
# Luminesce has a number of `Lusid.Instrument` providers that enable you to write a Luminesce query to retrieve instruments mastered in LUSID.
#
# The generic `Lusid.Instrument` provider retrieves basic information about instruments of any asset class. Dedicated providers retrieve instruments of a particular asset class, for example `Lusid.Instrument.Bond` retrieves the full economic definition of bond instruments.

# %% [markdown]
# We'll use the `Lusid.Instrument` Provider to query for the equities we have stored in Lusid. Then we'll use the `Lusid.Instrument.Equity` Provider to look at the full economic definition of stored equity instruments.

# %%
# %%luminesce
# SELECT *
# FROM Lusid.Instrument
# LIMIT 100
# Out:
#    LusidInstrumentId  Figi                         ClientInternal
# 0      LUID_ZAPUZ24Z   NaN  csid_8b163c280deb4a1a8edc440fb22cffd6  \
# 1      LUID_96TJEHDP   NaN  csid_b46c47132754427e8c1d12fbd2ccf09a
# 2      LUID_BNUPIHSI   NaN  csid_df6c6ff9165e4af0be433d295cd4f1a3
# 3      LUID_HU15K7N4   NaN  csid_1d5be6cb013740f5942021b1dc16ac0d
# 4      LUID_QZQJCROZ   NaN  csid_181554c2d7e642b0bdc7aa54c63b903c
# ..               ...   ...                                    ...
# 95     LUID_W0QERHUV   NaN  csid_ba94dd87cb294192b084aa85447cf226
# 96     LUID_25WPS5ZF   NaN  csid_3c146c0d3b2f42f1b3168aae9a8f8d7c
# 97     LUID_82FTNLL6   NaN  csid_82cb9f24d40c432c90985c3ee27169fe
# 98     LUID_ME68DL9F   NaN  csid_7cd69006e16445a4ac7658e56f2453e9
# 99     LUID_EOKTA8AJ   NaN  csid_e8a178b2ea87468f909c4e793a8c7b01
#
#     QuotePermId  EdiKey  SecurityNumber  Isin  Sedol  Cusip  Ticker  ...
# 0           NaN     NaN             NaN   NaN    NaN    NaN     NaN  ...  \
# 1           NaN     NaN             NaN   NaN    NaN    NaN     NaN  ...
# 2           NaN     NaN             NaN   NaN    NaN    NaN     NaN  ...
# 3           NaN     NaN             NaN   NaN    NaN    NaN     NaN  ...
# 4           NaN     NaN             NaN   NaN    NaN    NaN     NaN  ...
# ..          ...     ...             ...   ...    ...    ...     ...  ...
# 95          NaN     NaN             NaN   NaN    NaN    NaN     NaN  ...
# 96          NaN     NaN             NaN   NaN    NaN    NaN     NaN  ...
# 97          NaN     NaN             NaN   NaN    NaN    NaN     NaN  ...
# 98          NaN     NaN             NaN   NaN    NaN    NaN     NaN  ...
# 99          NaN     NaN             NaN   NaN    NaN    NaN     NaN  ...
#
#     InstTimeVarStrPropTypeConverted  InstNumProp  InstReqDateProp
# 0                               NaN          NaN              NaN  \
# 1                               NaN          NaN              NaN
# 2                               NaN          NaN              NaN
# 3                               NaN          NaN              NaN
# 4                               NaN          NaN              NaN
# ..                              ...          ...              ...
# 95                              NaN          NaN              NaN
# 96                              NaN          NaN              NaN
# 97                              NaN          NaN              NaN
# 98                              NaN          NaN              NaN
# 99                              NaN          NaN              NaN
#
#     InstTimeVarStrColl InstNumColl InstDerivedStrProp InstDerivedNumProp
# 0                  NaN         NaN           -derived                  0  \
# 1                  NaN         NaN           -derived                  0
# 2                  NaN         NaN           -derived                  0
# 3                  NaN         NaN           -derived                  0
# 4                  NaN         NaN           -derived                  0
# ..                 ...         ...                ...                ...
# 95                 NaN         NaN           -derived                  0
# 96                 NaN         NaN           -derived                  0
# 97                 NaN         NaN           -derived                  0
# 98                 NaN         NaN           -derived                  0
# 99                 NaN         NaN           -derived                  0
#
#    InstAmount  InstCurrency NonExistingProp
# 0         NaN           NaN             NaN
# 1         NaN           NaN             NaN
# 2         NaN           NaN             NaN
# 3         NaN           NaN             NaN
# 4         NaN           NaN             NaN
# ..        ...           ...             ...
# 95        NaN           NaN             NaN
# 96        NaN           NaN             NaN
# 97        NaN           NaN             NaN
# 98        NaN           NaN             NaN
# 99        NaN           NaN             NaN
#
# [100 rows x 34 columns]

# %% [markdown]
# The `Lusid.Instrument.Equity` Provider has a couple of extra fields: DomCcy & Identifiers, and will only return Instruments which are equities.

# %%
# %%luminesce
# SELECT DisplayName, DomCcy
# FROM Lusid.Instrument.Equity
# LIMIT 100
# Out:
#                                  DisplayName DomCcy
# 0                            AstraZeneca1257    GBP
# 1                            AstraZeneca1741    GBP
# 2                            AstraZeneca2264    GBP
# 3                            AstraZeneca1231    GBP
# 4                            AstraZeneca2037    GBP
# ..                                       ...    ...
# 95  luminesce-test-create-equity-16461339853    GBP
# 96                           AstraZeneca1094    GBP
# 97                              British Land    GBP
# 98                           AstraZeneca1189    GBP
# 99                             Taylor Wimpey    GBP
#
# [100 rows x 2 columns]

# %% [markdown]
# #### Lusid.Portfolio Provider

# %% [markdown]
# The `Lusid.Portfolio` provider enables you to write a Luminesce SQL query that retrieves information about one or more portfolios.

# %%
# %%luminesce
# SELECT *
# FROM Lusid.Portfolio
# LIMIT 100
# Out:
#                           PortfolioScope            PortfolioCode
# 0   b8ae5349-0895-4546-82eb-79122eaea5bd                        1  \
# 1   0f50a37b-0b8e-4d27-a286-e84c19fa655c  NewLookthroughPortfolio
# 2   0f50a37b-0b8e-4d27-a286-e84c19fa655c               Investment
# 3   06f9614b-4ef2-4454-9028-b45b350075cc                        2
# 4   06f9614b-4ef2-4454-9028-b45b350075cc                        3
# ..                                   ...                      ...
# 95  120ed16a-75ae-4ecd-94c8-20898193f0c1                       25
# 96  120ed16a-75ae-4ecd-94c8-20898193f0c1                       24
# 97  120ed16a-75ae-4ecd-94c8-20898193f0c1                       23
# 98  120ed16a-75ae-4ecd-94c8-20898193f0c1                       21
# 99  120ed16a-75ae-4ecd-94c8-20898193f0c1                       17
#
#    PortfolioType BaseCurrency  PfStrProp  PfTimeVarStrProp  PfRenamedNumProp
# 0    Transaction          GBP        NaN               NaN               NaN  \
# 1    Transaction          GBP        NaN               NaN               NaN
# 2    Transaction          GBP        NaN               NaN               NaN
# 3    Transaction          GBP        NaN               NaN               NaN
# 4    Transaction          GBP        NaN               NaN               NaN
# ..           ...          ...        ...               ...               ...
# 95   Transaction          GBP        NaN               NaN               NaN
# 96   Transaction          GBP        NaN               NaN               NaN
# 97   Transaction          GBP        NaN               NaN               NaN
# 98   Transaction          GBP        NaN               NaN               NaN
# 99   Transaction          GBP        NaN               NaN               NaN
#
#     PfReqDateProp  PfTimeVarStrColl  PfRenamedNumColl  ...
# 0             NaN               NaN               NaN  ...  \
# 1             NaN               NaN               NaN  ...
# 2             NaN               NaN               NaN  ...
# 3             NaN               NaN               NaN  ...
# 4             NaN               NaN               NaN  ...
# ..            ...               ...               ...  ...
# 95            NaN               NaN               NaN  ...
# 96            NaN               NaN               NaN  ...
# 97            NaN               NaN               NaN  ...
# 98            NaN               NaN               NaN  ...
# 99            NaN               NaN               NaN  ...
#
#    ParentPortfolioScope  ParentPortfolioCode  ChildPortfolioIds
# 0                   NaN                  NaN                NaN  \
# 1                   NaN                  NaN                NaN
# 2                   NaN                  NaN                NaN
# 3                   NaN                  NaN                NaN
# 4                   NaN                  NaN                NaN
# ..                  ...                  ...                ...
# 95                  NaN                  NaN                NaN
# 96                  NaN                  NaN                NaN
# 97                  NaN                  NaN                NaN
# 98                  NaN                  NaN                NaN
# 99                  NaN                  NaN                NaN
#
#     CorporateActionSourceScope  CorporateActionSourceId  AccountingMethod
# 0                          NaN                      NaN           Default  \
# 1                          NaN                      NaN           Default
# 2                          NaN                      NaN           Default
# 3                          NaN                      NaN           Default
# 4                          NaN                      NaN           Default
# ..                         ...                      ...               ...
# 95                         NaN                      NaN           Default
# 96                         NaN                      NaN           Default
# 97                         NaN                      NaN           Default
# 98                         NaN                      NaN           Default
# 99                         NaN                      NaN           Default
#
#                                                                                                                                     SubHoldingKeys
# 0   Transaction/b8ae5349-0895-4546-82eb-79122eaea5bd/ExampleTradeProperty1, Transaction/b8ae5349-0895-4546-82eb-79122eaea5bd/ExampleTradeProperty0  \
# 1                                                                                                                                              NaN
# 2                                                                                                                                              NaN
# 3   Transaction/06f9614b-4ef2-4454-9028-b45b350075cc/ExampleTradeProperty1, Transaction/06f9614b-4ef2-4454-9028-b45b350075cc/ExampleTradeProperty0
# 4   Transaction/06f9614b-4ef2-4454-9028-b45b350075cc/ExampleTradeProperty0, Transaction/06f9614b-4ef2-4454-9028-b45b350075cc/ExampleTradeProperty1
# ..                                                                                                                                             ...
# 95  Transaction/120ed16a-75ae-4ecd-94c8-20898193f0c1/ExampleTradeProperty0, Transaction/120ed16a-75ae-4ecd-94c8-20898193f0c1/ExampleTradeProperty1
# 96  Transaction/120ed16a-75ae-4ecd-94c8-20898193f0c1/ExampleTradeProperty0, Transaction/120ed16a-75ae-4ecd-94c8-20898193f0c1/ExampleTradeProperty1
# 97  Transaction/120ed16a-75ae-4ecd-94c8-20898193f0c1/ExampleTradeProperty0, Transaction/120ed16a-75ae-4ecd-94c8-20898193f0c1/ExampleTradeProperty1
# 98  Transaction/120ed16a-75ae-4ecd-94c8-20898193f0c1/ExampleTradeProperty0, Transaction/120ed16a-75ae-4ecd-94c8-20898193f0c1/ExampleTradeProperty1
# 99  Transaction/120ed16a-75ae-4ecd-94c8-20898193f0c1/ExampleTradeProperty0, Transaction/120ed16a-75ae-4ecd-94c8-20898193f0c1/ExampleTradeProperty1
#
#                     Created InstrumentScopes AmortisationMethod
# 0                2017-02-01              NaN     NoAmortisation
# 1   2019-06-19 18:40:23.999              NaN     NoAmortisation
# 2                2017-02-01              NaN     NoAmortisation
# 3                2017-02-01              NaN     NoAmortisation
# 4                2017-02-01              NaN     NoAmortisation
# ..                      ...              ...                ...
# 95               2017-02-01              NaN     NoAmortisation
# 96               2017-02-01              NaN     NoAmortisation
# 97               2017-02-01              NaN     NoAmortisation
# 98               2017-02-01              NaN     NoAmortisation
# 99               2017-02-01              NaN     NoAmortisation
#
# [100 rows x 30 columns]

# %% [markdown]
# Here we've returned all metadata about our Portfolios in Lusid.

# %% [markdown]
# #### Lusid.Tools Provider

# %% [markdown]
# The Lusid.Tools Provider does not query any data. It manipulates the input parameters to return a table.
#
# The `Tools.JsonExpand` provider enables you to write a Luminesce query that parses a JSON document into a table of constituent data objects, much like the SQLite json.tree function. We'll use this to demonstrate a data provider that does not query for any external data, instead manipulating the provided parameters.

# %%
# %%luminesce
# @@jsn = SELECT '{
#     "characters":[
#         {"name":"marge",
#          "age":36},
#         {"name":"homer",
#          "age":40},
#         {"name":"bart",
#          "age":9},
#         {"name":"lisa",
#          "age":12}
#     ]
# }';
# SELECT * FROM Tools.JsonExpand WHERE JsonString = @@jsn
# Out:
#            key
# 0          NaN  \
# 1   characters
# 2            0
# 3         name
# 4          age
# 5            1
# 6         name
# 7          age
# 8            2
# 9         name
# 10         age
# 11           3
# 12        name
# 13         age
#
#                                                                                                                     value
# 0   {"characters":[{"name":"marge","age":36},{"name":"homer","age":40},{"name":"bart","age":9},{"name":"lisa","age":12}]}  \
# 1                  [{"name":"marge","age":36},{"name":"homer","age":40},{"name":"bart","age":9},{"name":"lisa","age":12}]
# 2                                                                                               {"name":"marge","age":36}
# 3                                                                                                                   marge
# 4                                                                                                                      36
# 5                                                                                               {"name":"homer","age":40}
# 6                                                                                                                   homer
# 7                                                                                                                      40
# 8                                                                                                 {"name":"bart","age":9}
# 9                                                                                                                    bart
# 10                                                                                                                      9
# 11                                                                                               {"name":"lisa","age":12}
# 12                                                                                                                   lisa
# 13                                                                                                                     12
#
#        type   atom  id  parent               fullkey             path
# 0    object    NaN   0     NaN                     $                $
# 1     array    NaN   2     0.0          $.characters                $
# 2    object    NaN   3     2.0       $.characters[0]     $.characters
# 3      text  marge   5     3.0  $.characters[0].name  $.characters[0]
# 4   integer     36   7     3.0   $.characters[0].age  $.characters[0]
# 5    object    NaN   8     2.0       $.characters[1]     $.characters
# 6      text  homer  10     8.0  $.characters[1].name  $.characters[1]
# 7   integer     40  12     8.0   $.characters[1].age  $.characters[1]
# 8    object    NaN  13     2.0       $.characters[2]     $.characters
# 9      text   bart  15    13.0  $.characters[2].name  $.characters[2]
# 10  integer      9  17    13.0   $.characters[2].age  $.characters[2]
# 11   object    NaN  18     2.0       $.characters[3]     $.characters
# 12     text   lisa  20    18.0  $.characters[3].name  $.characters[3]
# 13  integer     12  22    18.0   $.characters[3].age  $.characters[3]

# %%
# %%luminesce
# @@jsn = SELECT '{
#     "characters":[
#         {"name":"marge",
#          "age":36},
#         {"name":"homer",
#          "age":40},
#         {"name":"bart",
#          "age":9},
#         {"name":"lisa",
#          "age":12}
#     ]
# }';
# @@selection = select "$.characters[0]";
# select * from Tools.JsonExpand where JsonString = @@jsn and RootPath = @@selection
# Out:
#     key                      value     type   atom  id  parent
# 0   NaN  {"name":"marge","age":36}   object    NaN   3     NaN  \
# 1  name                      marge     text  marge   5     3.0
# 2   age                         36  integer     36   7     3.0
#
#                 fullkey             path
# 0       $.characters[0]     $.characters
# 1  $.characters[0].name  $.characters[0]
# 2   $.characters[0].age  $.characters[0]

# %% [markdown]
# ### Direct Providers

# %% [markdown]
# #### Drive.Csv Provider

# %% [markdown]
# The Drive.Csv provider enables you to write a Luminesce query that extracts data from one or more CSV or similar pipe-delimited or row-based text files stored in Drive.
# We can pass a number of options to the Drive CSV provider, using the syntax `--<option>[=<value>]`

# %%
# %%luminesce
# @x = use Drive.Csv
# --file=/finbourne university/instrument_subsetT2.3.csv
# --noHeader
# --names=Name,Sector,Identifier
# enduse;
# select * from @x
# Out:
#                                   Name                               Sector
# 0                            Schroders                   Financial Services  \
# 1                             DS Smith                  General Industrials
# 2                Flutter Entertainment                     Travel & Leisure
# 3   Scottish Mortgage Investment Trust        Equity Investment Instruments
# 4                        Taylor Wimpey  Household Goods & Home Construction
# 5                                   BP                  Oil & Gas Producers
# 6                             Glencore                               Mining
# 7                                Segro        Real Estate Investment Trusts
# 8                       Prudential plc                       Life Insurance
# 9             Pershing Square Holdings                   Financial Services
# 10               St. James's Place plc                       Life Insurance
# 11               Hikma Pharmaceuticals      Pharmaceuticals & Biotechnology
# 12                  Melrose Industries                  Automobiles & Parts
# 13                     Legal & General                       Life Insurance
# 14                     Land Securities        Real Estate Investment Trusts
# 15                        Ferguson plc                     Support Services
# 16                            Experian                     Support Services
# 17          Intermediate Capital Group                  Investment Services
# 18                          Sage Group         Software & Computer Services
# 19                               Aviva                       Life Insurance
# 20                  Anglo American plc                               Mining
# 21                           Rightmove                                Media
# 22                      Vodafone Group            Mobile Telecommunications
# 23                         Ocado Group                Food & Drug Retailers
# 24                        British Land        Real Estate Investment Trusts
#
#       Identifier
# 0   BBG000BF0TF3
# 1   BBG000BF1LF9
# 2   BBG000DWL6M3
# 3   BBG000BFZMY9
# 4   BBG000BF4KL1
# 5   BBG000C05BD1
# 6   BBG001MM1KV4
# 7   BBG000BF1HY7
# 8   BBG000BDY322
# 9   BBG00747WHS1
# 10  BBG000BRMPC4
# 11  BBG000FG1MF1
# 12  BBG00B5YJC26
# 13  BBG000BDQCG6
# 14  BBG000BDPHS3
# 15  BBG00NZJ0JG0
# 16  BBG000BKFZN3
# 17  BBG000D8KQJ7
# 18  BBG000BN0PP3
# 19  BBG000DDCSJ1
# 20  BBG000BBLDF4
# 21  BBG000DD5X08
# 22  BBG000C6K6G9
# 23  BBG000BDXZH6
# 24  BBG000BD7DW7

# %% [markdown]
# Here we've read all data from the `/finbourne university/instrument_subsetT2.3.csv` file in drive. The file has no headers, so we've specified the no headers option, and provided a set of column names to the Provider.

# %% [markdown]
# ### Write Providers

# %% [markdown]
# #### Lusid.Instrument.Equity.Writer

# %% [markdown]
# Many of our Lusid write providers accept a `TableParameter` used to write multiple resources to some part of Lusid.

# %% [markdown]
# Now we'll use a Write Provider to create some equities by passing a table of equities as a parameter.

# %% [markdown]
# First let's take a look at the table parameter used by the `Lusid.Instruments.Equities` provider, and what the table it expects looks like.

# %%
# %%luminesce
# select FieldName, TableParamColumns from Sys.Field where TableName = 'Lusid.Instrument.Equity.Writer' AND DataType = 'Table';
# Out:
#   FieldName
# 0   ToWrite  \
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      TableParamColumns
# 0  LusidInstrumentId (Text) "The instrument identifier LusidInstrumentId"\nFigi (Text) "The instrument identifier Figi"\nClientInternal (Text) "The instrument identifier ClientInternal"\nQuotePermId (Text) "The instrument identifier QuotePermId"\nEdiKey (Text) "The instrument identifier EdiKey"\nSecurityNumber (Text) "The instrument identifier SecurityNumber"\nIsin (Text) "The instrument identifier Isin"\nSedol (Text) "The instrument identifier Sedol"\nCusip (Text) "The instrument identifier Cusip"\nTicker (Text) "The instrument identifier Ticker"\nCompositeFigi (Text) "The instrument identifier CompositeFigi"\nShareClassFigi (Text) "The instrument identifier ShareClassFigi"\nWertpapier (Text) "The instrument identifier Wertpapier"\nRIC (Text) "The instrument identifier RIC"\nScope (Text) "The scope in which the instrument lies."\nDisplayName (Text) "The instrument's display name."\nLookThroughPortfolioScope (Text) "The instrument's look-through portfolio scope, if applicable."\nLookThroughPortfolioCode (Text) "The instrument's look-through portfolio code, if applicable."\nIdentifiers (Text)\nDomCcy (Text)\nWriteAction (Text) "Whether to upsert or soft/hard delete the current row. If omitted defaults to upsert i.e. insert if Instrument does not exist and update if existsThe available values are: Upsert, SoftDelete, HardDelete"\nCountryOfIncorporation (Text)\nExchange (Text) "Exchange the instrument trades on"\nIssuerId (Text)\nIssuerName (Text)\nLegalEntityId (Text)\nNaicsCode (Text)\nParValue (Decimal) "ParValue"\nPrimaryCurrency (Text)\nPrimaryExchange (Text)\nSecurityId (Text)

# %% [markdown]
# We can see there's a `ToWrite` column which accepts a table of equities. By convention, many Lusid write providers use `toWrite` as a table parameter, returning the written values in the table, and some error information.
#
# We recommend examining the results of every write query using one or more of the `WriteError`, `WriteErrorCode` and `WriteErrorDetail` fields.
#
# For each record in the table of data to write, `Lusid.Portfolio.Writer` returns an error code. If the operation is successful, the error code is 0. If unsuccessful, a positive error code and explanation help you discover why LUSID considers the operation invalid.

# %%
# %%luminesce
# select * from Sys.Field where TableName = 'Lusid.Instrument.Equity.Writer';
# Out:
#                          TableName                  FieldName
# 0   Lusid.Instrument.Equity.Writer             ClientInternal  \
# 1   Lusid.Instrument.Equity.Writer              CompositeFigi
# 2   Lusid.Instrument.Equity.Writer     CountryOfIncorporation
# 3   Lusid.Instrument.Equity.Writer                      Cusip
# 4   Lusid.Instrument.Equity.Writer  DeletePropertiesWhereNull
# 5   Lusid.Instrument.Equity.Writer                DisplayName
# 6   Lusid.Instrument.Equity.Writer                     DomCcy
# 7   Lusid.Instrument.Equity.Writer                     EdiKey
# 8   Lusid.Instrument.Equity.Writer              EffectiveFrom
# 9   Lusid.Instrument.Equity.Writer                   Exchange
# 10  Lusid.Instrument.Equity.Writer                       Figi
# 11  Lusid.Instrument.Equity.Writer                Identifiers
# 12  Lusid.Instrument.Equity.Writer         InferredAssetClass
# 13  Lusid.Instrument.Equity.Writer             InferredDomCcy
# 14  Lusid.Instrument.Equity.Writer                   IsActive
# 15  Lusid.Instrument.Equity.Writer                       Isin
# 16  Lusid.Instrument.Equity.Writer                   IssuerId
# 17  Lusid.Instrument.Equity.Writer                 IssuerName
# 18  Lusid.Instrument.Equity.Writer              LegalEntityId
# 19  Lusid.Instrument.Equity.Writer   LookThroughPortfolioCode
# 20  Lusid.Instrument.Equity.Writer  LookThroughPortfolioScope
# 21  Lusid.Instrument.Equity.Writer          LusidInstrumentId
# 22  Lusid.Instrument.Equity.Writer                  NaicsCode
# 23  Lusid.Instrument.Equity.Writer                   ParValue
# 24  Lusid.Instrument.Equity.Writer            PrimaryCurrency
# 25  Lusid.Instrument.Equity.Writer            PrimaryExchange
# 26  Lusid.Instrument.Equity.Writer   PropertiesEffectiveUntil
# 27  Lusid.Instrument.Equity.Writer                QuotePermId
# 28  Lusid.Instrument.Equity.Writer                        RIC
# 29  Lusid.Instrument.Equity.Writer                      Scope
# 30  Lusid.Instrument.Equity.Writer                 SecurityId
# 31  Lusid.Instrument.Equity.Writer             SecurityNumber
# 32  Lusid.Instrument.Equity.Writer                      Sedol
# 33  Lusid.Instrument.Equity.Writer             ShareClassFigi
# 34  Lusid.Instrument.Equity.Writer                      State
# 35  Lusid.Instrument.Equity.Writer                     Ticker
# 36  Lusid.Instrument.Equity.Writer                    ToWrite
# 37  Lusid.Instrument.Equity.Writer                       Type
# 38  Lusid.Instrument.Equity.Writer                 Wertpapier
# 39  Lusid.Instrument.Equity.Writer                WriteAction
# 40  Lusid.Instrument.Equity.Writer                  WriteAsAt
# 41  Lusid.Instrument.Equity.Writer                 WriteError
# 42  Lusid.Instrument.Equity.Writer             WriteErrorCode
# 43  Lusid.Instrument.Equity.Writer           WriteErrorDetail
#
#                             Source  DataType  FieldType IsPrimaryKey IsMain
# 0   fbn-ci.global/client-fbn-ci.sm      Text     Column        False   True  \
# 1   fbn-ci.global/client-fbn-ci.sm      Text     Column        False  False
# 2   fbn-ci.global/client-fbn-ci.sm      Text     Column        False  False
# 3   fbn-ci.global/client-fbn-ci.sm      Text     Column        False  False
# 4   fbn-ci.global/client-fbn-ci.sm   Boolean  Parameter          NaN    NaN
# 5   fbn-ci.global/client-fbn-ci.sm      Text     Column        False   True
# 6   fbn-ci.global/client-fbn-ci.sm      Text     Column        False  False
# 7   fbn-ci.global/client-fbn-ci.sm      Text     Column        False   True
# 8   fbn-ci.global/client-fbn-ci.sm  DateTime  Parameter          NaN    NaN
# 9   fbn-ci.global/client-fbn-ci.sm      Text     Column        False  False
# 10  fbn-ci.global/client-fbn-ci.sm      Text     Column        False   True
# 11  fbn-ci.global/client-fbn-ci.sm      Text     Column        False  False
# 12  fbn-ci.global/client-fbn-ci.sm      Text     Column        False   True
# 13  fbn-ci.global/client-fbn-ci.sm      Text     Column        False   True
# 14  fbn-ci.global/client-fbn-ci.sm   Boolean     Column        False   True
# 15  fbn-ci.global/client-fbn-ci.sm      Text     Column        False  False
# 16  fbn-ci.global/client-fbn-ci.sm      Text     Column        False  False
# 17  fbn-ci.global/client-fbn-ci.sm      Text     Column        False  False
# 18  fbn-ci.global/client-fbn-ci.sm      Text     Column        False  False
# 19  fbn-ci.global/client-fbn-ci.sm      Text     Column        False  False
# 20  fbn-ci.global/client-fbn-ci.sm      Text     Column        False  False
# 21  fbn-ci.global/client-fbn-ci.sm      Text     Column        False   True
# 22  fbn-ci.global/client-fbn-ci.sm      Text     Column        False  False
# 23  fbn-ci.global/client-fbn-ci.sm   Decimal     Column        False  False
# 24  fbn-ci.global/client-fbn-ci.sm      Text     Column        False  False
# 25  fbn-ci.global/client-fbn-ci.sm      Text     Column        False  False
# 26  fbn-ci.global/client-fbn-ci.sm  DateTime  Parameter          NaN    NaN
# 27  fbn-ci.global/client-fbn-ci.sm      Text     Column        False   True
# 28  fbn-ci.global/client-fbn-ci.sm      Text     Column        False  False
# 29  fbn-ci.global/client-fbn-ci.sm      Text     Column        False   True
# 30  fbn-ci.global/client-fbn-ci.sm      Text     Column        False  False
# 31  fbn-ci.global/client-fbn-ci.sm      Text     Column        False   True
# 32  fbn-ci.global/client-fbn-ci.sm      Text     Column        False  False
# 33  fbn-ci.global/client-fbn-ci.sm      Text     Column        False  False
# 34  fbn-ci.global/client-fbn-ci.sm      Text     Column        False   True
# 35  fbn-ci.global/client-fbn-ci.sm      Text     Column        False  False
# 36  fbn-ci.global/client-fbn-ci.sm     Table  Parameter          NaN    NaN
# 37  fbn-ci.global/client-fbn-ci.sm      Text     Column        False   True
# 38  fbn-ci.global/client-fbn-ci.sm      Text     Column        False  False
# 39  fbn-ci.global/client-fbn-ci.sm      Text     Column        False  False
# 40  fbn-ci.global/client-fbn-ci.sm  DateTime     Column        False  False
# 41  fbn-ci.global/client-fbn-ci.sm      Text     Column        False   True
# 42  fbn-ci.global/client-fbn-ci.sm       Int     Column        False  False
# 43  fbn-ci.global/client-fbn-ci.sm      Text     Column        False  False
#
#        ParamDefaultValue
# 0                    NaN  \
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                  False
# 5                    NaN
# 6                    NaN
# 7                    NaN
# 8   0001-01-01T00:00:00Z
# 9                    NaN
# 10                   NaN
# 11                   NaN
# 12                   NaN
# 13                   NaN
# 14                   NaN
# 15                   NaN
# 16                   NaN
# 17                   NaN
# 18                   NaN
# 19                   NaN
# 20                   NaN
# 21                   NaN
# 22                   NaN
# 23                   NaN
# 24                   NaN
# 25                   NaN
# 26  0001-01-01T00:00:00Z
# 27                   NaN
# 28                   NaN
# 29                   NaN
# 30                   NaN
# 31                   NaN
# 32                   NaN
# 33                   NaN
# 34                   NaN
# 35                   NaN
# 36                   NaN
# 37                   NaN
# 38                   NaN
# 39                   NaN
# 40                   NaN
# 41                   NaN
# 42                   NaN
# 43                   NaN
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       TableParamColumns
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   NaN  \
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   NaN
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   NaN
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   NaN
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   NaN
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   NaN
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   NaN
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   NaN
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   NaN
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   NaN
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  NaN
# 11                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  NaN
# 12                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  NaN
# 13                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  NaN
# 14                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  NaN
# 15                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  NaN
# 16                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  NaN
# 17                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  NaN
# 18                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  NaN
# 19                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  NaN
# 20                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  NaN
# 21                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  NaN
# 22                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  NaN
# ...
# 15                                                                                                                                                                                                                                                                                                                                                                                                    The instrument identifier Isin
# 16                                                                                                                                                                                                                                                                                                                                                                                                                               NaN
# 17                                                                                                                                                                                                                                                                                                                                                                                                                               NaN
# 18                                                                                                                                                                                                                                                                                                                                                                                                                               NaN
# 19                                                                                                                                                                                                                                                                                                                                                                      The instrument's look-through portfolio code, if applicable.
# 20                                                                                                                                                                                                                                                                                                                                                                     The instrument's look-through portfolio scope, if applicable.
# 21                                                                                                                                                                                                                                                                                                                                                                                       The instrument identifier LusidInstrumentId
# 22                                                                                                                                                                                                                                                                                                                                                                                                                               NaN
# 23                                                                                                                                                                                                                                                                                                                                                                                                                          ParValue
# 24                                                                                                                                                                                                                                                                                                                                                                                                                               NaN
# 25                                                                                                                                                                                                                                                                                                                                                                                                                               NaN
# 26                                                                                                                                                                                                                                                                                                                                          Effective time that properties are valid until. Default if unspecified is until infinity
# 27                                                                                                                                                                                                                                                                                                                                                                                             The instrument identifier QuotePermId
# 28                                                                                                                                                                                                                                                                                                                                                                                                     The instrument identifier RIC
# 29                                                                                                                                                                                                                                                                                                                                                                                           The scope in which the instrument lies.
# 30                                                                                                                                                                                                                                                                                                                                                                                                                               NaN
# 31                                                                                                                                                                                                                                                                                                                                                                                          The instrument identifier SecurityNumber
# 32                                                                                                                                                                                                                                                                                                                                                                                                   The instrument identifier Sedol
# 33                                                                                                                                                                                                                                                                                                                                                                                          The instrument identifier ShareClassFigi
# 34                                                                                                                                                                                                                                                                                                                                                                                   Instrument state e.g. Active, Inactive, Deleted
# 35                                                                                                                                                                                                                                                                                                                                                                                                  The instrument identifier Ticker
# 36  Available columns: LusidInstrumentId, Figi, ClientInternal, QuotePermId, EdiKey, SecurityNumber, Isin, Sedol, Cusip, Ticker, CompositeFigi, ShareClassFigi, Wertpapier, RIC, Scope, DisplayName, LookThroughPortfolioScope, LookThroughPortfolioCode, Identifiers, DomCcy, WriteAction, CountryOfIncorporation, Exchange, IssuerId, IssuerName, LegalEntityId, NaicsCode, ParValue, PrimaryCurrency, PrimaryExchange, SecurityId
# 37                                                                                                                                                                                                                                                                                                                                                                                   Type of the instrument e.g. Bond, Equity Option
# 38                                                                                                                                                                                                                                                                                                                                                                                              The instrument identifier Wertpapier
# 39                                                                                                                                                                                                                        Whether to upsert or soft/hard delete the current row. If omitted defaults to upsert i.e. insert if Instrument does not exist and update if existsThe available values are: Upsert, SoftDelete, HardDelete
# 40                                                                                                                                                                                                                                                                                                                                                                                                                               NaN
# 41                                                                                                                                                                                                                                                                                                                                                                  A brief description of a write error, otherwise null on success.
# 42                                                                                                                                                                                                                                                                                                                                                                          The error code of a write error, otherwise 0 on success.
# 43                                                                                                                                                                                                                                                                                                                                                               A detailed description of a write error, otherwise null on success.
#
#                      DisplayName ConditionUsage  SampleValues  AllowedValues
# 0                Client Internal            NaN           NaN            NaN
# 1                 Composite Figi            NaN           NaN            NaN
# 2       Country Of Incorporation            NaN           NaN            NaN
# 3                          Cusip            NaN           NaN            NaN
# 4   Delete Properties Where Null            NaN           NaN            NaN
# 5                   Display Name            NaN           NaN            NaN
# 6                        Dom Ccy            NaN           NaN            NaN
# 7                        Edi Key            NaN           NaN            NaN
# 8                 Effective From            NaN           NaN            NaN
# 9                       Exchange            NaN           NaN            NaN
# 10                          Figi            NaN           NaN            NaN
# 11                   Identifiers            NaN           NaN            NaN
# 12          Inferred Asset Class            NaN           NaN            NaN
# 13              Inferred Dom Ccy            NaN           NaN            NaN
# 14                     Is Active            NaN           NaN            NaN
# 15                          Isin            NaN           NaN            NaN
# 16                     Issuer Id            NaN           NaN            NaN
# 17                   Issuer Name            NaN           NaN            NaN
# 18               Legal Entity Id            NaN           NaN            NaN
# 19   Look Through Portfolio Code            NaN           NaN            NaN
# 20  Look Through Portfolio Scope            NaN           NaN            NaN
# 21           Lusid Instrument Id            NaN           NaN            NaN
# 22                    Naics Code            NaN           NaN            NaN
# 23                     Par Value            NaN           NaN            NaN
# 24              Primary Currency            NaN           NaN            NaN
# 25              Primary Exchange            NaN           NaN            NaN
# 26    Properties Effective Until            NaN           NaN            NaN
# 27                 Quote Perm Id            NaN           NaN            NaN
# 28                           RIC            NaN           NaN            NaN
# 29                         Scope            NaN           NaN            NaN
# 30                   Security Id            NaN           NaN            NaN
# 31               Security Number            NaN           NaN            NaN
# 32                         Sedol            NaN           NaN            NaN
# 33              Share Class Figi            NaN           NaN            NaN
# 34                         State            NaN           NaN            NaN
# 35                        Ticker            NaN           NaN            NaN
# 36                      To Write       Required           NaN            NaN
# 37                          Type            NaN           NaN            NaN
# 38                    Wertpapier            NaN           NaN            NaN
# 39                  Write Action            NaN           NaN            NaN
# 40                   Write As At            NaN           NaN            NaN
# 41                   Write Error            NaN           NaN            NaN
# 42              Write Error Code            NaN           NaN            NaN
# 43            Write Error Detail            NaN           NaN            NaN

# %% [markdown]
# We'll upsert some equities. Looking at the [knowledge-base](https://support.lusid.com/knowledgebase/article/KA-01685/en-us), we can see that the `Equity.Writer` Provider must have a DisplayName, at least one unique-identifier, and a `DomCcy`.

# %%
# %%luminesce
# @inserted_values = SELECT
#                     'T2.3-Fake-Equity-1' as DisplayName,
#                     '0000000-000001' as Figi,
#                     'GBP' as DomCcy
#                    UNION
#                    SELECT
#                    'T2.3 Fake Equity-2' as DisplayName,
#                    '0000000-000002' as Figi,
#                    'CHF' as DomCcy;
#
# SELECT *
# FROM @inserted_values;
# Out:
#           DisplayName            Figi DomCcy
# 0  T2.3 Fake Equity-2  0000000-000002    CHF
# 1  T2.3-Fake-Equity-1  0000000-000001    GBP

# %%
# %%luminesce
# @inserted_values = SELECT
#                     'T2.3-Fake-Equity-1' as DisplayName,
#                     '0000000-000001' as Figi,
#                     'GBP' as DomCcy
#                    UNION
#                    SELECT
#                    'T2.3 Fake Equity-2' as DisplayName,
#                    '0000000-000002' as Figi,
#                    'CHF' as DomCcy;
#
# SELECT * FROM Lusid.Instrument.Equity.Writer WHERE toWrite = @inserted_values;
# Out:
#                  WriteAsAt  WriteErrorCode  WriteError  WriteErrorDetail
# 0  2022-12-14 10:32:33.927               0         NaN               NaN  \
# 1  2022-12-14 10:32:33.927               0         NaN               NaN
#
#   WriteAction LusidInstrumentId            Figi  ClientInternal  QuotePermId
# 0      Upsert     LUID_0004MDSK  0000000-000002             NaN          NaN  \
# 1      Upsert     LUID_0004MDSJ  0000000-000001             NaN          NaN
#
#    EdiKey  ...  CountryOfIncorporation  Exchange  IssuerId  IssuerName
# 0     NaN  ...                     NaN       NaN       NaN         NaN  \
# 1     NaN  ...                     NaN       NaN       NaN         NaN
#
#    LegalEntityId  NaicsCode  ParValue  PrimaryCurrency  PrimaryExchange
# 0            NaN        NaN       NaN              NaN              NaN  \
# 1            NaN        NaN       NaN              NaN              NaN
#
#   SecurityId
# 0        NaN
# 1        NaN
#
# [2 rows x 40 columns]

# %% [markdown]
# As you can see, a table is returned with the values we've written, some values auto-created by LUSID, and error information (if there was an error).

# %% [markdown]
# #### Drive.SaveAs

# %% [markdown]
# The `Drive.SaveAs` Provider is a Direct Provider that allows you to write tables of data to different types of file. As its a direct provider that has its own arbritrary syntax used to tell the Provider what data to write, to which file type, and how to write the data.

# %%
# %%luminesce
# @inserted_file = SELECT
#                 'Marge' as CharacterName,
#                 '35' as Age,
#                 'Married' as Status;
# SELECT * FROM @inserted_file;
# Out:
#   CharacterName  Age   Status
# 0         Marge   35  Married

# %%
# %%luminesce
# @inserted_file = SELECT
#                 'Marge' as CharacterName,
#                 '35' as Age,
#                 'Married' as Status;
#
# @x = use Drive.SaveAs with @inserted_file
# --path=/finbourne university
# --fileNames=simpsons
# --type=Csv
# enduse;
# select * from @x
# Out:
#      VariableName                        FileName  RowCount  Skipped
# 0  @inserted_file  /finbourne university/simpsons         1    False

# %% [markdown]
# We can see from the table that a simpsons.csv file has been written to drive, containing one row.

# %% [markdown]
# ## Luminesce views

# %% [markdown]
# You can use the Sys.Admin.SetupView direct provider supplied by FINBOURNE to create a ‘view’ that can access any number of other Luminesce providers (or existing views).
#
# The goal is to enable end users to write simplified or more performant queries using this view instead of the underlying providers directly, obscuring complexity, increasing productivity and promoting adoption.

# %% [markdown]
# Provider creation syntax
#
#     @x = use Sys.Admin.SetupView [with @@scalar_var1 [, @@scalar_var2...]]
#     <options-section>
#     ----
#     <sql-section>
#     enduse;
#     -- The following statement is optional but useful while creating the view to test it returns meaningful data
#     select * from @x

# %% [markdown]
# SetupView works similarly to other direct Providers. You create a variable using `SetupView`, and can pass parameters using the with syntax.
# You can specify options on the View Provider as usual, by passing `--<key>=<value>` pairs to the Provider.
# Once you have configured the provider, use 4 dashes `----` to separate options from the SQLite operation you'd like to use in your View.

# %%
# %%luminesce
# @x = use Sys.Admin.SetupView
# --provider=Views.FBNUNIVIEW
# ----
# SELECT #SELECT {
#   { EquityName: i.DisplayName },
# }
# FROM Lusid.Instrument.Equity i
# WHERE i.DisplayName LIKE 'A%'
# enduse;
# Out:
# Empty DataFrame
# Columns: [rowid_noop_alias]
# Index: []

# %% [markdown]
# Here we've created a view called `Views.FBNUNIVIEW` which selects any DisplayNames that begin with 'A' from `Lusid.Instrument.Equity` and maps the `DisplayName` column to `EquityName`.
#
# The `#SELECT` is special syntax used to signify to luminesce that this query should be optimized, described in the [setupview article](https://support.lusid.com/knowledgebase/article/KA-01767/en-us) in the knowledgebase.
#
# We can now use this view to query data:

# %%
# %%luminesce
# SELECT * FROM Views.FBNUNIVIEW
# LIMIT 10;
# Out:
#         EquityName
# 0  AstraZeneca1221
# 1  AstraZeneca1392
# 2    Ashtead Group
# 3  AstraZeneca1715
# 4  AstraZeneca1709
# 5  AstraZeneca1839
# 6  AstraZeneca1567
# 7  AstraZeneca1791
# 8    Ashtead Group
# 9  AstraZeneca1517

# %% [markdown]
# We've selected 10 of the Equities that would've been returned from our view.
