# %%
from lusidtools.jupyter_tools import toggle_code

"""Luminesce Syntax

Attributes
----------

"""

toggle_code("Toggle Docstring")
# Out:
#     <form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Toggle Docstring"></form>
#
#          <script>
#          function code_toggle() {
#              if ($('div.cell.code_cell.rendered.selected div.input').css('display')!='none'){
#                  $('div.cell.code_cell.rendered.selected div.input').hide();
#              } else {
#                  $('div.cell.code_cell.rendered.selected div.input').show();
#              }
#          }
#          </script>

# %%
from lusid.utilities import ApiClientFactory
from lusidjam import RefreshingToken
import lusid as lu
import pandas as pd
import lusid_drive
import lusid_drive.rest
import lusid.rest
from lusid_drive.rest import ApiException
from pprint import pprint
import json

pd.set_option('display.max_colwidth', None)
secrets_path = os.getenv("FBN_SECRETS_PATH")

api_factory = ApiClientFactory(
    token = RefreshingToken(), 
    api_secrets_filename = secrets_path,
    app_name = "LusidJupyterNotebook"
)

# Confirm success by printing SDK version
api_status = pd.DataFrame(api_factory.build(lu.ApplicationMetadataApi).get_lusid_versions().to_dict())
display(api_status)
# Out:
#   api_version build_version excel_version  \
# 0          v0   0.6.10321.0      0.5.3088
#
#                                                links
# 0  {'relation': 'RequestLogs', 'href': 'http://fb...

# %%
# here's some sample equities we've prepared earlier
uk_equity_instruments = pd.read_csv('_data/uk_equity_instruments.csv')
us_equity_instruments = pd.read_csv('_data/us_equity_instruments.csv')

# %%
# don't show exception if error is due to upsert
def exception_guard(e, code):
    return e.status and e.status != '400 Bad Request' and e.body and json.loads(e.body)["code"] == code

scope = 'FBNUniversity' # str | The scope of the portfolio.

# %%
# create a request to upsert a bunch of instruments.
def generate_upsert_instrument_request(api_instance, name, ccy, figi, isin, other_identifier_name, other_identifier):
    request_id = name + isin
    request ={"name":name,
                     "identifiers":{ "Figi":{"value":figi},
                                     "Isin":{"value":isin},
                                     other_identifier_name:{"value":other_identifier}
                                   },

                     "definition":{"instrumentType":"Equity", "domCcy":ccy}}
    return request_id, request

# %%
# Create an instance of the API class
api_instance = api_factory.build(lu.InstrumentsApi)

# We're going to load some american and UK equities into LUSID

other_identifier_name = 'Sedol'
ccy = 'GBP'
upsert_body_tuple = (generate_upsert_instrument_request(api_instance, name, ccy, figi, isin, other_identifier_name, other_identifier)
               for 
               index, ticker, name, _, isin, other_identifier, figi
               in uk_equity_instruments.itertuples())
uk_equity_body_dict = {request_id:request_body for request_id,request_body in upsert_body_tuple}
other_identifier_name = 'Cusip'
ccy = 'USD'
upsert_body_tuple = (generate_upsert_instrument_request(api_instance, name, ccy, figi, isin, other_identifier_name, other_identifier)
               for 
               index, ticker, name, _, isin, other_identifier, figi
               in us_equity_instruments.itertuples())
us_equity_body_dict = {request_id:request_body for request_id,request_body in upsert_body_tuple}

request_body_dict = us_equity_body_dict | uk_equity_body_dict

try:
    # UpsertInstruments: Upsert instruments
    api_response = api_instance.upsert_instruments(request_body_dict, scope=scope)
#     pprint(api_response)
except lusid.rest.ApiException as e:
    print("Exception when calling InstrumentsApi->upsert_instruments: %s\n" % e)

# %%
api_instance = api_factory.build(lu.TransactionPortfoliosApi)
code = 'Module-T2-3' # str | The code of the portfolio. Together with the scope this uniquely identifies the portfolio.
create_transaction_portfolio_request = {"displayName":"Training module T2.3", "baseCurrency":"GBP", "code":code} # UpdatePortfolioRequest | The updated portfolio definition.
try:
    # CreatePortfolio: Create portfolio
    api_response = api_instance.create_portfolio(scope, create_transaction_portfolio_request)
except lusid.rest.ApiException as e:
    if not exception_guard(e, 112):
        print(e)

# %%
# let's chuck a file containing a randomly selected subset of 25 instruments with their sectors into drive for some examples:

subset_file = open('_data/instrument_subset.csv').read()

drive_config = lusid_drive.Configuration(
    host = f'{api_instance.api_client.configuration.host[:-4]}/drive'
)
drive_config.access_token = RefreshingToken()

# Enter a context with an instance of the API client
with lusid_drive.ApiClient(drive_config) as api_client:
    # Create an instance of the API class
    api_instance = lusid_drive.FoldersApi(api_client)
    create_folder = {"path":"/","name":"finbourne university"} # CreateFolder | A CreateFolder object that defines the name and path of the new folder

    try:
        # [EARLY ACCESS] CreateFolder: Create a new folder in LUSID Drive
        api_response = api_instance.create_folder(create_folder)
        pprint(api_response)
    except ApiException as e:
        if not exception_guard(e, 664):
            print("Exception when calling FilesApi->create_file: %s\n" % e)
        
        
    api_instance = lusid_drive.FilesApi(api_client)
    x_lusid_drive_filename = 'instrument_subsetT2.3.csv' # str | File name.
    x_lusid_drive_path = '/finbourne university/' # str | File path.
    content_length = len(subset_file.encode('UTF-8'))
    body = subset_file # str | 

    try:
        # [EARLY ACCESS] CreateFile: Uploads a file to Lusid Drive. If using an SDK, consider using the UploadAsStreamAsync function for larger files instead.
        api_response = api_instance.create_file(x_lusid_drive_filename, x_lusid_drive_path, content_length, body)
    except lusid_drive.rest.ApiException as e:
        if not exception_guard(e, 671):
            print("Exception when calling FilesApi->create_file: %s\n" % e)

# %% [markdown]
# # Providers and Views

# %% [markdown]
# A provider is a component that enables you to write a Luminesce SQL query for a data source in situ, without first having to extract, transform or load data from that source.
#
# We supply providers for numerous data sources, including for the investment data stored in LUSID itself and for files stored in Drive.

# %% [markdown]
# In this part of the course we will cover:

# %% [markdown]
# - Data providers
# - Direct providers
# - Write providers
# - Provider parameters
# - Using Luminesce views
# - Writing Luminesce views

# %% [markdown]
# ## Data providers

# %% [markdown]
# A data provider is designed to query a data source whose shape is known. It therefore returns a table of results with a fixed number of fields (columns).
#
# Most of the providers we supply to query the investment management data stored in LUSID itself are data providers with a fixed number of fields, making it easier to query the data using standard SQL query syntax and luminesce extensions.
#
# A data provider does not have to query a datasource, as long as it returns some data.For example, we supply providers that perform calculations on demand, such as Lusid.Portfolio.Valuation, where the data returned doesn't actually exist anywhere but rather is calculated each time the provider is queried.

# %% [markdown]
# ## Direct providers

# %% [markdown]
# A direct provider is designed to query a data source whose shape is not known, and thus cannot return a table of results with a fixed number of fields (columns).
#
# A Luminesce query for a direct provider uses an arbitrary syntax, which may differ for each provider, and is defined by the writer of the provider.
#
#     @variable = use Some.Provider [wait]
#     <arbitrary-syntax>
#     enduse;
#     select * from @variable

# %% [markdown]
#
# Some direct providers can also interpolate table and scalar parameters into their arbritrary syntax, enabling the use of parameters within the direct provider query using the WITH syntax:
#
#     @@today = select strftime('%Y%m%d', 'now');
#     @table_of_results = use Drive.Csv with @@today
#     --file=/trade-files/eod-{@@today}.csv
#     --noHeader
#     --names=Equity,Units,Cost
#     enduse;
#     select * from @table_of_results

# %% [markdown]
# ## Write providers

# %% [markdown]
# As mentioned earlier, data providers aren't limited to reading data from a datasource. Some providers' primary role is to write data to some target.
#
# Using a write provider is straightforward. Query the Provider passing the data you'd like to write as parameters to fields specified by the provider, for example:
#
#     @table_of_data = <select-statement>;
#     select * from <Provider>.Writer where toWrite = @table_of_data;
#
# By convention, many write providers accept a table of values as a parameter, and specify the expected columns in their fields.

# %% [markdown]
# ## Examples of Lusid Providers

# %% [markdown]
# In this section we'll demonstrate some simple examples using the different types of provider.

# %% [markdown]
# ### Data Providers

# %% [markdown]
# #### Lusid.Instrument.Equity Provider

# %% [markdown]
# Luminesce has a number of Lusid.Instrument providers that enable you to write a Luminesce query to retrieve instruments mastered in LUSID.
#
# The generic Lusid.Instrument provider retrieves basic information about instruments of any asset class. Dedicated providers retrieve instruments of a particular asset class, for example Lusid.Instrument.Bond retrieves the full economic definition of bond instruments.

# %% [markdown]
# We'll use the Lusid.Instrument Provider to query for the equities we have stored in Lusid. Then we'll use the Lusid.Instrument.Equity Provider to look at the full economic definition of stored equity instruments.

# %%
# %%luminesce
# SELECT *
# FROM Lusid.Instrument
# LIMIT 100
# Out:
#    LusidInstrumentId          Isin    Sedol      Cusip  Ticker  \
# 0      LUID_00003DA2  US7223041028      NaN  722304102     NaN
# 1            CCY_MYR           NaN      NaN        NaN     NaN
# 2      LUID_00003DBG  US83088M1027      NaN  83088M102     NaN
# 3            CCY_TTD           NaN      NaN        NaN     NaN
# 4            CCY_CDF           NaN      NaN        NaN     NaN
# ..               ...           ...      ...        ...     ...
# 95     LUID_00003DE4  US8716071076      NaN  871607107     NaN
# 96     LUID_00003DAF  US0079031078      NaN    7903107     NaN
# 97     LUID_00003DLS  GB00B019KW72  B019KW7        NaN     NaN
# 98           CCY_ALL           NaN      NaN        NaN     NaN
# 99     LUID_00003DE0  US1567821046      NaN  156782104     NaN
#
#     ClientInternal          Figi  CompositeFigi  ShareClassFigi  Wertpapier  \
# 0              NaN  BBG00LBLDDR2            NaN             NaN         NaN
# 1              NaN           NaN            NaN             NaN         NaN
# 2              NaN  BBG000GB4HW0            NaN             NaN         NaN
# 3              NaN           NaN            NaN             NaN         NaN
# 4              NaN           NaN            NaN             NaN         NaN
# ..             ...           ...            ...             ...         ...
# 95             NaN  BBG000BSFRF3            NaN             NaN         NaN
# 96             NaN  BBG000BBQCY0            NaN             NaN         NaN
# 97             NaN  BBG000BF0KW3            NaN             NaN         NaN
# 98             NaN           NaN            NaN             NaN         NaN
# 99             NaN  BBG000BFDLV8            NaN             NaN         NaN
#
#     ...  QuotePermId  EdiKey                     Scope  \
# 0   ...          NaN     NaN            fbn-uni-T02002
# 1   ...          NaN     NaN                   default
# 2   ...          NaN     NaN            fbn-uni-T02002
# 3   ...          NaN     NaN                   default
# 4   ...          NaN     NaN                   default
# ..  ...          ...     ...                       ...
# 95  ...          NaN     NaN             FBNUniversity
# 96  ...          NaN     NaN            fbn-uni-T02002
# 97  ...          NaN     NaN  FBNUniversityModule-T2-2
# 98  ...          NaN     NaN                   default
# 99  ...          NaN     NaN             FBNUniversity
#
#                  DisplayName LookThroughPortfolioScope  \
# 0             Pinduoduo Inc.                       NaN
# 1                        MYR                       NaN
# 2   Skyworks Solutions, Inc.                       NaN
# 3                        TTD                       NaN
# 4                        CDF                       NaN
# ..                       ...                       ...
# 95            Synopsys, Inc.                       NaN
# 96    Advanced Micro Devices                       NaN
# 97               Sainsbury's                       NaN
# 98                       ALL                       NaN
# 99        Cerner Corporation                       NaN
#
#     LookThroughPortfolioCode    Type InferredAssetClass InferredDomCcy  \
# 0                        NaN  Equity           Equities            USD
# 1                        NaN     NaN            Unknown            ZZZ
# 2                        NaN  Equity           Equities            USD
# 3                        NaN     NaN            Unknown            ZZZ
# 4                        NaN     NaN            Unknown            ZZZ
# ..                       ...     ...                ...            ...
# 95                       NaN  Equity           Equities            USD
# 96                       NaN  Equity           Equities            USD
# 97                       NaN  Equity           Equities            GBP
# 98                       NaN     NaN            Unknown            ZZZ
# 99                       NaN  Equity           Equities            USD
#
#    IsActive
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# ..      ...
# 95     True
# 96     True
# 97     True
# 98     True
# 99     True
#
# [100 rows x 21 columns]

# %% [markdown]
# The Lusid.Instrument.Equity Provider has a couple of extra fields: DomCcy & Identifiers, and will only return Instruments which are equities.

# %%
# %%luminesce
# SELECT DisplayName, DomCcy
# FROM Lusid.Instrument.Equity
# LIMIT 100
# Out:
#                    DisplayName DomCcy
# 0               Pinduoduo Inc.    USD
# 1     Skyworks Solutions, Inc.    USD
# 2                PepsiCo, Inc.    USD
# 3                 MercadoLibre    USD
# 4                       Splunk    USD
# ..                         ...    ...
# 95  Intermediate Capital Group    GBP
# 96               Coca-Cola HBC    GBP
# 97              Facebook, Inc.    USD
# 98          Idexx Laboratories    USD
# 99                ASML Holding    USD
#
# [100 rows x 2 columns]

# %% [markdown]
# #### Lusid.Portfolio Provider

# %% [markdown]
# The Lusid.Portfolio provider enables you to write a Luminesce SQL query that retrieves information about one or more portfolios.

# %%
# %%luminesce
# SELECT *
# FROM Lusid.Portfolio
# LIMIT 100
# Out:
#   PortfolioScope PortfolioCode PortfolioType BaseCurrency  \
# 0  FBNUniversity    Module-6-4   Transaction          GBP
# 1  FBNUniversity    Module-6-1   Transaction          GBP
# 2  FBNUniversity    Module-6-3   Transaction          GBP
# 3  FBNUniversity    Module-3-1   Transaction          GBP
# 4  FBNUniversity   Module-T2-2   Transaction          GBP
# 5  FBNUniversity    Module-6-2   Transaction          GBP
# 6  FBNUniversity      Module-1   Transaction          GBP
# 7  FBNUniversity   Module-T2-3   Transaction          GBP
# 8  FBNUniversity    Module-3-2   Transaction          GBP
# 9  FBNUniversity    Module-4-1   Transaction          GBP
#
#                                          DisplayName  \
# 0  Training module 6.4 - Track commission as sepa...
# 1  Training module 6.1 - Different transaction co...
# 2  Training module 6.3 - Reduce cash balance by c...
# 3                                Training module 3.1
# 4                               Training module T2.2
# 5  Training module 6.2 - Same transaction code, d...
# 6                                           Module 1
# 7                               Training module T2.3
# 8                                Training module 3.2
# 9                                Training module 4.1
#
#                         Description OriginPortfolioScope OriginPortfolioCode  \
# 0                               NaN        FBNUniversity          Module-6-4
# 1                               NaN        FBNUniversity          Module-6-1
# 2                               NaN        FBNUniversity          Module-6-3
# 3                               NaN        FBNUniversity          Module-3-1
# 4  A portfolio to hold transactions        FBNUniversity         Module-T2-2
# 5                               NaN        FBNUniversity          Module-6-2
# 6                               NaN        FBNUniversity            Module-1
# 7                               NaN        FBNUniversity         Module-T2-3
# 8                               NaN        FBNUniversity          Module-3-2
# 9                               NaN        FBNUniversity          Module-4-1
#
#    ParentPortfolioScope  ParentPortfolioCode  ChildPortfolioIds  \
# 0                   NaN                  NaN                NaN
# 1                   NaN                  NaN                NaN
# 2                   NaN                  NaN                NaN
# 3                   NaN                  NaN                NaN
# 4                   NaN                  NaN                NaN
# 5                   NaN                  NaN                NaN
# 6                   NaN                  NaN                NaN
# 7                   NaN                  NaN                NaN
# 8                   NaN                  NaN                NaN
# 9                   NaN                  NaN                NaN
#
#    CorporateActionSourceScope  CorporateActionSourceId AccountingMethod  \
# 0                         NaN                      NaN          Default
# 1                         NaN                      NaN          Default
# 2                         NaN                      NaN          Default
# 3                         NaN                      NaN          Default
# 4                         NaN                      NaN          Default
# 5                         NaN                      NaN          Default
# 6                         NaN                      NaN          Default
# 7                         NaN                      NaN          Default
# 8                         NaN                      NaN          Default
# 9                         NaN                      NaN          Default
#
#                               SubHoldingKeys                  Created  \
# 0  Transaction/FBNUniversity/TrackCommission               2022-01-01
# 1                                        NaN               2022-01-01
# 2                                        NaN               2022-01-01
# 3       Transaction/FBNUniversity/Module-3-1               2022-01-01
# 4                                        NaN  2022-11-03 20:14:15.334
# 5                                        NaN               2022-01-01
# 6                                        NaN               2021-12-01
# 7                                        NaN  2022-11-21 15:59:45.669
# 8                                        NaN               2022-01-01
# 9                                        NaN               2022-01-01
#
#            InstrumentScopes
# 0   FBNUniversityModule-6-4
# 1   FBNUniversityModule-6-1
# 2   FBNUniversityModule-6-3
# 3   FBNUniversityModule-3-1
# 4  FBNUniversityModule-T2-2
# 5   FBNUniversityModule-6-2
# 6     FBNUniversityModule-1
# 7                       NaN
# 8   FBNUniversityModule-3-2
# 9   FBNUniversityModule-4-1

# %% [markdown]
# Here we've returned all metadata about our Portfolios in Lusid.

# %% [markdown]
# #### Lusid.Tools Provider

# %% [markdown]
# The Lusid.Tools Provider does not query any data. It manipulates the input parameters to return a table.
#
# The Tools.JsonExpand provider enables you to write a Luminesce query that parses a JSON document into a table of constituent data objects, much like the SQLite json.tree function. We'll use this to demonstrate a data provider that does not query for any external data, instead manipulating the provided parameters.

# %%
# %%luminesce
# @@jsn = SELECT '{
#     "characters":[
#         {"name":"marge",
#          "age":36},
#         {"name":"homer",
#          "age":40},
#         {"name":"bart",
#          "age":9},
#         {"name":"lisa",
#          "age":12}
#     ]
# }';
# SELECT * FROM Tools.JsonExpand WHERE JsonString = @@jsn
# Out:
#            key                                              value     type  \
# 0          NaN  {"characters":[{"name":"marge","age":36},{"nam...   object
# 1   characters  [{"name":"marge","age":36},{"name":"homer","ag...    array
# 2            0                          {"name":"marge","age":36}   object
# 3         name                                              marge     text
# 4          age                                                 36  integer
# 5            1                          {"name":"homer","age":40}   object
# 6         name                                              homer     text
# 7          age                                                 40  integer
# 8            2                            {"name":"bart","age":9}   object
# 9         name                                               bart     text
# 10         age                                                  9  integer
# 11           3                           {"name":"lisa","age":12}   object
# 12        name                                               lisa     text
# 13         age                                                 12  integer
#
#      atom  id  parent               fullkey             path
# 0     NaN   0     NaN                     $                $
# 1     NaN   2     0.0          $.characters                $
# 2     NaN   3     2.0       $.characters[0]     $.characters
# 3   marge   5     3.0  $.characters[0].name  $.characters[0]
# 4      36   7     3.0   $.characters[0].age  $.characters[0]
# 5     NaN   8     2.0       $.characters[1]     $.characters
# 6   homer  10     8.0  $.characters[1].name  $.characters[1]
# 7      40  12     8.0   $.characters[1].age  $.characters[1]
# 8     NaN  13     2.0       $.characters[2]     $.characters
# 9    bart  15    13.0  $.characters[2].name  $.characters[2]
# 10      9  17    13.0   $.characters[2].age  $.characters[2]
# 11    NaN  18     2.0       $.characters[3]     $.characters
# 12   lisa  20    18.0  $.characters[3].name  $.characters[3]
# 13     12  22    18.0   $.characters[3].age  $.characters[3]

# %%
# %%luminesce
# @@jsn = SELECT '{
#     "characters":[
#         {"name":"marge",
#          "age":36},
#         {"name":"homer",
#          "age":40},
#         {"name":"bart",
#          "age":9},
#         {"name":"lisa",
#          "age":12}
#     ]
# }';
# @@selection = select "$.characters[0]";
# select * from Tools.JsonExpand where JsonString = @@jsn and RootPath = @@selection
# Out:
#     key                      value     type   atom  id  parent  \
# 0   NaN  {"name":"marge","age":36}   object    NaN   3     NaN
# 1  name                      marge     text  marge   5     3.0
# 2   age                         36  integer     36   7     3.0
#
#                 fullkey             path
# 0       $.characters[0]     $.characters
# 1  $.characters[0].name  $.characters[0]
# 2   $.characters[0].age  $.characters[0]

# %% [markdown]
# ### Direct Providers

# %% [markdown]
# #### Drive.Csv Provider

# %% [markdown]
# The Drive.Csv provider enables you to write a Luminesce query that extracts data from one or more CSV or similar pipe-delimited or row-based text files stored in Drive.
# We can pass a number of options to the Drive CSV provider, using the syntax `--<option>[=<value>]`

# %%
# %%luminesce
# @x = use Drive.Csv
# --file=/finbourne university/instrument_subsetT2.3.csv
# --noHeader
# --names=Name,Sector,Identifier
# enduse;
# select * from @x
# Out:
#                                   Name                               Sector  \
# 0                            Schroders                   Financial Services
# 1                             DS Smith                  General Industrials
# 2                Flutter Entertainment                     Travel & Leisure
# 3   Scottish Mortgage Investment Trust        Equity Investment Instruments
# 4                        Taylor Wimpey  Household Goods & Home Construction
# 5                                   BP                  Oil & Gas Producers
# 6                             Glencore                               Mining
# 7                                Segro        Real Estate Investment Trusts
# 8                       Prudential plc                       Life Insurance
# 9             Pershing Square Holdings                   Financial Services
# 10               St. James's Place plc                       Life Insurance
# 11               Hikma Pharmaceuticals      Pharmaceuticals & Biotechnology
# 12                  Melrose Industries                  Automobiles & Parts
# 13                     Legal & General                       Life Insurance
# 14                     Land Securities        Real Estate Investment Trusts
# 15                        Ferguson plc                     Support Services
# 16                            Experian                     Support Services
# 17          Intermediate Capital Group                  Investment Services
# 18                          Sage Group         Software & Computer Services
# 19                               Aviva                       Life Insurance
# 20                  Anglo American plc                               Mining
# 21                           Rightmove                                Media
# 22                      Vodafone Group            Mobile Telecommunications
# 23                         Ocado Group                Food & Drug Retailers
# 24                        British Land        Real Estate Investment Trusts
#
#       Identifier
# 0   BBG000BF0TF3
# 1   BBG000BF1LF9
# 2   BBG000DWL6M3
# 3   BBG000BFZMY9
# 4   BBG000BF4KL1
# 5   BBG000C05BD1
# 6   BBG001MM1KV4
# 7   BBG000BF1HY7
# 8   BBG000BDY322
# 9   BBG00747WHS1
# 10  BBG000BRMPC4
# 11  BBG000FG1MF1
# 12  BBG00B5YJC26
# 13  BBG000BDQCG6
# 14  BBG000BDPHS3
# 15  BBG00NZJ0JG0
# 16  BBG000BKFZN3
# 17  BBG000D8KQJ7
# 18  BBG000BN0PP3
# 19  BBG000DDCSJ1
# 20  BBG000BBLDF4
# 21  BBG000DD5X08
# 22  BBG000C6K6G9
# 23  BBG000BDXZH6
# 24  BBG000BD7DW7

# %% [markdown]
# Here we've read all data from the `/finbourne university/instrument_subsetT2.3.csv` file in drive. The file has no headers, so we've specified the no headers option, and provided a set of column names to the Provider.

# %% [markdown]
# ### Write Providers

# %% [markdown]
# #### Lusid.Instrument.Equity.Writer

# %% [markdown]
# Many of our Lusid write providers accept a TableParameter used to write multiple resources to some part of Lusid.

# %% [markdown]
# Now we'll use a Write Provider to create some equities by passing a table of equities as a parameter.

# %% [markdown]
# First let's take a look at the table parameter used by the Lusid.Instruments.Equities provider, and what the table it expects looks like.

# %%
# %%luminesce
# select FieldName, TableParamColumns from Sys.Field where TableName = 'Lusid.Instrument.Equity.Writer' AND DataType = 'Table';
# Out:
#   FieldName  \
# 0   ToWrite
#
#                                                                                                                                                                                                                                                                                                                                                              TableParamColumns
# 0  LusidInstrumentId (Text)\nIsin (Text)\nSedol (Text)\nCusip (Text)\nTicker (Text)\nClientInternal (Text)\nFigi (Text)\nCompositeFigi (Text)\nShareClassFigi (Text)\nWertpapier (Text)\nRIC (Text)\nQuotePermId (Text)\nEdiKey (Text)\nScope (Text)\nDisplayName (Text)\nLookThroughPortfolioScope (Text)\nLookThroughPortfolioCode (Text)\nIdentifiers (Text)\nDomCcy (Text)

# %% [markdown]
# We can see there's a ToWrite column which accepts a table of equities. By convention, many Lusid write providers use toWrite as a table parameter, returning the written values in the table, and some Error information.
#
# We recommend examining the results of every write query using one or more of the WriteError, WriteErrorCode and WriteErrorDetail fields.
#
# For each record in the table of data to write, Lusid.Portfolio.Writer returns an error code. If the operation is successful, the error code is 0. If unsuccessful, a positive error code and explanation help you discover why LUSID considers the operation invalid.

# %%
# %%luminesce
# select * from Sys.Field where TableName = 'Lusid.Instrument.Equity.Writer';
# Out:
#                          TableName                  FieldName        Source  \
# 0   Lusid.Instrument.Equity.Writer             ClientInternal  service-main
# 1   Lusid.Instrument.Equity.Writer              CompositeFigi  service-main
# 2   Lusid.Instrument.Equity.Writer                      Cusip  service-main
# 3   Lusid.Instrument.Equity.Writer  DeletePropertiesWhereNull  service-main
# 4   Lusid.Instrument.Equity.Writer                DisplayName  service-main
# 5   Lusid.Instrument.Equity.Writer                     DomCcy  service-main
# 6   Lusid.Instrument.Equity.Writer                     EdiKey  service-main
# 7   Lusid.Instrument.Equity.Writer              EffectiveFrom  service-main
# 8   Lusid.Instrument.Equity.Writer                       Figi  service-main
# 9   Lusid.Instrument.Equity.Writer                Identifiers  service-main
# 10  Lusid.Instrument.Equity.Writer         InferredAssetClass  service-main
# 11  Lusid.Instrument.Equity.Writer             InferredDomCcy  service-main
# 12  Lusid.Instrument.Equity.Writer                   IsActive  service-main
# 13  Lusid.Instrument.Equity.Writer                       Isin  service-main
# 14  Lusid.Instrument.Equity.Writer   LookThroughPortfolioCode  service-main
# 15  Lusid.Instrument.Equity.Writer  LookThroughPortfolioScope  service-main
# 16  Lusid.Instrument.Equity.Writer          LusidInstrumentId  service-main
# 17  Lusid.Instrument.Equity.Writer   PropertiesEffectiveUntil  service-main
# 18  Lusid.Instrument.Equity.Writer                QuotePermId  service-main
# 19  Lusid.Instrument.Equity.Writer                        RIC  service-main
# 20  Lusid.Instrument.Equity.Writer                      Scope  service-main
# 21  Lusid.Instrument.Equity.Writer                      Sedol  service-main
# 22  Lusid.Instrument.Equity.Writer             ShareClassFigi  service-main
# 23  Lusid.Instrument.Equity.Writer                     Ticker  service-main
# 24  Lusid.Instrument.Equity.Writer                    ToWrite  service-main
# 25  Lusid.Instrument.Equity.Writer                       Type  service-main
# 26  Lusid.Instrument.Equity.Writer                 Wertpapier  service-main
# 27  Lusid.Instrument.Equity.Writer                 WriteError  service-main
# 28  Lusid.Instrument.Equity.Writer             WriteErrorCode  service-main
# 29  Lusid.Instrument.Equity.Writer           WriteErrorDetail  service-main
#
#     DataType  FieldType IsPrimaryKey IsMain     ParamDefaultValue  \
# 0       Text     Column        False  False                   NaN
# 1       Text     Column        False  False                   NaN
# 2       Text     Column        False  False                   NaN
# 3    Boolean  Parameter          NaN    NaN                 False
# 4       Text     Column        False   True                   NaN
# 5       Text     Column        False  False                   NaN
# 6       Text     Column        False  False                   NaN
# 7   DateTime  Parameter          NaN    NaN  0001-01-01T00:00:00Z
# 8       Text     Column        False  False                   NaN
# 9       Text     Column        False  False                   NaN
# 10      Text     Column        False   True                   NaN
# 11      Text     Column        False   True                   NaN
# 12   Boolean     Column        False   True                   NaN
# 13      Text     Column        False  False                   NaN
# 14      Text     Column        False  False                   NaN
# 15      Text     Column        False  False                   NaN
# 16      Text     Column        False   True                   NaN
# 17  DateTime  Parameter          NaN    NaN  0001-01-01T00:00:00Z
# 18      Text     Column        False  False                   NaN
# 19      Text     Column        False  False                   NaN
# 20      Text     Column        False   True                   NaN
# 21      Text     Column        False  False                   NaN
# 22      Text     Column        False  False                   NaN
# 23      Text     Column        False  False                   NaN
# 24     Table  Parameter          NaN    NaN                   NaN
# 25      Text     Column        False   True                   NaN
# 26      Text     Column        False  False                   NaN
# 27      Text     Column        False   True                   NaN
# 28       Int     Column        False  False                   NaN
# 29      Text     Column        False  False                   NaN
#
#                                     TableParamColumns  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24  LusidInstrumentId (Text)\nIsin (Text)\nSedol (...
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#                                           Description  \
# 0            The instrument identifier ClientInternal
# 1             The instrument identifier CompositeFigi
# 2                     The instrument identifier Cusip
# 3   If true, if there isn't a value specified for ...
# 4                      The instrument's display name.
# 5                                                 NaN
# 6                    The instrument identifier EdiKey
# 7   Effective time to upsert at. The provider will...
# 8                      The instrument identifier Figi
# 9                                                 NaN
# 10  Asset class of the instrument, inferred from t...
# 11  Domestic currency, inferred from the instrumen...
# 12  True if the instrument can be used for the boo...
# 13                     The instrument identifier Isin
# 14  The instrument's look-through portfolio code, ...
# 15  The instrument's look-through portfolio scope,...
# 16        The instrument identifier LusidInstrumentId
# 17  Effective time that properties are valid until...
# 18              The instrument identifier QuotePermId
# 19                      The instrument identifier RIC
# 20            The scope in which the instrument lies.
# 21                    The instrument identifier Sedol
# 22           The instrument identifier ShareClassFigi
# 23                   The instrument identifier Ticker
# 24                                                NaN
# 25    Type of the instrument e.g. Bond, Equity Option
# 26               The instrument identifier Wertpapier
# 27  A brief description of a write error, otherwis...
# 28  The error code of a write error, otherwise 0 o...
# 29  A detailed description of a write error, other...
#
#                      DisplayName ConditionUsage  SampleValues  AllowedValues
# 0                Client Internal           None           NaN            NaN
# 1                 Composite Figi           None           NaN            NaN
# 2                          Cusip           None           NaN            NaN
# 3   Delete Properties Where Null           None           NaN            NaN
# 4                   Display Name           None           NaN            NaN
# 5                        Dom Ccy           None           NaN            NaN
# 6                        Edi Key           None           NaN            NaN
# 7                 Effective From           None           NaN            NaN
# 8                           Figi           None           NaN            NaN
# 9                    Identifiers           None           NaN            NaN
# 10          Inferred Asset Class           None           NaN            NaN
# 11              Inferred Dom Ccy           None           NaN            NaN
# 12                     Is Active           None           NaN            NaN
# 13                          Isin           None           NaN            NaN
# 14   Look Through Portfolio Code           None           NaN            NaN
# 15  Look Through Portfolio Scope           None           NaN            NaN
# 16           Lusid Instrument Id           None           NaN            NaN
# 17    Properties Effective Until           None           NaN            NaN
# 18                 Quote Perm Id           None           NaN            NaN
# 19                           RIC           None           NaN            NaN
# 20                         Scope           None           NaN            NaN
# 21                         Sedol           None           NaN            NaN
# 22              Share Class Figi           None           NaN            NaN
# 23                        Ticker           None           NaN            NaN
# 24                      To Write       Required           NaN            NaN
# 25                          Type           None           NaN            NaN
# 26                    Wertpapier           None           NaN            NaN
# 27                   Write Error           None           NaN            NaN
# 28              Write Error Code           None           NaN            NaN
# 29            Write Error Detail           None           NaN            NaN

# %% [markdown]
# We'll upsert some equities. Looking at the [knowledge-base](https://support.lusid.com/knowledgebase/article/KA-01685/en-us), we can see that the Equity.Writer Provider must have a DisplayName, at least one unique-identifier, and a DomCcy.

# %%
# %%luminesce
# @inserted_values = SELECT
#                     'T2.3-Fake-Equity-1' as DisplayName,
#                     '0000000-000001' as Figi,
#                     'GBP' as DomCcy
#                    UNION
#                    SELECT
#                    'T2.3 Fake Equity-2' as DisplayName,
#                    '0000000-000002' as Figi,
#                    'CHF' as DomCcy;
#
# SELECT *
# FROM @inserted_values;
# Out:
#           DisplayName            Figi DomCcy
# 0  T2.3 Fake Equity-2  0000000-000002    CHF
# 1  T2.3-Fake-Equity-1  0000000-000001    GBP

# %%
# %%luminesce
# @inserted_values = SELECT
#                     'T2.3-Fake-Equity-1' as DisplayName,
#                     '0000000-000001' as Figi,
#                     'GBP' as DomCcy
#                    UNION
#                    SELECT
#                    'T2.3 Fake Equity-2' as DisplayName,
#                    '0000000-000002' as Figi,
#                    'CHF' as DomCcy;
#
# SELECT * FROM Lusid.Instrument.Equity.Writer WHERE toWrite = @inserted_values;
# Out:
#    WriteErrorCode  WriteError  WriteErrorDetail LusidInstrumentId  Isin  \
# 0               0         NaN               NaN     LUID_00003DON   NaN
# 1               0         NaN               NaN     LUID_00003DOM   NaN
#
#    Sedol  Cusip  Ticker  ClientInternal            Figi  ...    Scope  \
# 0    NaN    NaN     NaN             NaN  0000000-000002  ...  default
# 1    NaN    NaN     NaN             NaN  0000000-000001  ...  default
#
#           DisplayName  LookThroughPortfolioScope  LookThroughPortfolioCode  \
# 0  T2.3 Fake Equity-2                        NaN                       NaN
# 1  T2.3-Fake-Equity-1                        NaN                       NaN
#
#      Type  InferredAssetClass InferredDomCcy IsActive  Identifiers  DomCcy
# 0  Equity            Equities            CHF     True          NaN     CHF
# 1  Equity            Equities            GBP     True          NaN     GBP
#
# [2 rows x 26 columns]

# %% [markdown]
# As you can see, a table is returned with the values we've written, some values auto-created by Lusid, and error information (if there was an error).

# %% [markdown]
# #### Drive.SaveAs

# %% [markdown]
# The Drive.SaveAs Provider is a Direct Provider that allows you to write tables of data to different types of file. As its a direct provider that has its own arbritrary syntax used to tell the Provider what data to write, to which file type, and how to write the data.

# %%
# %%luminesce
# @inserted_file = SELECT
#                 'Marge' as CharacterName,
#                 '35' as Age,
#                 'Married' as Status;
# SELECT * FROM @inserted_file;
# Out:
#   CharacterName  Age   Status
# 0         Marge   35  Married

# %%
# %%luminesce
# @inserted_file = SELECT
#                 'Marge' as CharacterName,
#                 '35' as Age,
#                 'Married' as Status;
#
# @x = use Drive.SaveAs with @inserted_file
# --path=/finbourne university
# --fileNames=simpsons
# --type=Csv
# enduse;
# select * from @x
# Out:
#      VariableName                        FileName  RowCount  Skipped
# 0  @inserted_file  /finbourne university/simpsons         1    False

# %% [markdown]
# We can see from the table that a simpsons.csv file has been written to drive, containing one row.

# %% [markdown]
# ## Luminesce views

# %% [markdown]
# You can use the Sys.Admin.SetupView direct provider supplied by FINBOURNE to create a ‘view’ that can access any number of other Luminesce providers (or existing views).
#
# The goal is to enable end users to write simplified or more performant queries using this view instead of the underlying providers directly, obscuring complexity, increasing productivity and promoting adoption.

# %% [markdown]
# Provider creation syntax
#
#     @x = use Sys.Admin.SetupView [with @@scalar_var1 [, @@scalar_var2...]]
#     <options-section>
#     ----
#     <sql-section>
#     enduse;
#     -- The following statement is optional but useful while creating the view to test it returns meaningful data
#     select * from @x

# %%
# %%luminesce
# @x = use Sys.Admin.SetupView [with @@scalar_var1 [, @@scalar_var2...]]
# --provider=Views.FBNUNIVIEW
# ----
# SELECT #SELECT {
#   { EquityName: i.DisplayName },
# }
# FROM Lusid.Instrument.Equity i
# Limit 100
# enduse;
# Out:
# Empty DataFrame
# Columns: [rowid_noop_alias]
# Index: []

# %% [markdown]
# Here we've created a view called Views.FBNUNIVIEW which selects 100 DisplayNames from Lusid.Instrument.Equity and maps the DisplayName column to EquityName.
#
# The #SELECT is special syntax used to optimize queries, described in the [setupview article](https://support.lusid.com/knowledgebase/article/KA-01767/en-us) in the knowledgebase.
#
# We can now use this view to query data:

# %%
# %%luminesce
# SELECT * FROM Views.FBNUNIVIEW Limit 10;
# Out:
#                  EquityName
# 0            Pinduoduo Inc.
# 1    Advanced Micro Devices
# 2  Skyworks Solutions, Inc.
# 3             PepsiCo, Inc.
# 4                  Unilever
# 5                    DexCom
# 6               Match Group
# 7                    Splunk
# 8                 Schroders
# 9               Antofagasta

# %% [markdown]
# We've selected 10 of the 100 Equities that would've been returned from our view.
