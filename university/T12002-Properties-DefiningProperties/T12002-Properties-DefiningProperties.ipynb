# %% [markdown]
# <p style="font-family: Montserrat; color: #203443; font-weight: bold; font-size: 125%">What are we going to cover?</p>

# %% [markdown]
# <ul>
#     <li style="color: #ff5200"><p style="font-family: Montserrat; color: #203443">How are Properties identified?</p></li>
# </ul>

# %% [markdown]
# <ul>
#     <li style="color: #ff5200"><p style="font-family: Montserrat; color: #203443">What Data Types can Properties have?</p></li>
# </ul>

# %% [markdown]
# <ul>
#     <li style="color: #ff5200"><p style="font-family: Montserrat; color: #203443">What are the different options for the Lifetime of a Property?</p></li>
# </ul>

# %% [markdown]
# <ul>
#     <li style="color: #ff5200"><p style="font-family: Montserrat; color: #203443">How can Property values be constrained?</p></li>
# </ul>

# %% [markdown]
# <ul>
#     <li style="color: #ff5200"><p style="font-family: Montserrat; color: #203443">How can we create a Property Definition using the LUSID API via the LUSID website?</p></li>
# </ul>

# %% [markdown]
# <ul>
#     <li style="color: #ff5200"><p style="font-family: Montserrat; color: #203443">How can we update, delete and re-create Property Definitions using the LUSID API via the Python SDK?</p></li>
# </ul>

# %% [markdown]
# <p style="font-family: Montserrat; color: #203443; font-weight: bold; font-size: 125%">Listing Data Types</p>

# %%
import pprint

import lusid
from lusidjam import RefreshingToken
from lusidtools.pandas_utils.lusid_pandas import lusid_response_to_data_frame

api_factory = lusid.utilities.ApiClientFactory(token=RefreshingToken())
data_types_api = api_factory.build(lusid.api.DataTypesApi)

# %%
result = data_types_api.list_data_type_summaries(filter="id.scope eq 'system'")

lusid_response_to_data_frame(result)
# Out:
#    type_value_range id.scope                           id.code  \
# 0            Closed   system                      PropertyType
# 1              Open   system                              date
# 2            Closed   system                    TradePriceType
# 3            Closed   system                      CalendarType
# 4            Closed   system                        Multiplier
# 5              Open   system                        percentage
# 6            Closed   system                         ValueType
# 7              Open   system                      compositeKey
# 8            Closed   system                   AggregationType
# 9            Closed   system                DataTypeValueRange
# 10           Closed   system                   iso4217Currency
# 11           Closed   system             IdentifierCardinality
# 12             Open   system                   ObjectReference
# 13           Closed   system                 TransactionStatus
# ...

# %%
lusid_response_to_data_frame(result)["value_type"].unique()
# Out:
# array(['String', 'DateTime', 'Percentage', 'Id', 'ResultValue',
#        'UnindexedText', 'Decimal', 'Boolean'], dtype=object)

# %% [markdown]
# <p style="font-family: Montserrat; color: #203443; font-weight: bold; font-size: 125%">Updating Property Definitions</p>

# %%
property_definitions_api = api_factory.build(lusid.api.PropertyDefinitionsApi)

# %%
try:
    property_definitions_api.get_property_definition(
        domain="Instrument",
        scope="FinbourneUniversity",
        code="MarketCap"
    )
except:
    property_definitions_api.create_property_definition(
        create_property_definition_request=lusid.CreatePropertyDefinitionRequest(
            domain="Instrument",
            scope="FinbourneUniversity",
            code="MarketCap",
            data_type_id=lusid.ResourceId(
                scope="system",
                code="number"
            ),
            life_time="TimeVariant",
            constraint_style="Property",
            display_name="Market Capitalisation",
            property_description="The market capitalisation of the instrument",
        )
    )

# %%
property_definitions_api.update_property_definition(
    domain="Instrument",
    scope="FinbourneUniversity",
    code="MarketCap",
    update_property_definition_request=lusid.UpdatePropertyDefinitionRequest(
        display_name="Market Capitalization",
        property_description="The market capitalization of the instrument"
    )
)
# Out:
# {'code': 'MarketCap',
#  'constraint_style': 'Property',
#  'data_type_id': {'code': 'currencyAndAmount', 'scope': 'system'},
#  'derivation_formula': None,
#  'display_name': 'Market Capitalization',
#  'domain': 'Instrument',
#  'href': None,
#  'key': 'Instrument/FinbourneUniversity/MarketCap',
#  'life_time': 'TimeVariant',
#  'links': [{'description': None,
#             'href': 'https://demo.lusid.com/api/api/schemas/entities/PropertyDefinition',
#             'method': 'GET',
#             'relation': 'EntitySchema'},
#            {'description': 'A link to the LUSID Insights website showing all '
#                            'logs related to this request',
#             'href': 'http://demo.lusid.com/app/insights/logs/0HMP5M0ASKAUQ:00000009',
#             'method': 'GET',
#             'relation': 'RequestLogs'}],
#  'property_definition_type': 'ValueProperty',
#  'property_description': 'The market capitalization of the instrument',
#  'scope': 'FinbourneUniversity',
# ...

# %% [markdown]
# <p style="font-family: Montserrat; color: #203443; font-weight: bold; font-size: 125%">Deleting Property Definitions</p>

# %%
property_definitions_api.delete_property_definition(    
    domain="Instrument",
    scope="FinbourneUniversity",
    code="MarketCap"
)
# Out:
# {'as_at': datetime.datetime(2023, 3, 16, 5, 17, 48, 589081, tzinfo=tzlocal()),
#  'effective_from': None,
#  'href': None,
#  'links': [{'description': 'A link to the LUSID Insights website showing all '
#                            'logs related to this request',
#             'href': 'http://demo.lusid.com/app/insights/logs/0HMP5H12SJP25:00000004',
#             'method': 'GET',
#             'relation': 'RequestLogs'}]}

# %% [markdown]
# <p style="font-family: Montserrat; color: #203443; font-weight: bold; font-size: 125%">Creating Property Definitions</p>

# %%
property_definitions_api.create_property_definition(
    create_property_definition_request=lusid.CreatePropertyDefinitionRequest(
        domain="Instrument",
        scope="FinbourneUniversity",
        code="MarketCap",
        data_type_id=lusid.ResourceId(
            scope="system",
            code="currencyAndAmount"
        ),
        life_time="TimeVariant",
        constraint_style="Property",
        display_name="Market Capitalization",
        property_description="The market capitalization of the instrument",
    )
)
# Out:
# {'code': 'MarketCap',
#  'constraint_style': 'Property',
#  'data_type_id': {'code': 'currencyAndAmount', 'scope': 'system'},
#  'derivation_formula': None,
#  'display_name': 'Market Capitalization',
#  'domain': 'Instrument',
#  'href': None,
#  'key': 'Instrument/FinbourneUniversity/MarketCap',
#  'life_time': 'TimeVariant',
#  'links': [{'description': None,
#             'href': 'https://demo.lusid.com/api/api/schemas/entities/PropertyDefinition',
#             'method': 'GET',
#             'relation': 'EntitySchema'},
#            {'description': 'A link to the LUSID Insights website showing all '
#                            'logs related to this request',
#             'href': 'http://demo.lusid.com/app/insights/logs/0HMP5H1I0BBRE:00000005',
#             'method': 'GET',
#             'relation': 'RequestLogs'}],
#  'property_definition_type': 'ValueProperty',
#  'property_description': 'The market capitalization of the instrument',
#  'scope': 'FinbourneUniversity',
# ...

# %%
property_definitions_api.delete_property_definition(
    domain="Instrument",
    scope="FinbourneUniversity",
    code="MarketCap")

# %% [markdown]
# <p style="font-family: Montserrat; color: #203443; font-weight: bold; font-size: 125%">What have we covered?</p>

# %% [markdown]
# <ul>
#     <li style="color: #ff5200"><p style="font-family: Montserrat; color: #203443">We saw that a Property's identifier was made up of a 3 part Property Key in the format {Domain}/{Scope}/{Code}.</p></li>
# </ul>

# %% [markdown]
# <ul>
#     <li style="color: #ff5200"><p style="font-family: Montserrat; color: #203443">We understood how a Property has a well defined Data Type and that custom Data Types can also be defined independently.</p></li>
# </ul>

# %% [markdown]
# <ul>
#     <li style="color: #ff5200"><p style="font-family: Montserrat; color: #203443">We listed the available Data Types using the LUSID API via the Python SDK and looked at some of the details.</p></li>
# </ul>

# %% [markdown]
# <ul>
#     <li style="color: #ff5200"><p style="font-family: Montserrat; color: #203443">We saw that Properties can either be "Perpetual" or "Time-Variant". A "Perpetual" Property is a time-series of values (e.g. a person's birthplace), a "Time-Variant" Property is a time-series of a time-series of values (e.g. a person's address history).</p></li>
# </ul>

# %% [markdown]
# <ul>
#     <li style="color: #ff5200"><p style="font-family: Montserrat; color: #203443">We discussed the available constraint styles for a Property, including "Property", "Identifier" and "Collection".</p></li>
# </ul>

# %% [markdown]
# <ul>
#     <li style="color: #ff5200"><p style="font-family: Montserrat; color: #203443">We created a Property Definition for an Instrument's market capitalisation using the LUSID API via the LUSID website. We discussed that although we have created the definition, no Instruments have been populated with values for the Property.</p></li>
# </ul>

# %% [markdown]
# <ul>
#     <li style="color: #ff5200"><p style="font-family: Montserrat; color: #203443">We updated our Property Definition using the LUSID API via the Python SDK. We realised that there is actually very little we can update on a Property Definition due to potential incompatibility with existing values.</p></li>
# </ul>

# %% [markdown]
# <ul>
#     <li style="color: #ff5200"><p style="font-family: Montserrat; color: #203443">We deleted and re-created our Property Definition and discussed the salient points to consider when re-creating Property Definitions, such as the fact that all previous values are no longer attached to the new Property Definition despite it having the same Property Key.</p></li>
# </ul>
